# %% [markdown]
# # Part 1: Acquisition de données
#
# #### Logique générale
# 1. Classe pour téléchargement de données
# 2. Téléchargement des matches de 2016 à 2023:
#     * **Saisons régulières**. Sauvegarde dans: _data/nhl_reguliere_
#     * **Matches des playoffs**. Sauvegarde dans: _data/nhl_playoffs_
# 3. Fusion des deux repertoires _data/nhl_reguliere_ et _data/nhl_playoffs_ dans _data/nhl_data_

# %% [markdown]
# ### 1. Classe pour téléchargement de données

# %%
import os
import requests
import json
import time

class NHLDataDownloader:
    def __init__(self, base_dir):
        """
        Initialise le répertoire où les données seront sauvegardées.
        :param base_dir: Chemin du répertoire local pour la sauvegarde des données
        """
        self.base_dir = base_dir
        if not os.path.exists(base_dir):
            os.makedirs(base_dir)

    def download_game_data(self, game_id: str) -> dict:
     """
    Télécharge les données d'un match spécifique depuis l'API de la LNH.
    Si le fichier existe déjà localement, il est chargé depuis le disque.
    :param game_id: L'identifiant unique du match (ex. '2020020001' pour le premier match de la saison 2020-21)
    :return: Un dictionnaire contenant les données du match, ou None en cas d'erreur
    """
     file_path = os.path.join(self.base_dir, f"{game_id}.json")
     if os.path.exists(file_path):
        print(f"Fichier {game_id}.json déjà existant dans le répertoire {self.base_dir}.")
        with open(file_path, 'r', encoding='utf-8') as f:
                game = json.load(f)
                return game
     else:
        game_type = str(game_id)[4:6]
        game = None  # Initialisation de la variable 'game'
        if game_type == '02' or game_type == '03':
            url = f"https://api-web.nhle.com/v1/gamecenter/{str(game_id)}/play-by-play"
            try:
                response = requests.get(url)
                response.raise_for_status()  # Vérifie si la requête a réussi
                game = response.json()
                with open(os.path.join(self.base_dir, f"{game_id}.json"), 'w', encoding='utf-8') as f:
                    json.dump(game, f, ensure_ascii=False, indent=4)
                    f.close()
                    print(f"Téléchargé et enregistré : {game_id}.json")
            except Exception as e:
                print(f"Erreur de téléchargement du match {game_id}: {e}")
            time.sleep(1)  # Délai d'une seconde entre les requêtes
        return game

# %% [markdown]
# ##### Exemple de téléchargement d'un fichier existent et d'un fichier non-existent

# %%
# Utilisation de la classe
downloader = NHLDataDownloader(base_dir='../data/test')

# Télécharge les données pour la saison 2016 (saison régulière et playoffs)
downloader.download_game_data(2016020001)
downloader.download_game_data(2016020002)
# Out:
# Fichier 2016020001.json déjà existant dans le répertoire ../data/test.
# Fichier 2016020002.json déjà existant dans le répertoire ../data/test.
# {'id': 2016020002,
#  'season': 20162017,
#  'gameType': 2,
#  'limitedScoring': False,
#  'gameDate': '2016-10-12',
#  'venue': {'default': 'United Center'},
#  'venueLocation': {'default': 'Chicago'},
#  'startTimeUTC': '2016-10-13T00:00:00Z',
#  'easternUTCOffset': '-04:00',
#  'venueUTCOffset': '-05:00',
#  'tvBroadcasts': [{'id': 241,
#    'market': 'N',
#    'countryCode': 'US',
#    'network': 'NBCSN',
#    'sequenceNumber': 13}],
#  'gameState': 'OFF',
#  'gameScheduleState': 'OK',
#  'periodDescriptor': {'number': 3,
#   'periodType': 'REG',
#   'maxRegulationPeriods': 3},
#  'awayTeam': {'id': 19,
#   'name': {'default': 'Blues'},
#   'abbrev': 'STL',
#   'score': 5,
#   'sog': 33,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/STL_light.svg',
#   'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/STL_dark.svg',
#   'placeName': {'default': 'St. Louis'},
#   'placeNameWithPreposition': {'default': 'St. Louis', 'fr': 'de St. Louis'}},
#  'homeTeam': {'id': 16,
#   'name': {'default': 'Blackhawks'},
#   'abbrev': 'CHI',
#   'score': 2,
#   'sog': 19,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/CHI_light.svg',
#   'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CHI_dark.svg',
#   'placeName': {'default': 'Chicago'},
#   'placeNameWithPreposition': {'default': 'Chicago', 'fr': 'de Chicago'}},
#  'shootoutInUse': True,
#  'otInUse': True,
#  'clock': {'timeRemaining': '00:00',
#   'secondsRemaining': 0,
#   'running': False,
#   'inIntermission': False},
#  'displayPeriod': 1,
#  'maxPeriods': 5,
#  'gameOutcome': {'lastPeriodType': 'REG'},
#  'plays': [{'eventId': 5,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'typeCode': 520,
#    'typeDescKey': 'period-start',
#    'sortOrder': 5},
#   {'eventId': 6,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 6,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473604,
#     'winningPlayerId': 8471669,
#     'xCoord': 1,
#     'yCoord': 1,
#     'zoneCode': 'N'}},
#   {'eventId': 7,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:12',
#    'timeRemaining': '19:48',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 7,
#    'details': {'xCoord': 64,
#     'yCoord': -16,
#     'zoneCode': 'O',
#     'shotType': 'snap',
#     'shootingPlayerId': 8470257,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 1,
#     'homeSOG': 0}},
#   {'eventId': 51,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:11',
#    'timeRemaining': '19:49',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 8,
#    'details': {'xCoord': 88,
#     'yCoord': -37,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8471669,
#     'hitteePlayerId': 8470281}},
#   {'eventId': 8,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:45',
#    'timeRemaining': '19:15',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 9,
#    'details': {'xCoord': 54,
#     'yCoord': 28,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'slap',
#     'shootingPlayerId': 8470151,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 9,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:10',
#    'timeRemaining': '18:50',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 13,
#    'details': {'xCoord': 52,
#     'yCoord': -8,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474627,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 2,
#     'homeSOG': 0}},
#   {'eventId': 53,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:10',
#    'timeRemaining': '18:50',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 15,
#    'details': {'reason': 'goalie-stopped-after-sog'}},
#   {'eventId': 10,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:10',
#    'timeRemaining': '18:50',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 17,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8474627,
#     'winningPlayerId': 8475323,
#     'xCoord': 69,
#     'yCoord': -22,
#     'zoneCode': 'D'}},
#   {'eventId': 54,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:24',
#    'timeRemaining': '18:36',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 18,
#    'details': {'xCoord': -95,
#     'yCoord': 21,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477353,
#     'hitteePlayerId': 8476441}},
#   {'eventId': 11,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:33',
#    'timeRemaining': '18:27',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 19,
#    'details': {'xCoord': 86,
#     'yCoord': 11,
#     'zoneCode': 'O',
#     'reason': 'goalpost',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8476892,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 55,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:06',
#    'timeRemaining': '17:54',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 22,
#    'details': {'xCoord': 42,
#     'yCoord': 32,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8466285}},
#   {'eventId': 12,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:27',
#    'timeRemaining': '17:33',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 24,
#    'details': {'xCoord': -77,
#     'yCoord': 8,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8474565,
#     'shootingPlayerId': 8473573,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 56,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:38',
#    'timeRemaining': '17:22',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 27,
#    'details': {'xCoord': -33,
#     'yCoord': -37,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8479482,
#     'hitteePlayerId': 8476436}},
#   {'eventId': 13,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:36',
#    'timeRemaining': '17:24',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 29,
#    'details': {'xCoord': -66,
#     'yCoord': 7,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8470151,
#     'shootingPlayerId': 8474141,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 57,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:50',
#    'timeRemaining': '17:10',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 30,
#    'details': {'xCoord': -90,
#     'yCoord': 28,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474145,
#     'hitteePlayerId': 8476994}},
#   {'eventId': 58,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:54',
#    'timeRemaining': '17:06',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 31,
#    'details': {'xCoord': -92,
#     'yCoord': 33,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8469547,
#     'hitteePlayerId': 8474145}},
#   {'eventId': 59,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:00',
#    'timeRemaining': '17:00',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 33,
#    'details': {'reason': 'offside'}},
#   {'eventId': 14,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:00',
#    'timeRemaining': '17:00',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 35,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8471669,
#     'winningPlayerId': 8473604,
#     'xCoord': 20,
#     'yCoord': -21,
#     'zoneCode': 'N'}},
#   {'eventId': 60,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:22',
#    'timeRemaining': '16:38',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 36,
#    'details': {'xCoord': -65,
#     'yCoord': -39,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474145,
#     'hitteePlayerId': 8466148}},
#   {'eventId': 15,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:28',
#    'timeRemaining': '16:32',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 37,
#    'details': {'xCoord': -82,
#     'yCoord': -8,
#     'zoneCode': 'O',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8473604,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 2,
#     'homeSOG': 1}},
#   {'eventId': 16,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:31',
#    'timeRemaining': '16:29',
#    'situationCode': '1551',
#    'typeCode': 509,
#    'typeDescKey': 'penalty',
#    'sortOrder': 39,
#    'details': {'xCoord': -30,
#     'yCoord': 38,
#     'zoneCode': 'D',
#     'typeCode': 'MIN',
#     'descKey': 'slashing',
#     'duration': 2,
#     'committedByPlayerId': 8477952,
#     'drawnByPlayerId': 8477845,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 61,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:31',
#    'timeRemaining': '16:29',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 43,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8474141,
#     'winningPlayerId': 8474627,
#     'xCoord': -68,
#     'yCoord': -23,
#     'zoneCode': 'D'}},
#   {'eventId': 18,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:45',
#    'timeRemaining': '16:15',
#    'situationCode': '1451',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 44,
#    'details': {'xCoord': -76,
#     'yCoord': 29,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474141,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 2,
#     'homeSOG': 2}},
#   {'eventId': 62,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:53',
#    'timeRemaining': '16:07',
#    'situationCode': '1451',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 45,
#    'details': {'xCoord': -17,
#     'yCoord': 27,
#     'zoneCode': 'N',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474102,
#     'hitteePlayerId': 8470607}},
#   {'eventId': 63,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:17',
#    'timeRemaining': '15:43',
#    'situationCode': '1451',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 50,
#    'details': {'xCoord': -17,
#     'yCoord': 35,
#     'zoneCode': 'N',
#     'playerId': 8470803,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 64,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:26',
#    'timeRemaining': '15:34',
#    'situationCode': '1451',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 53,
#    'details': {'reason': 'offside'}},
#   {'eventId': 19,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:26',
#    'timeRemaining': '15:34',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 55,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8471669,
#     'winningPlayerId': 8473604,
#     'xCoord': -69,
#     'yCoord': 21,
#     'zoneCode': 'O'}},
#   {'eventId': 20,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:37',
#    'timeRemaining': '15:23',
#    'situationCode': '1451',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 56,
#    'details': {'xCoord': -76,
#     'yCoord': 2,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8473604,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 2,
#     'homeSOG': 3}},
#   {'eventId': 21,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:38',
#    'timeRemaining': '15:22',
#    'situationCode': '1451',
#    'typeCode': 505,
#    'typeDescKey': 'goal',
#    'sortOrder': 57,
#    'details': {'xCoord': -81,
#     'yCoord': -8,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'scoringPlayerId': 8475209,
#     'scoringPlayerTotal': 1,
#     'assist1PlayerId': 8473604,
#     'assist1PlayerTotal': 1,
#     'assist2PlayerId': 8466148,
#     'assist2PlayerTotal': 1,
#     'eventOwnerTeamId': 16,
#     'goalieInNetId': 8474596,
#     'awayScore': 0,
#     'homeScore': 1}},
#   {'eventId': 65,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:38',
#    'timeRemaining': '15:22',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 61,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8474627,
#     'winningPlayerId': 8473573,
#     'xCoord': 1,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 22,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:57',
#    'timeRemaining': '15:03',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 63,
#    'details': {'xCoord': -79,
#     'yCoord': -3,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8473573,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 2,
#     'homeSOG': 4}},
#   {'eventId': 23,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:01',
#    'timeRemaining': '14:59',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 64,
#    'details': {'xCoord': -77,
#     'yCoord': -1,
#     'zoneCode': 'O',
#     'reason': 'over-net',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8473573,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 24,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:06',
#    'timeRemaining': '14:54',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 65,
#    'details': {'xCoord': -68,
#     'yCoord': 3,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8475765,
#     'shootingPlayerId': 8479482,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 25,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:16',
#    'timeRemaining': '14:44',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 66,
#    'details': {'xCoord': -76,
#     'yCoord': -3,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8470151,
#     'shootingPlayerId': 8473573,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 66,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:12',
#    'timeRemaining': '14:48',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 67,
#    'details': {'xCoord': -91,
#     'yCoord': -37,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474565,
#     'hitteePlayerId': 8473573}},
#   {'eventId': 26,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:25',
#    'timeRemaining': '14:35',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 69,
#    'details': {'xCoord': 74,
#     'yCoord': -34,
#     'zoneCode': 'O',
#     'shotType': 'slap',
#     'shootingPlayerId': 8474565,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 3,
#     'homeSOG': 4}},
#   {'eventId': 67,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:38',
#    'timeRemaining': '14:22',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 72,
#    'details': {'xCoord': -95,
#     'yCoord': 32,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477451,
#     'hitteePlayerId': 8476436}},
#   {'eventId': 68,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:01',
#    'timeRemaining': '13:59',
#    'situationCode': '1551',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 73,
#    'details': {'xCoord': -64,
#     'yCoord': -37,
#     'zoneCode': 'O',
#     'playerId': 8477353,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 27,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:04',
#    'timeRemaining': '13:56',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 74,
#    'details': {'xCoord': -46,
#     'yCoord': -26,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8473534,
#     'shootingPlayerId': 8470281,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 69,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:15',
#    'timeRemaining': '13:45',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 78,
#    'details': {'xCoord': -34,
#     'yCoord': -7,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8471817,
#     'hitteePlayerId': 8475323}},
#   {'eventId': 28,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:23',
#    'timeRemaining': '13:37',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 81,
#    'details': {'xCoord': 65,
#     'yCoord': -35,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'slap',
#     'shootingPlayerId': 8470803,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 70,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:43',
#    'timeRemaining': '13:17',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 83,
#    'details': {'xCoord': 84,
#     'yCoord': -38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8478055}},
#   {'eventId': 29,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:48',
#    'timeRemaining': '13:12',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 84,
#    'details': {'xCoord': 44,
#     'yCoord': 19,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8469547,
#     'shootingPlayerId': 8476441,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 71,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:56',
#    'timeRemaining': '13:04',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 85,
#    'details': {'xCoord': 61,
#     'yCoord': 38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8469547}},
#   {'eventId': 30,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '07:58',
#    'timeRemaining': '12:02',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 95,
#    'details': {'xCoord': 63,
#     'yCoord': -3,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474627,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 4,
#     'homeSOG': 4}},
#   {'eventId': 31,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:03',
#    'timeRemaining': '11:57',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 96,
#    'details': {'xCoord': 78,
#     'yCoord': 13,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8475765,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 32,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:30',
#    'timeRemaining': '11:30',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 99,
#    'details': {'xCoord': 72,
#     'yCoord': 3,
#     'zoneCode': 'O',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8474145,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 5,
#     'homeSOG': 4}},
#   {'eventId': 73,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:47',
#    'timeRemaining': '11:13',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 102,
#    'details': {'reason': 'offside', 'secondaryReason': 'tv-timeout'}},
#   {'eventId': 33,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:47',
#    'timeRemaining': '11:13',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 104,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8475323,
#     'winningPlayerId': 8473534,
#     'xCoord': 20,
#     'yCoord': 23,
#     'zoneCode': 'N'}},
#   {'eventId': 74,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '09:13',
#    'timeRemaining': '10:47',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 105,
#    'details': {'xCoord': 92,
#     'yCoord': -36,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8476855,
#     'hitteePlayerId': 8466285}},
#   {'eventId': 75,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '09:36',
#    'timeRemaining': '10:24',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 108,
#    'details': {'xCoord': 95,
#     'yCoord': 12,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477845,
#     'hitteePlayerId': 8476892}},
#   {'eventId': 34,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '09:46',
#    'timeRemaining': '10:14',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 112,
#    'details': {'xCoord': -49,
#     'yCoord': 17,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8474102,
#     'shootingPlayerId': 8466148,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 35,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '09:54',
#    'timeRemaining': '10:06',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 113,
#    'details': {'xCoord': -58,
#     'yCoord': 21,
#     'zoneCode': 'O',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8466148,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 5,
#     'homeSOG': 5}},
#   {'eventId': 76,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '10:20',
#    'timeRemaining': '09:40',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 118,
#    'details': {'xCoord': 93,
#     'yCoord': 31,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8477952,
#     'hitteePlayerId': 8474141}},
#   {'eventId': 77,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '10:40',
#    'timeRemaining': '09:20',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 119,
#    'details': {'xCoord': -96,
#     'yCoord': -31,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8474565}},
#   {'eventId': 78,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:02',
#    'timeRemaining': '08:58',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 124,
#    'details': {'xCoord': -51,
#     'yCoord': -39,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474031,
#     'hitteePlayerId': 8474141}},
#   {'eventId': 79,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:08',
#    'timeRemaining': '08:52',
#    'situationCode': '1551',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 126,
#    'details': {'xCoord': -54,
#     'yCoord': 37,
#     'zoneCode': 'O',
#     'playerId': 8476994,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 80,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:16',
#    'timeRemaining': '08:44',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 128,
#    'details': {'xCoord': 81,
#     'yCoord': 0,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8470645}},
#   {'eventId': 36,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:18',
#    'timeRemaining': '08:42',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 129,
#    'details': {'xCoord': 52,
#     'yCoord': 3,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8470105,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 6,
#     'homeSOG': 5}},
#   {'eventId': 81,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:18',
#    'timeRemaining': '08:42',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 130,
#    'details': {'reason': 'goalie-stopped-after-sog',
#     'secondaryReason': 'tv-timeout'}},
#   {'eventId': 37,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:18',
#    'timeRemaining': '08:42',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 133,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8474102,
#     'winningPlayerId': 8475323,
#     'xCoord': 73,
#     'yCoord': 24,
#     'zoneCode': 'D'}},
#   {'eventId': 82,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:24',
#    'timeRemaining': '08:36',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 134,
#    'details': {'reason': 'puck-in-benches'}},
#   {'eventId': 38,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:24',
#    'timeRemaining': '08:36',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 135,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8475323,
#     'winningPlayerId': 8474627,
#     'xCoord': 68,
#     'yCoord': 22,
#     'zoneCode': 'O'}},
#   {'eventId': 39,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:31',
#    'timeRemaining': '08:29',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 136,
#    'details': {'xCoord': 50,
#     'yCoord': -22,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8477353,
#     'shootingPlayerId': 8474031,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 83,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:41',
#    'timeRemaining': '08:19',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 137,
#    'details': {'xCoord': -60,
#     'yCoord': -35,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8474031}},
#   {'eventId': 84,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:56',
#    'timeRemaining': '08:04',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 140,
#    'details': {'xCoord': -96,
#     'yCoord': -6,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474031,
#     'hitteePlayerId': 8475323}},
#   {'eventId': 85,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:05',
#    'timeRemaining': '07:55',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 143,
#    'details': {'xCoord': 76,
#     'yCoord': 38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477353,
#     'hitteePlayerId': 8475765}},
#   {'eventId': 86,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:17',
#    'timeRemaining': '07:43',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 144,
#    'details': {'reason': 'icing'}},
#   {'eventId': 40,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:17',
#    'timeRemaining': '07:43',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 145,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8471669,
#     'winningPlayerId': 8473604,
#     'xCoord': 69,
#     'yCoord': -21,
#     'zoneCode': 'D'}},
#   {'eventId': 87,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:28',
#    'timeRemaining': '07:32',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 146,
#    'details': {'xCoord': 80,
#     'yCoord': -38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8479482,
#     'hitteePlayerId': 8470257}},
#   {'eventId': 41,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:04',
#    'timeRemaining': '06:56',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 151,
#    'details': {'xCoord': 78,
#     'yCoord': 30,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8473534,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 7,
#     'homeSOG': 5}},
#   {'eventId': 88,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:05',
#    'timeRemaining': '06:55',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 152,
#    'details': {'reason': 'goalie-stopped-after-sog'}},
#   {'eventId': 42,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:05',
#    'timeRemaining': '06:55',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 154,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473573,
#     'winningPlayerId': 8473534,
#     'xCoord': 68,
#     'yCoord': 21,
#     'zoneCode': 'O'}},
#   {'eventId': 89,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:17',
#    'timeRemaining': '06:43',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 155,
#    'details': {'xCoord': -94,
#     'yCoord': 32,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8478550,
#     'hitteePlayerId': 8476441}},
#   {'eventId': 90,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:30',
#    'timeRemaining': '06:30',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 157,
#    'details': {'xCoord': -75,
#     'yCoord': -30,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8476892}},
#   {'eventId': 91,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:40',
#    'timeRemaining': '06:20',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 159,
#    'details': {'xCoord': -62,
#     'yCoord': 37,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8476441,
#     'hitteePlayerId': 8474141}},
#   {'eventId': 92,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:47',
#    'timeRemaining': '06:13',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 160,
#    'details': {'xCoord': -84,
#     'yCoord': -18,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8476892}},
#   {'eventId': 43,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:14',
#    'timeRemaining': '05:46',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 166,
#    'details': {'xCoord': 69,
#     'yCoord': -33,
#     'zoneCode': 'O',
#     'shotType': 'snap',
#     'shootingPlayerId': 8470803,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 8,
#     'homeSOG': 5}},
#   {'eventId': 93,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:14',
#    'timeRemaining': '05:46',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 167,
#    'details': {'reason': 'goalie-stopped-after-sog',
#     'secondaryReason': 'tv-timeout'}},
#   {'eventId': 44,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:14',
#    'timeRemaining': '05:46',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 170,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8471669,
#     'winningPlayerId': 8473604,
#     'xCoord': 70,
#     'yCoord': -22,
#     'zoneCode': 'D'}},
#   {'eventId': 94,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:51',
#    'timeRemaining': '05:09',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 175,
#    'details': {'xCoord': -55,
#     'yCoord': -37,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474627,
#     'hitteePlayerId': 8466148}},
#   {'eventId': 95,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:15',
#    'timeRemaining': '04:45',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 179,
#    'details': {'xCoord': -3,
#     'yCoord': -40,
#     'zoneCode': 'N',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8474141,
#     'hitteePlayerId': 8476892}},
#   {'eventId': 96,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:15',
#    'timeRemaining': '04:45',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 180,
#    'details': {'reason': 'offside'}},
#   {'eventId': 45,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:15',
#    'timeRemaining': '04:45',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 182,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473573,
#     'winningPlayerId': 8473534,
#     'xCoord': 19,
#     'yCoord': -21,
#     'zoneCode': 'N'}},
#   {'eventId': 97,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:26',
#    'timeRemaining': '04:34',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 184,
#    'details': {'xCoord': 95,
#     'yCoord': 3,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8466285,
#     'hitteePlayerId': 8470151}},
#   {'eventId': 98,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:44',
#    'timeRemaining': '04:16',
#    'situationCode': '1551',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 185,
#    'details': {'xCoord': -48,
#     'yCoord': 29,
#     'zoneCode': 'D',
#     'playerId': 8476436,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 46,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:52',
#    'timeRemaining': '04:08',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 186,
#    'details': {'xCoord': -47,
#     'yCoord': 8,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'slap',
#     'shootingPlayerId': 8473573,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 99,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:22',
#    'timeRemaining': '03:38',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 192,
#    'details': {'xCoord': -71,
#     'yCoord': -38,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8476994,
#     'hitteePlayerId': 8474145}},
#   {'eventId': 100,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:26',
#    'timeRemaining': '03:34',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 193,
#    'details': {'reason': 'puck-in-benches'}},
#   {'eventId': 47,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:26',
#    'timeRemaining': '03:34',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 195,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8477951,
#     'winningPlayerId': 8470803,
#     'xCoord': 0,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 48,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:42',
#    'timeRemaining': '03:18',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 196,
#    'details': {'xCoord': 51,
#     'yCoord': -7,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8471817,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 251,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:52',
#    'timeRemaining': '03:08',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 197,
#    'details': {'xCoord': 86,
#     'yCoord': 38,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8470105,
#     'hitteePlayerId': 8470607}},
#   {'eventId': 49,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:06',
#    'timeRemaining': '02:54',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 198,
#    'details': {'xCoord': 36,
#     'yCoord': -33,
#     'zoneCode': 'O',
#     'shotType': 'slap',
#     'shootingPlayerId': 8476892,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 9,
#     'homeSOG': 5}},
#   {'eventId': 252,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:03',
#    'timeRemaining': '02:57',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 200,
#    'details': {'xCoord': 54,
#     'yCoord': 35,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8470803,
#     'hitteePlayerId': 8469547}},
#   {'eventId': 253,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:45',
#    'timeRemaining': '02:15',
#    'situationCode': '1551',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 205,
#    'details': {'xCoord': -13,
#     'yCoord': 27,
#     'zoneCode': 'N',
#     'playerId': 8470257,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 254,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:16',
#    'timeRemaining': '01:44',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 212,
#    'details': {'reason': 'high-stick'}},
#   {'eventId': 50,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:16',
#    'timeRemaining': '01:44',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 215,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8470803,
#     'winningPlayerId': 8473573,
#     'xCoord': -68,
#     'yCoord': -24,
#     'zoneCode': 'O'}},
#   {'eventId': 255,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:33',
#    'timeRemaining': '01:27',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 216,
#    'details': {'xCoord': -57,
#     'yCoord': 41,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8476441,
#     'hitteePlayerId': 8473573}},
#   {'eventId': 201,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:39',
#    'timeRemaining': '01:21',
#    'situationCode': '1551',
#    'typeCode': 509,
#    'typeDescKey': 'penalty',
#    'sortOrder': 217,
#    'details': {'xCoord': -50,
#     'yCoord': -38,
#     'zoneCode': 'D',
#     'typeCode': 'MIN',
#     'descKey': 'holding',
#     'duration': 2,
#     'committedByPlayerId': 8476892,
#     'drawnByPlayerId': 8474141,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 256,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:39',
#    'timeRemaining': '01:21',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 221,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473604,
#     'winningPlayerId': 8471669,
#     'xCoord': -68,
#     'yCoord': -23,
#     'zoneCode': 'D'}},
#   {'eventId': 257,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:22',
#    'timeRemaining': '00:38',
#    'situationCode': '1451',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 225,
#    'details': {'xCoord': -94,
#     'yCoord': 5,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8474596}},
#   {'eventId': 258,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:33',
#    'timeRemaining': '00:27',
#    'situationCode': '1451',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 227,
#    'details': {'xCoord': -45,
#     'yCoord': -34,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474145,
#     'hitteePlayerId': 8478550}},
#   {'eventId': 203,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '20:00',
#    'timeRemaining': '00:00',
#    'typeCode': 521,
#    'typeDescKey': 'period-end',
#    'sortOrder': 230},
#   {'eventId': 208,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'typeCode': 520,
#    'typeDescKey': 'period-start',
#    'sortOrder': 237},
#   {'eventId': 209,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 238,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473604,
#     'winningPlayerId': 8471669,
#     'xCoord': 2,
#     'yCoord': 1,
#     'zoneCode': 'N'}},
#   {'eventId': 259,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:32',
#    'timeRemaining': '19:28',
#    'situationCode': '1451',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 240,
#    'details': {'reason': 'offside'}},
#   {'eventId': 210,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:32',
#    'timeRemaining': '19:28',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 242,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8474627,
#     'winningPlayerId': 8473573,
#     'xCoord': 1,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 260,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:53',
#    'timeRemaining': '19:07',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 245,
#    'details': {'xCoord': -30,
#     'yCoord': -18,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8475209}},
#   {'eventId': 211,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:55',
#    'timeRemaining': '19:05',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 246,
#    'details': {'xCoord': -77,
#     'yCoord': 4,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474102,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 10,
#     'homeSOG': 5}},
#   {'eventId': 212,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:56',
#    'timeRemaining': '19:04',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 247,
#    'details': {'xCoord': -91,
#     'yCoord': 13,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474102,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
# ...
#    'sortOrder': 649,
#    'details': {'xCoord': -52,
#     'yCoord': -12,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8471669,
#     'shootingPlayerId': 8478550,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 619,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:44',
#    'timeRemaining': '01:16',
#    'situationCode': '1560',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 650,
#    'details': {'xCoord': -45,
#     'yCoord': 10,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8470257,
#     'shootingPlayerId': 8478055,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 620,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:54',
#    'timeRemaining': '01:06',
#    'situationCode': '1560',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 651,
#    'details': {'xCoord': 81,
#     'yCoord': -15,
#     'zoneCode': 'O',
#     'reason': 'goalpost',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8471669,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 621,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:54',
#    'timeRemaining': '01:06',
#    'situationCode': '1560',
#    'typeCode': 505,
#    'typeDescKey': 'goal',
#    'sortOrder': 652,
#    'details': {'xCoord': 77,
#     'yCoord': 5,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'scoringPlayerId': 8475765,
#     'scoringPlayerTotal': 2,
#     'assist1PlayerId': 8471669,
#     'assist1PlayerTotal': 2,
#     'assist2PlayerId': 8470257,
#     'assist2PlayerTotal': 2,
#     'eventOwnerTeamId': 19,
#     'awayScore': 4,
#     'homeScore': 2}},
#   {'eventId': 598,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:54',
#    'timeRemaining': '01:06',
#    'situationCode': '1560',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 655,
#    'details': {'reason': 'home-timeout', 'secondaryReason': 'home-timeout'}},
#   {'eventId': 599,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:54',
#    'timeRemaining': '01:06',
#    'situationCode': '1560',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 657,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8473534,
#     'winningPlayerId': 8473604,
#     'xCoord': 1,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 623,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:06',
#    'timeRemaining': '00:54',
#    'situationCode': '1560',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 658,
#    'details': {'xCoord': 34,
#     'yCoord': 16,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8470281,
#     'shootingPlayerId': 8473534,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 600,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:10',
#    'timeRemaining': '00:50',
#    'situationCode': '1560',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 659,
#    'details': {'xCoord': 45,
#     'yCoord': -38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8473604,
#     'hitteePlayerId': 8470803}},
#   {'eventId': 701,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:24',
#    'timeRemaining': '00:36',
#    'situationCode': '1560',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 660,
#    'details': {'xCoord': -70,
#     'yCoord': -8,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8476892}},
#   {'eventId': 1101,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:41',
#    'timeRemaining': '00:19',
#    'situationCode': '1560',
#    'typeCode': 505,
#    'typeDescKey': 'goal',
#    'sortOrder': 663,
#    'details': {'xCoord': 26,
#     'yCoord': 27,
#     'zoneCode': 'N',
#     'shotType': 'wrist',
#     'scoringPlayerId': 8470105,
#     'scoringPlayerTotal': 1,
#     'eventOwnerTeamId': 19,
#     'awayScore': 5,
#     'homeScore': 2}},
#   {'eventId': 702,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:41',
#    'timeRemaining': '00:19',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 665,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8477951,
#     'winningPlayerId': 8474627,
#     'xCoord': 0,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 703,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:51',
#    'timeRemaining': '00:09',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 667,
#    'details': {'xCoord': 95,
#     'yCoord': 14,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477951,
#     'hitteePlayerId': 8474627}},
#   {'eventId': 625,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:59',
#    'timeRemaining': '00:01',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 668,
#    'details': {'xCoord': 57,
#     'yCoord': -14,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8477951,
#     'shootingPlayerId': 8476436,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 626,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '20:00',
#    'timeRemaining': '00:00',
#    'typeCode': 521,
#    'typeDescKey': 'period-end',
#    'sortOrder': 669},
#   {'eventId': 630,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '20:00',
#    'timeRemaining': '00:00',
#    'typeCode': 524,
#    'typeDescKey': 'game-end',
#    'sortOrder': 673}],
#  'rosterSpots': [{'teamId': 16,
#    'playerId': 8466148,
#    'firstName': {'default': 'Marian'},
#    'lastName': {'default': 'Hossa'},
#    'sweaterNumber': 81,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8466148.png'},
#   {'teamId': 16,
#    'playerId': 8466285,
#    'firstName': {'default': 'Brian'},
#    'lastName': {'default': 'Campbell'},
#    'sweaterNumber': 51,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8466285.png'},
#   {'teamId': 16,
#    'playerId': 8469547,
#    'firstName': {'default': 'Jordin'},
#    'lastName': {'default': 'Tootoo'},
#    'sweaterNumber': 22,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8469547.png'},
#   {'teamId': 19,
#    'playerId': 8470105,
#    'firstName': {'default': 'Scottie'},
#    'lastName': {'default': 'Upshall'},
#    'sweaterNumber': 10,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8470105.png'},
#   {'teamId': 19,
#    'playerId': 8470151,
#    'firstName': {'default': 'Jay'},
#    'lastName': {'default': 'Bouwmeester'},
#    'sweaterNumber': 19,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8470151.png'},
#   {'teamId': 19,
#    'playerId': 8470257,
#    'firstName': {'default': 'Alexander'},
#    'lastName': {'default': 'Steen'},
#    'sweaterNumber': 20,
#    'positionCode': 'L',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8470257.png'},
#   {'teamId': 16,
#    'playerId': 8470281,
#    'firstName': {'default': 'Duncan'},
#    'lastName': {'default': 'Keith'},
#    'sweaterNumber': 2,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8470281.png'},
#   {'teamId': 16,
#    'playerId': 8470607,
#    'firstName': {'default': 'Brent'},
#    'lastName': {'default': 'Seabrook'},
#    'sweaterNumber': 7,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8470607.png'},
#   {'teamId': 16,
#    'playerId': 8470645,
#    'firstName': {'default': 'Corey'},
#    'lastName': {'default': 'Crawford'},
#    'sweaterNumber': 50,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8470645.png'},
#   {'teamId': 19,
#    'playerId': 8470803,
#    'firstName': {'default': 'Kyle'},
#    'lastName': {'default': 'Brodziak'},
#    'sweaterNumber': 28,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8470803.png'},
#   {'teamId': 19,
#    'playerId': 8471669,
#    'firstName': {'default': 'Paul'},
#    'lastName': {'default': 'Stastny'},
#    'sweaterNumber': 26,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8471669.png'},
#   {'teamId': 19,
#    'playerId': 8471817,
#    'firstName': {'default': 'Ryan'},
#    'lastName': {'default': 'Reaves'},
#    'sweaterNumber': 75,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8471817.png'},
#   {'teamId': 19,
#    'playerId': 8473534,
#    'firstName': {'default': 'Patrik'},
#    'lastName': {'default': 'Berglund'},
#    'sweaterNumber': 21,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8473534.png'},
#   {'teamId': 16,
#    'playerId': 8473573,
#    'firstName': {'default': 'Artem',
#     'cs': 'Arťom',
#     'fi': 'Artjom',
#     'sk': 'Arťom'},
#    'lastName': {'default': 'Anisimov'},
#    'sweaterNumber': 15,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8473573.png'},
#   {'teamId': 16,
#    'playerId': 8473604,
#    'firstName': {'default': 'Jonathan'},
#    'lastName': {'default': 'Toews'},
#    'sweaterNumber': 19,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8473604.png'},
#   {'teamId': 19,
#    'playerId': 8474031,
#    'firstName': {'default': 'Kevin'},
#    'lastName': {'default': 'Shattenkirk'},
#    'sweaterNumber': 22,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474031.png'},
#   {'teamId': 19,
#    'playerId': 8474102,
#    'firstName': {'default': 'David'},
#    'lastName': {'default': 'Perron'},
#    'sweaterNumber': 57,
#    'positionCode': 'L',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474102.png'},
#   {'teamId': 16,
#    'playerId': 8474141,
#    'firstName': {'default': 'Patrick'},
#    'lastName': {'default': 'Kane'},
#    'sweaterNumber': 88,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8474141.png'},
#   {'teamId': 19,
#    'playerId': 8474145,
#    'firstName': {'default': 'Robert'},
#    'lastName': {'default': 'Bortuzzo'},
#    'sweaterNumber': 41,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474145.png'},
#   {'teamId': 16,
#    'playerId': 8474152,
#    'firstName': {'default': 'Scott'},
#    'lastName': {'default': 'Darling'},
#    'sweaterNumber': 33,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8474152.png'},
#   {'teamId': 19,
#    'playerId': 8474565,
#    'firstName': {'default': 'Alex'},
#    'lastName': {'default': 'Pietrangelo'},
#    'sweaterNumber': 27,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474565.png'},
#   {'teamId': 19,
#    'playerId': 8474596,
#    'firstName': {'default': 'Jake'},
#    'lastName': {'default': 'Allen'},
#    'sweaterNumber': 34,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474596.png'},
#   {'teamId': 19,
#    'playerId': 8474627,
#    'firstName': {'default': 'Jori'},
#    'lastName': {'default': 'Lehtera'},
#    'sweaterNumber': 12,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474627.png'},
#   {'teamId': 16,
#    'playerId': 8475209,
#    'firstName': {'default': 'Richard'},
#    'lastName': {'default': 'Panik', 'cs': 'Pánik', 'sk': 'Pánik'},
#    'sweaterNumber': 14,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8475209.png'},
#   {'teamId': 16,
#    'playerId': 8475323,
#    'firstName': {'default': 'Marcus'},
#    'lastName': {'default': 'Kruger'},
#    'sweaterNumber': 16,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8475323.png'},
#   {'teamId': 19,
#    'playerId': 8475622,
#    'firstName': {'default': 'Carter'},
#    'lastName': {'default': 'Hutton'},
#    'sweaterNumber': 40,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8475622.png'},
#   {'teamId': 19,
#    'playerId': 8475765,
#    'firstName': {'default': 'Vladimir'},
#    'lastName': {'default': 'Tarasenko'},
#    'sweaterNumber': 91,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8475765.png'},
#   {'teamId': 19,
#    'playerId': 8476436,
#    'firstName': {'default': 'Dmitrij'},
#    'lastName': {'default': 'Jaskin', 'cs': 'Jaškin', 'sk': 'Jaškin'},
#    'sweaterNumber': 23,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8476436.png'},
#   {'teamId': 19,
#    'playerId': 8476441,
#    'firstName': {'default': 'Joel'},
#    'lastName': {'default': 'Edmundson'},
#    'sweaterNumber': 6,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8476441.png'},
#   {'teamId': 19,
#    'playerId': 8476855,
#    'firstName': {'default': 'Nail'},
#    'lastName': {'default': 'Yakupov'},
#    'sweaterNumber': 64,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8476855.png'},
#   {'teamId': 19,
#    'playerId': 8476892,
#    'firstName': {'default': 'Colton'},
#    'lastName': {'default': 'Parayko'},
#    'sweaterNumber': 55,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8476892.png'},
#   {'teamId': 16,
#    'playerId': 8476994,
#    'firstName': {'default': 'Vinnie'},
#    'lastName': {'default': 'Hinostroza'},
#    'sweaterNumber': 48,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8476994.png'},
#   {'teamId': 16,
#    'playerId': 8477353,
#    'firstName': {'default': 'Tyler'},
#    'lastName': {'default': 'Motte'},
#    'sweaterNumber': 64,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8477353.png'},
#   {'teamId': 16,
#    'playerId': 8477451,
#    'firstName': {'default': 'Ryan'},
#    'lastName': {'default': 'Hartman'},
#    'sweaterNumber': 38,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8477451.png'},
#   {'teamId': 16,
#    'playerId': 8477845,
#    'firstName': {'default': 'Trevor'},
#    'lastName': {'default': 'van Riemsdyk'},
#    'sweaterNumber': 57,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8477845.png'},
#   {'teamId': 16,
#    'playerId': 8477951,
#    'firstName': {'default': 'Nick'},
#    'lastName': {'default': 'Schmaltz'},
#    'sweaterNumber': 8,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8477951.png'},
#   {'teamId': 19,
#    'playerId': 8477952,
#    'firstName': {'default': 'Robby'},
#    'lastName': {'default': 'Fabbri'},
#    'sweaterNumber': 15,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8477952.png'},
#   {'teamId': 16,
#    'playerId': 8478055,
#    'firstName': {'default': 'Gustav'},
#    'lastName': {'default': 'Forsling'},
#    'sweaterNumber': 42,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8478055.png'},
#   {'teamId': 16,
#    'playerId': 8478550,
#    'firstName': {'default': 'Artemi', 'cs': 'Artěmij', 'sk': 'Artemij'},
#    'lastName': {'default': 'Panarin'},
#    'sweaterNumber': 72,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8478550.png'},
#   {'teamId': 16,
#    'playerId': 8479482,
#    'firstName': {'default': 'Michal'},
#    'lastName': {'default': 'Kempny', 'cs': 'Kempný', 'sk': 'Kempný'},
#    'sweaterNumber': 6,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8479482.png'}],
#  'regPeriods': 3,
#  'summary': {}}

# %% [markdown]
# ### 2. Téléchargement des matches de 2016 à 2023

# %% [markdown]
# #### **Saisons régulières**. Sauvegarde dans: _data/nhl_reguliere_

# %%
# Utilisation de la classe
downloader = NHLDataDownloader(base_dir='../data/nhl_reguliere')

def download_all_seasons(downloader, start_year, end_year):    
    # Cette partie a seulement relation avec la saison régulière (type 2) 
    """
    Télécharge les données pour des saisons de la LNH.
    :param downloader: Une instance de la classe NHLDataDownloader
    :param year: Année de début de la saison (ex. '2020')
    :param no_of_games: Nombre de matchs à télécharger pour la saison régulière (ex. 1271)
    :param game_type: '02' pour la saison régulière
    """

    for year in range(start_year, end_year + 1):
        year_str = str(year)
        downloaded_count = 0
        
        # Définir le nombre de matchs en fonction de l'année
        if year_str == '2016':
            no_of_games = 1231  # 1230 matches in 2016
        elif year_str == '2020':
            no_of_games = 869  # 868 matches in 2020 because of covid
        elif year_str in ['2017', '2018', '2019']:
            no_of_games = 1272  # Matches normaux pour ces années
        else:
            no_of_games = 1354  # Pour les années 2021 et après (32 équipes)

        #print(f"Téléchargement des données de la saison {year_str} pour {no_of_games} matchs.")

        # Boucler sur les IDs de match pour télécharger les données de la saison régulière (type 02)
        for game_number in range(1, no_of_games + 1):
            game_id = f"{year_str}02{str(game_number).zfill(4)}"  # Format de l'ID de jeu
            game_data = downloader.download_game_data(game_id=game_id)

            #Vérifier le contenu des données téléchargées
            if game_data:
                downloaded_count += 1
                #print(f"Données pour le game_id {game_id} téléchargées avec succès.")
            #else:
                #print(f"Aucune donnée disponible pour le game_id {game_id}.")
        print(f"Total de fichiers téléchargés pour la saison {year_str}: {downloaded_count}")

# %%
# Télécharger toutes les saisons de 2016 à 2023
download_all_seasons(downloader, start_year=2016, end_year=2023)
# Out:
# Fichier 2016020001.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020002.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020003.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020004.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020005.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020006.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020007.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020008.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020009.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020010.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020011.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020012.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020013.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020014.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020015.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020016.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020017.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020018.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020019.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020020.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020021.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020022.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020023.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020024.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020025.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020026.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020027.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020028.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020029.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020030.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020031.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020032.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020033.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020034.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020035.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020036.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020037.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020038.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020039.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020040.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020041.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020042.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020043.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020044.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020045.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020046.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020047.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020048.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020049.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020050.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020051.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020052.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020053.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020054.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020055.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020056.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020057.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020058.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020059.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020060.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020061.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020062.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020063.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020064.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020065.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020066.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020067.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020068.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020069.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020070.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020071.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020072.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020073.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020074.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020075.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020076.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020077.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020078.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020079.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020080.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020081.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020082.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020083.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020084.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020085.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020086.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020087.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020088.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020089.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020090.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020091.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020092.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020093.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020094.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020095.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020096.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020097.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020098.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020099.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020100.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020101.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020102.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020103.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020104.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020105.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020106.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020107.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020108.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020109.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020110.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020111.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020112.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020113.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020114.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020115.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020116.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020117.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020118.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020119.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020120.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020121.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020122.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020123.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020124.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020125.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020126.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020127.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020128.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020129.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020130.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020131.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020132.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020133.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020134.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020135.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020136.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020137.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020138.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020139.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020140.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020141.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020142.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020143.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020144.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020145.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020146.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020147.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020148.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020149.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020150.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020151.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020152.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020153.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020154.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020155.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020156.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020157.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020158.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020159.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020160.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020161.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020162.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020163.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020164.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020165.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020166.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020167.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020168.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020169.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020170.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020171.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020172.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020173.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020174.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020175.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020176.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020177.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020178.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020179.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020180.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020181.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020182.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020183.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020184.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020185.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020186.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020187.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020188.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020189.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020190.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020191.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020192.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020193.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020194.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020195.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020196.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020197.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020198.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020199.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020200.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020201.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020202.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020203.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020204.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020205.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020206.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020207.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020208.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020209.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020210.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020211.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020212.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020213.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020214.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020215.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020216.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020217.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020218.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020219.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020220.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020221.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020222.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020223.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016020224.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Fichier 2016
 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021119/play-by-play
# Erreur de téléchargement du match 2019021120: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021120/play-by-play
# Erreur de téléchargement du match 2019021121: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021121/play-by-play
# Erreur de téléchargement du match 2019021122: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021122/play-by-play
# Erreur de téléchargement du match 2019021123: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021123/play-by-play
# Erreur de téléchargement du match 2019021124: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021124/play-by-play
# Erreur de téléchargement du match 2019021125: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021125/play-by-play
# Erreur de téléchargement du match 2019021126: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021126/play-by-play
# Erreur de téléchargement du match 2019021127: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021127/play-by-play
# Erreur de téléchargement du match 2019021128: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021128/play-by-play
# Erreur de téléchargement du match 2019021129: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021129/play-by-play
# Erreur de téléchargement du match 2019021130: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021130/play-by-play
# Erreur de téléchargement du match 2019021131: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021131/play-by-play
# Erreur de téléchargement du match 2019021132: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021132/play-by-play
# Erreur de téléchargement du match 2019021133: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2019021133/play-by-play

# %% [markdown]
# #### **Playoffs**. Sauvegarde dans: _data/nhl_playoffs_

# %%
# Utilisation de la classe
downloader = NHLDataDownloader(base_dir='../data/nhl_playoffs')

def download_playoffs_data(downloader,start_year, end_year) -> None:
    """
        Fonction utilisant des appels REST calls pour télécharger les données des playoffs des saisons allant de start_year à end_year. Sauvegarde le résultat json dans le path 
        défini dans la classe NHLDataDownloader
        :param start_year: année de début de la liste écrite en 4-digits.
        :param end_year: année de fin de la liste écrite en 4-digits.
        :return: None

        """
    #Premier tour des playoffs (1/8 de finale) : 0301
    #Deuxième tour (quarts de finale) : 0302
    #Troisième tour (demi-finales) : 0303
    #Finale : 0304
       
    for year in range(start_year, end_year + 1):
        year_str = str(year)
        print(f"Téléchargement des données des playoffs pour la saison {year_str}")

        # Générer les IDs des matchs de playoffs
        playoffs = []
        # Huitièmes de finale
        playoffs.extend([f"{year_str}0301{str(matchup)}{game_number}" for matchup in range(1, 9) for game_number in range(1, 8)])
        # Quarts de finale
        playoffs.extend([f"{year_str}0302{str(matchup)}{game_number}" for matchup in range(1, 5) for game_number in range(1, 8)])   
        # Demi-finales
        playoffs.extend([f"{year_str}0303{str(matchup)}{game_number}" for matchup in range(1, 3) for game_number in range(1, 8)])   
        # Finales
        playoffs.extend([f"{year_str}0304{str(1)}{game_number}" for game_number in range(1, 8)])        
        
        # Télécharger chaque match de playoffs
        for game_id in playoffs:
            game_data = downloader.download_game_data(game_id=game_id)
            # Vérifier le contenu des données téléchargées
            if game_data:
                print(f"Données pour le game_id {game_id} téléchargées avec succès.")
            else:
                print(f"Aucune donnée disponible pour le game_id {game_id}.")

# Télécharger toutes les données des playoffs de 2016 à 2023
download_playoffs_data(downloader, start_year=2016, end_year=2023)
# Out:
# Téléchargement des données des playoffs pour la saison 2016
# Fichier 2016030111.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2016030111 téléchargées avec succès.
# Fichier 2016030112.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2016030112 téléchargées avec succès.
# Fichier 2016030113.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2016030113 téléchargées avec succès.
# Fichier 2016030114.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2016030114 téléchargées avec succès.
# Fichier 2016030115.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2016030115 téléchargées avec succès.
# Fichier 2016030116.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2016030116 téléchargées avec succès.
# Erreur de téléchargement du match 2016030117: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2016030117/play-by-play
# Aucune donnée disponible pour le game_id 2016030117.
# Fichier 2016030121.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2016
json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030311 téléchargées avec succès.
# Fichier 2023030312.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030312 téléchargées avec succès.
# Fichier 2023030313.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030313 téléchargées avec succès.
# Fichier 2023030314.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030314 téléchargées avec succès.
# Fichier 2023030315.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030315 téléchargées avec succès.
# Fichier 2023030316.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030316 téléchargées avec succès.
# Erreur de téléchargement du match 2023030317: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2023030317/play-by-play
# Aucune donnée disponible pour le game_id 2023030317.
# Fichier 2023030321.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030321 téléchargées avec succès.
# Fichier 2023030322.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030322 téléchargées avec succès.
# Fichier 2023030323.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030323 téléchargées avec succès.
# Fichier 2023030324.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030324 téléchargées avec succès.
# Fichier 2023030325.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030325 téléchargées avec succès.
# Fichier 2023030326.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030326 téléchargées avec succès.
# Erreur de téléchargement du match 2023030327: 404 Client Error: Not Found for url: https://api-web.nhle.com/v1/gamecenter/2023030327/play-by-play
# Aucune donnée disponible pour le game_id 2023030327.
# Fichier 2023030411.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030411 téléchargées avec succès.
# Fichier 2023030412.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030412 téléchargées avec succès.
# Fichier 2023030413.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030413 téléchargées avec succès.
# Fichier 2023030414.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030414 téléchargées avec succès.
# Fichier 2023030415.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030415 téléchargées avec succès.
# Fichier 2023030416.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030416 téléchargées avec succès.
# Fichier 2023030417.json déjà existant dans le répertoire ../data/nhl_playoffs.
# Données pour le game_id 2023030417 téléchargées avec succès.

# %% [markdown]
# ### 3. Fusion des deux repertoires
# _data/nhl_reguliere_ et _data/nhl_playoffs_ dans _data/nhl_data_

# %%
import os
import shutil

# Define the paths to your folders
reguliere_folder = '../data/nhl_reguliere'
playoffs_folder = '../data/nhl_playoffs'
destination_folder ='../data/nhl_data'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Function to copy files from a source folder to the destination folder
def copy_files(source_folder, destination_folder):
    # Loop through all files in the source folder
    for filename in os.listdir(source_folder):
            source_file = os.path.join(source_folder, filename)
            destination_file = os.path.join(destination_folder, filename)

            # Check if the source_file is actually a file and not a directory
            if os.path.isfile(source_file):
                # Copy the file to the destination folder
                shutil.copy(source_file, destination_file)
                print(f"Copied {filename} to {destination_folder}")
            else:
                print(f"Skipped directory: {filename}")

# Copy files from both nhl_reguliere and nhl_playoffs to nhl_data
copy_files(reguliere_folder, destination_folder)
copy_files(playoffs_folder, destination_folder)

print("All files have been copied successfully.")
# Out:
# Copied 2022020671.json to ../data/nhl_data
# Copied 2023020320.json to ../data/nhl_data
# Copied 2021020828.json to ../data/nhl_data
# Copied 2019020910.json to ../data/nhl_data
# Copied 2018020811.json to ../data/nhl_data
# Copied 2021020982.json to ../data/nhl_data
# Copied 2022020221.json to ../data/nhl_data
# Copied 2023020770.json to ../data/nhl_data
# Copied 2018020542.json to ../data/nhl_data
# Copied 2022021060.json to ../data/nhl_data
# Copied 2017020495.json to ../data/nhl_data
# Copied 2019020013.json to ../data/nhl_data
# Copied 2020020180.json to ../data/nhl_data
# Copied 2018020112.json to ../data/nhl_data
# Copied 2021020081.json to ../data/nhl_data
# Copied 2016020594.json to ../data/nhl_data
# Copied 2023021161.json to ../data/nhl_data
# Copied 2019020443.json to ../data/nhl_data
# Copied 2016020081.json to ../data/nhl_data
# Copied 2019020156.json to ../data/nhl_data
# Copied 2018020407.json to ../data/nhl_data
# Copied 2021020594.json to ../data/nhl_data
# Copied 2022021125.json to ../data/nhl_data
# Copied 2023021024.json to ../data/nhl_data
# Copied 2019020506.json to ../data/nhl_data
# Copied 2020020495.json to ../data/nhl_data
# Copied 2018020057.json to ../data/nhl_data
# Copied 2017020180.json to ../data/nhl_data
# Copied 2016020982.json to ../data/nhl_data
# Copied 2023020265.json to ../data/nhl_data
# Copied 2017020929.json to ../data/nhl_data
# Copied 2019020855.json to ../data/nhl_data
# Copied 2018021216.json to ../data/nhl_data
# Copied 2022020734.json to ../data/nhl_data
# Copied 2023020635.json to ../data/nhl_data
# Copied 2018020954.json to ../data/nhl_data
# Copied 2016020828.json to ../data/nhl_data
# Copied 2022020364.json to ../data/nhl_data
# Copied 2017020883.json to ../data/nhl_data
# Copied 2021020717.json to ../data/nhl_data
# Copied 2018020684.json to ../data/nhl_data
# Copied 2017020753.json to ../data/nhl_data
# Copied 2016020202.json to ../data/nhl_data
# Copied 2020020246.json to ../data/nhl_data
# Copied 2021020347.json to ../data/nhl_data
# Copied 2017020303.json to ../data/nhl_data
# Copied 2016020652.json to ../data/nhl_data
# Copied 2020020616.json to ../data/nhl_data
# Copied 2019020785.json to ../data/nhl_data
# Copied 2018021095.json to ../data/nhl_data
# Copied 2021021106.json to ../data/nhl_data
# Copied 2017021142.json to ../data/nhl_data
# Copied 2016021043.json to ../data/nhl_data
# Copied 2022020108.json to ../data/nhl_data
# Copied 2021021043.json to ../data/nhl_data
# Copied 2023020459.json to ../data/nhl_data
# Copied 2017021007.json to ../data/nhl_data
# Copied 2022020558.json to ../data/nhl_data
# Copied 2016021106.json to ../data/nhl_data
# Copied 2023020009.json to ../data/nhl_data
# Copied 2016020347.json to ../data/nhl_data
# Copied 2020020303.json to ../data/nhl_data
# Copied 2019020290.json to ../data/nhl_data
# Copied 2021020652.json to ../data/nhl_data
# Copied 2017020616.json to ../data/nhl_data
# Copied 2023021248.json to ../data/nhl_data
# Copied 2016020717.json to ../data/nhl_data
# Copied 2020020753.json to ../data/nhl_data
# Copied 2021020202.json to ../data/nhl_data
# Copied 2018020391.json to ../data/nhl_data
# Copied 2017020246.json to ../data/nhl_data
# Copied 2023021136.json to ../data/nhl_data
# Copied 2017020568.json to ../data/nhl_data
# Copied 2019020414.json to ../data/nhl_data
# Copied 2020020587.json to ../data/nhl_data
# Copied 2018020145.json to ../data/nhl_data
# Copied 2017020092.json to ../data/nhl_data
# Copied 2016020039.json to ../data/nhl_data
# Copied 2017020138.json to ../data/nhl_data
# Copied 2016020193.json to ../data/nhl_data
# Copied 2019020044.json to ../data/nhl_data
# Copied 2018020515.json to ../data/nhl_data
# Copied 2021020486.json to ../data/nhl_data
# Copied 2022021037.json to ../data/nhl_data
# Copied 2016020469.json to ../data/nhl_data
# Copied 2023020727.json to ../data/nhl_data
# Copied 2018020846.json to ../data/nhl_data
# Copied 2022020276.json to ../data/nhl_data
# Copied 2017020991.json to ../data/nhl_data
# Copied 2016020890.json to ../data/nhl_data
# Copied 2023020377.json to ../data/nhl_data
# Copied 2019020947.json to ../data/nhl_data
# Copied 2021021297.json to ../data/nhl_data
# Copied 2022020626.json to ../data/nhl_data
# Copied 2018020903.json to ../data/nhl_data
# Copied 2021020890.json to ../data/nhl_data
# Copied 2023020398.json to ../data/nhl_data
# Copied 2022020333.json to ../data/nhl_data
# Copied 2023020662.json to ../data/nhl_data
# Copied 2021021278.json to ../data/nhl_data
# Copied 2018021241.json to ../data/nhl_data
# Copied 2022020763.json to ../data/nhl_data
# Copied 2023020232.json to ../data/nhl_data
# Copied 2022020299.json to ../data/nhl_data
# Copied 2019020802.json to ../data/nhl_data
# Copied 2020020138.json to ../data/nhl_data
# Copied 2021020193.json to ../data/nhl_data
# Copied 2016020486.json to ../data/nhl_data
# Copied 2023021073.json to ../data/nhl_data
# Copied 2021020469.json to ../data/nhl_data
# Copied 2019020551.json to ../data/nhl_data
# Copied 2018020450.json to ../data/nhl_data
# Copied 2020020568.json to ../data/nhl_data
# Copied 2022021172.json to ../data/nhl_data
# Copied 2017020587.json to ../data/nhl_data
# Copied 2019020101.json to ../data/nhl_data
# Copied 2020020092.json to ../data/nhl_data
# Copied 2021020039.json to ../data/nhl_data
# Copied 2016021014.json to ../data/nhl_data
# Copied 2018021168.json to ../data/nhl_data
# Copied 2021021151.json to ../data/nhl_data
# Copied 2019021069.json to ../data/nhl_data
# Copied 2017021115.json to ../data/nhl_data
# Copied 2016020605.json to ../data/nhl_data
# Copied 2018020779.json to ../data/nhl_data
# Copied 2020020641.json to ../data/nhl_data
# Copied 2019020228.json to ../data/nhl_data
# Copied 2021020310.json to ../data/nhl_data
# Copied 2018020283.json to ../data/nhl_data
# Copied 2017020354.json to ../data/nhl_data
# Copied 2023020818.json to ../data/nhl_data
# Copied 2022020919.json to ../data/nhl_data
# Copied 2016020255.json to ../data/nhl_data
# Copied 2020020211.json to ../data/nhl_data
# Copied 2019020382.json to ../data/nhl_data
# Copied 2018020329.json to ../data/nhl_data
# Copied 2021020740.json to ../data/nhl_data
# Copied 2019020678.json to ../data/nhl_data
# Copied 2017020704.json to ../data/nhl_data
# Copied 2021020255.json to ../data/nhl_data
# Copied 2017020211.json to ../data/nhl_data
# Copied 2016020740.json to ../data/nhl_data
# Copied 2020020704.json to ../data/nhl_data
# Copied 2019020697.json to ../data/nhl_data
# Copied 2021020605.json to ../data/nhl_data
# Copied 2018020796.json to ../data/nhl_data
# Copied 2017020641.json to ../data/nhl_data
# Copied 2016020310.json to ../data/nhl_data
# Copied 2020020354.json to ../data/nhl_data
# Copied 2016021151.json to ../data/nhl_data
# Copied 2018021187.json to ../data/nhl_data
# Copied 2021021014.json to ../data/nhl_data
# Copied 2017021050.json to ../data/nhl_data
# Copied 2022020630.json to ../data/nhl_data
# Copied 2021021281.json to ../data/nhl_data
# Copied 2019020951.json to ../data/nhl_data
# Copied 2021020869.json to ../data/nhl_data
# Copied 2016020886.json to ../data/nhl_data
# Copied 2023020361.json to ../data/nhl_data
# Copied 2022020260.json to ../data/nhl_data
# Copied 2017020987.json to ../data/nhl_data
# Copied 2018020850.json to ../data/nhl_data
# Copied 2023020731.json to ../data/nhl_data
# Copied 2022021021.json to ../data/nhl_data
# Copied 2018020503.json to ../data/nhl_data
# Copied 2021020490.json to ../data/nhl_data
# Copied 2019020052.json to ../data/nhl_data
# Copied 2016020185.json to ../data/nhl_data
# Copied 2017020084.json to ../data/nhl_data
# Copied 2018020153.json to ../data/nhl_data
# Copied 2019020402.json to ../data/nhl_data
# Copied 2020020591.json to ../data/nhl_data
# Copied 2023021120.json to ../data/nhl_data
# Copied 2019020117.json to ../data/nhl_data
# Copied 2020020084.json to ../data/nhl_data
# Copied 2017020591.json to ../data/nhl_data
# Copied 2022021164.json to ../data/nhl_data
# Copied 2018020446.json to ../data/nhl_data
# Copied 2019020547.json to ../data/nhl_data
# Copied 2023021065.json to ../data/nhl_data
# Copied 2016020490.json to ../data/nhl_data
# Copied 2018020016.json to ../data/nhl_data
# Copied 2021020185.json to ../data/nhl_data
# Copied 2019020814.json to ../data/nhl_data
# Copied 2017020968.json to ../data/nhl_data
# Copied 2023020224.json to ../data/nhl_data
# Copied 2022020775.json to ../data/nhl_data
# Copied 2018021257.json to ../data/nhl_data
# Copied 2023020674.json to ../data/nhl_data
# Copied 2022020325.json to ../data/nhl_data
# Copied 2016020869.json to ../data/nhl_data
# Copied 2018020915.json to ../data/nhl_data
# Copied 2021020886.json to ../data/nhl_data
# Copied 2017020712.json to ../data/nhl_data
# Copied 2021020756.json to ../data/nhl_data
# Copied 2020020207.json to ../data/nhl_data
# Copied 2019020394.json to ../data/nhl_data
# Copied 2016020243.json to ../data/nhl_data
# Copied 2017020342.json to ../data/nhl_data
# Copied 2021020306.json to ../data/nhl_data
# Copied 2018020295.json to ../data/nhl_data
# Copied 2020020657.json to ../data/nhl_data
# Copied 2016020613.json to ../data/nhl_data
# Copied 2017021103.json to ../data/nhl_data
# Copied 2021021147.json to ../data/nhl_data
# Copied 2016021002.json to ../data/nhl_data
# Copied 2022020149.json to ../data/nhl_data
# Copied 2017021046.json to ../data/nhl_data
# Copied 2023020418.json to ../data/nhl_data
# Copied 2018021191.json to ../data/nhl_data
# Copied 2021021002.json to ../data/nhl_data
# Copied 2016021147.json to ../data/nhl_data
# Copied 2022020519.json to ../data/nhl_data
# Copied 2023020048.json to ../data/nhl_data
# Copied 2020020342.json to ../data/nhl_data
# Copied 2016020306.json to ../data/nhl_data
# Copied 2023021209.json to ../data/nhl_data
# Copied 2017020657.json to ../data/nhl_data
# Copied 2021020613.json to ../data/nhl_data
# Copied 2018020780.json to ../data/nhl_data
# Copied 2020020712.json to ../data/nhl_data
# Copied 2019020681.json to ../data/nhl_data
# Copied 2022021308.json to ../data/nhl_data
# Copied 2016020756.json to ../data/nhl_data
# Copied 2017020207.json to ../data/nhl_data
# Copied 2021020243.json to ../data/nhl_data
# Copied 2019020455.json to ../data/nhl_data
# Copied 2017020529.json to ../data/nhl_data
# Copied 2023021177.json to ../data/nhl_data
# Copied 2016020582.json to ../data/nhl_data
# Copied 2016020078.json to ../data/nhl_data
# Copied 2018020104.json to ../data/nhl_data
# Copied 2021020097.json to ../data/nhl_data
# Copied 2019020005.json to ../data/nhl_data
# Copied 2020020196.json to ../data/nhl_data
# Copied 2017020179.json to ../data/nhl_data
# Copied 2017020483.json to ../data/nhl_data
# Copied 2016020428.json to ../data/nhl_data
# Copied 2022021076.json to ../data/nhl_data
# Copied 2018020554.json to ../data/nhl_data
# Copied 2023020766.json to ../data/nhl_data
# Copied 2022020237.json to ../data/nhl_data
# Copied 2018020807.json to ../data/nhl_data
# Copied 2021020994.json to ../data/nhl_data
# Copied 2019020906.json to ../data/nhl_data
# Copied 2023020336.json to ../data/nhl_data
# Copied 2022020667.json to ../data/nhl_data
# Copied 2022020372.json to ../data/nhl_data
# Copied 2017020895.json to ../data/nhl_data
# Copied 2018020942.json to ../data/nhl_data
# Copied 2021021239.json to ../data/nhl_data
# Copied 2023020623.json to ../data/nhl_data
# Copied 2022020688.json to ../data/nhl_data
# Copied 2023020789.json to ../data/nhl_data
# Copied 2022020722.json to ../data/nhl_data
# Copied 2018021200.json to ../data/nhl_data
# Copied 2019020843.json to ../data/nhl_data
# Copied 2016020994.json to ../data/nhl_data
# Copied 2023020273.json to ../data/nhl_data
# Copied 2017020196.json to ../data/nhl_data
# Copied 2018020041.json to ../data/nhl_data
# Copied 2020020179.json to ../data/nhl_data
# Copied 2019020510.json to ../data/nhl_data
# Copied 2020020483.json to ../data/nhl_data
# Copied 2021020428.json to ../data/nhl_data
# Copied 2023021032.json to ../data/nhl_data
# Copied 2022021099.json to ../data/nhl_data
# Copied 2023021198.json to ../data/nhl_data
# Copied 2022021133.json to ../data/nhl_data
# Copied 2020020529.json to ../data/nhl_data
# Copied 2018020411.json to ../data/nhl_data
# Copied 2021020582.json to ../data/nhl_data
# Copied 2021020078.json to ../data/nhl_data
# Copied 2019020140.json to ../data/nhl_data
# Copied 2016020097.json to ../data/nhl_data
# Copied 2018021129.json to ../data/nhl_data
# Copied 2016021055.json to ../data/nhl_data
# Copied 2017021154.json to ../data/nhl_data
# Copied 2019021028.json to ../data/nhl_data
# Copied 2018021083.json to ../data/nhl_data
# Copied 2021021110.json to ../data/nhl_data
# Copied 2020020600.json to ../data/nhl_data
# Copied 2019020793.json to ../data/nhl_data
# Copied 2018020738.json to ../data/nhl_data
# Copied 2016020644.json to ../data/nhl_data
# Copied 2023020859.json to ../data/nhl_data
# Copied 2017020315.json to ../data/nhl_data
# Copied 2021020351.json to ../data/nhl_data
# Copied 2019020269.json to ../data/nhl_data
# Copied 2018020368.json to ../data/nhl_data
# Copied 2020020250.json to ../data/nhl_data
# Copied 2016020214.json to ../data/nhl_data
# Copied 2022020958.json to ../data/nhl_data
# Copied 2017020745.json to ../data/nhl_data
# Copied 2019020639.json to ../data/nhl_data
# Copied 2021020701.json to ../data/nhl_data
# Copied 2018020692.json to ../data/nhl_data
# Copied 2017020250.json to ../data/nhl_data
# Copied 2021020214.json to ../data/nhl_data
# Copied 2018020387.json to ../data/nhl_data
# Copied 2020020745.json to ../data/nhl_data
# Copied 2016020701.json to ../data/nhl_data
# Copied 2017020600.json to ../data/nhl_data
# Copied 2021020644.json to ../data/nhl_data
# Copied 2020020315.json to ../data/nhl_data
# Copied 2019020286.json to ../data/nhl_data
# Copied 2016020351.json to ../data/nhl_data
# Copied 2016021110.json to ../data/nhl_data
# Copied 2017021011.json to ../data/nhl_data
# Copied 2021021055.json to ../data/nhl_data
# Copied 2020020801.json to ../data/nhl_data
# Copied 2019020992.json to ../data/nhl_data
# Copied 2018020939.json to ../data/nhl_data
# Copied 2022020309.json to ../data/nhl_data
# Copied 2016020845.json to ../data/nhl_data
# Copied 2023020658.json to ../data/nhl_data
# Copied 2017021206.json to ../data/nhl_data
# Copied 2021021242.json to ../data/nhl_data
# Copied 2022020759.json to ../data/nhl_data
# Copied 2017020944.json to ../data/nhl_data
# Copied 2023020208.json to ../data/nhl_data
# Copied 2019020838.json to ../data/nhl_data
# Copied 2021020900.json to ../data/nhl_data
# Copied 2018020893.json to ../data/nhl_data
# Copied 2020020102.json to ../data/nhl_data
# Copied 2019020091.json to ../data/nhl_data
# Copied 2016020146.json to ../data/nhl_data
# Copied 2017020417.json to ../data/nhl_data
# Copied 2023021049.json to ../data/nhl_data
# Copied 2021020453.json to ../data/nhl_data
# Copied 2020020552.json to ../data/nhl_data
# Copied 2016020516.json to ../data/nhl_data
# Copied 2022021148.json to ../data/nhl_data
# Copied 2017020047.json to ../data/nhl_data
# Copied 2021020003.json to ../data/nhl_data
# Copied 2018020190.json to ../data/nhl_data
# Copied 2017020552.json to ../data/nhl_data
# Copied 2021020516.json to ../data/nhl_data
# Copied 2018020485.json to ../data/nhl_data
# Copied 2020020047.json to ../data/nhl_data
# Copied 2016020003.json to ../data/nhl_data
# Copied 2017020102.json to ../data/nhl_data
# Copied 2021020146.json to ../data/nhl_data
# Copied 2020020417.json to ../data/nhl_data
# Copied 2019020584.json to ../data/nhl_data
# Copied 2016020453.json to ../data/nhl_data
# Copied 2021021307.json to ../data/nhl_data
# Copied 2016020900.json to ../data/nhl_data
# Copied 2017020801.json to ../data/nhl_data
# Copied 2021020845.json to ../data/nhl_data
# Copied 2019020357.json to ../data/nhl_data
# Copied 2016020280.json to ../data/nhl_data
# Copied 2023020967.json to ../data/nhl_data
# Copied 2018020606.json to ../data/nhl_data
# Copied 2021020795.json to ../data/nhl_data
# Copied 2019020707.json to ../data/nhl_data
# Copied 2020020694.json to ../data/nhl_data
# Copied 2023021225.json to ../data/nhl_data
# Copied 2022020866.json to ../data/nhl_data
# Copied 2017020381.json to ../data/nhl_data
# Copied 2018020256.json to ../data/nhl_data
# Copied 2023020064.json to ../data/nhl_data
# Copied 2022020535.json to ../data/nhl_data
# Copied 2021021184.json to ../data/nhl_data
# Copied 2018021017.json to ../data/nhl_data
# Copied 2023020434.json to ../data/nhl_data
# Copied 2022020165.json to ../data/nhl_data
# Copied 2017021085.json to ../data/nhl_data
# Copied 2022020470.json to ../data/nhl_data
# Copied 2018021152.json to ../data/nhl_data
# Copied 2023020121.json to ../data/nhl_data
# Copied 2022020020.json to ../data/nhl_data
# Copied 2019021053.json to ../data/nhl_data
# Copied 2023020571.json to ../data/nhl_data
# Copied 2016021184.json to ../data/nhl_data
# Copied 2017020694.json to ../data/nhl_data
# Copied 2022021261.json to ../data/nhl_data
# Copied 2018020743.json to ../data/nhl_data
# Copied 2019020212.json to ../data/nhl_data
# Copied 2020020381.json to ../data/nhl_data
# Copied 2023020822.json to ../data/nhl_data
# Copied 2022020889.json to ../data/nhl_data
# Copied 2023020988.json to ../data/nhl_data
# Copied 2022020923.json to ../data/nhl_data
# Copied 2018020313.json to ../data/nhl_data
# Copied 2021020280.json to ../data/nhl_data
# Copied 2019020642.json to ../data/nhl_data
# Copied 2016020795.json to ../data/nhl_data
# Copied 2017020010.json to ../data/nhl_data
# Copied 2021020054.json to ../data/nhl_data
# Copied 2020020505.json to ../data/nhl_data
# Copied 2019020496.json to ../data/nhl_data
# Copied 2016020541.json to ../data/nhl_data
# Copied 2017020440.json to ../data/nhl_data
# Copied 2021020404.json to ../data/nhl_data
# Copied 2018020597.json to ../data/nhl_data
# Copied 2020020155.json to ../data/nhl_data
# Copied 2016020111.json to ../data/nhl_data
# Copied 2017020913.json to ../data/nhl_data
# Copied 2021020957.json to ../data/nhl_data
# Copied 2017021251.json to ../data/nhl_data
# Copied 2021021215.json to ../data/nhl_data
# Copied 2020020856.json to ../data/nhl_data
# Copied 2016020812.json to ../data/nhl_data
# Copied 2016021215.json to ../data/nhl_data
# Copied 2017020856.json to ../data/nhl_data
# Copied 2021020812.json to ../data/nhl_data
# Copied 2018020981.json to ../data/nhl_data
# Copied 2019020880.json to ../data/nhl_data
# Copied 2016020957.json to ../data/nhl_data
# Copied 2020020440.json to ../data/nhl_data
# Copied 2018020578.json to ../data/nhl_data
# Copied 2016020404.json to ../data/nhl_data
# Copied 2017020155.json to ../data/nhl_data
# Copied 2021020111.json to ../data/nhl_data
# Copied 2018020082.json to ../data/nhl_data
# Copied 2019020029.json to ../data/nhl_data
# Copied 2018020128.json to ../data/nhl_data
# Copied 2020020010.json to ../data/nhl_data
# Copied 2019020183.json to ../data/nhl_data
# Copied 2016020054.json to ../data/nhl_data
# Copied 2017020505.json to ../data/nhl_data
# Copied 2019020479.json to ../data/nhl_data
# Copied 2021020541.json to ../data/nhl_data
# Copied 2022020132.json to ../data/nhl_data
# Copied 2023020199.json to ../data/nhl_data
# Copied 2021021079.json to ../data/nhl_data
# Copied 2023020463.json to ../data/nhl_data
# Copied 2016021096.json to ../data/nhl_data
# Copied 2017021197.json to ../data/nhl_data
# Copied 2022020562.json to ../data/nhl_data
# Copied 2018021040.json to ../data/nhl_data
# Copied 2022020098.json to ../data/nhl_data
# Copied 2023020033.json to ../data/nhl_data
# Copied 2022020831.json to ../data/nhl_data
# Copied 2018020201.json to ../data/nhl_data
# Copied 2021020392.json to ../data/nhl_data
# Copied 2020020339.json to ../data/nhl_data
# Copied 2019020750.json to ../data/nhl_data
# Copied 2021020668.json to ../data/nhl_data
# Copied 2023021272.json to ../data/nhl_data
# Copied 2016020687.json to ../data/nhl_data
# Copied 2017020786.json to ../data/nhl_data
# Copied 2020020769.json to ../data/nhl_data
# Copied 2018020651.json to ../data/nhl_data
# Copied 2021020238.json to ../data/nhl_data
# Copied 2019020300.json to ../data/nhl_data
# Copied 2020020293.json to ../data/nhl_data
# Copied 2023020930.json to ../data/nhl_data
# Copied 2019020615.json to ../data/nhl_data
# Copied 2020020786.json to ../data/nhl_data
# Copied 2017020769.json to ../data/nhl_data
# Copied 2016020238.json to ../data/nhl_data
# Copied 2022020974.json to ../data/nhl_data
# Copied 2017020293.json to ../data/nhl_data
# Copied 2018020344.json to ../data/nhl_data
# Copied 2019020245.json to ../data/nhl_data
# Copied 2016020392.json to ../data/nhl_data
# Copied 2023020875.json to ../data/nhl_data
# Copied 2017020339.json to ../data/nhl_data
# Copied 2022021236.json to ../data/nhl_data
# Copied 2016020668.json to ../data/nhl_data
# Copied 2018020714.json to ../data/nhl_data
# Copied 2021020687.json to ../data/nhl_data
# Copied 2019021004.json to ../data/nhl_data
# Copied 2017021178.json to ../data/nhl_data
# Copied 2023020526.json to ../data/nhl_data
# Copied 2022020077.json to ../data/nhl_data
# Copied 2023020176.json to ../data/nhl_data
# Copied 2016021079.json to ../data/nhl_data
# Copied 2022020427.json to ../data/nhl_data
# Copied 2021021096.json to ../data/nhl_data
# Copied 2018021105.json to ../data/nhl_data
# Copied 2016020804.json to ../data/nhl_data
# Copied 2022020348.json to ../data/nhl_data
# Copied 2018020978.json to ../data/nhl_data
# Copied 2020020840.json to ../data/nhl_data
# Copied 2021021203.json to ../data/nhl_data
# Copied 2017021247.json to ../data/nhl_data
# Copied 2023020619.json to ../data/nhl_data
# Copied 2022020718.json to ../data/nhl_data
# Copied 2021020941.json to ../data/nhl_data
# Copied 2019020879.json to ../data/nhl_data
# Copied 2023020249.json to ../data/nhl_data
# Copied 2017020905.json to ../data/nhl_data
# Copied 2016020107.json to ../data/nhl_data
# Copied 2020020143.json to ../data/nhl_data
# Copied 2021020412.json to ../data/nhl_data
# Copied 2018020581.json to ../data/nhl_data
# Copied 2023021008.json to ../data/nhl_data
# Copied 2017020456.json to ../data/nhl_data
# Copied 2022021109.json to ../data/nhl_data
# Copied 2016020557.json to ../data/nhl_data
# Copied 2020020513.json to ../data/nhl_data
# Copied 2019020480.json to ../data/nhl_data
# Copied 2021020042.json to ../data/nhl_data
# Copied 2017020006.json to ../data/nhl_data
# Copied 2021020557.json to ../data/nhl_data
# Copied 2017020513.json to ../data/nhl_data
# Copied 2016020042.json to ../data/nhl_data
# Copied 2020020006.json to ../data/nhl_data
# Copied 2019020195.json to ../data/nhl_data
# Copied 2021020107.json to ../data/nhl_data
# Copied 2018020094.json to ../data/nhl_data
# Copied 2017020143.json to ../data/nhl_data
# Copied 2016020412.json to ../data/nhl_data
# Copied 2020020456.json to ../data/nhl_data
# Copied 2016020941.json to ../data/nhl_data
# Copied 2019020896.json to ../data/nhl_data
# Copied 2021020804.json to ../data/nhl_data
# Copied 2018020997.json to ../data/nhl_data
# Copied 2017020840.json to ../data/nhl_data
# Copied 2016021203.json to ../data/nhl_data
# Copied 2023020926.json to ../data/nhl_data
# Copied 2019020316.json to ../data/nhl_data
# Copied 2020020285.json to ../data/nhl_data
# Copied 2018020647.json to ../data/nhl_data
# Copied 2017020790.json to ../data/nhl_data
# Copied 2016020691.json to ../data/nhl_data
# Copied 2023021264.json to ../data/nhl_data
# Copied 2019020746.json to ../data/nhl_data
# Copied 2018020217.json to ../data/nhl_data
# Copied 2021020384.json to ../data/nhl_data
# Copied 2022020827.json to ../data/nhl_data
# Copied 2023020025.json to ../data/nhl_data
# Copied 2018021056.json to ../data/nhl_data
# Copied 2022020574.json to ../data/nhl_data
# Copied 2017021181.json to ../data/nhl_data
# Copied 2016021080.json to ../data/nhl_data
# Copied 2023020475.json to ../data/nhl_data
# Copied 2022020124.json to ../data/nhl_data
# Copied 2021021080.json to ../data/nhl_data
# Copied 2018021113.json to ../data/nhl_data
# Copied 2022020431.json to ../data/nhl_data
# Copied 2023020160.json to ../data/nhl_data
# Copied 2022020061.json to ../data/nhl_data
# Copied 2023020530.json to ../data/nhl_data
# Copied 2019021012.json to ../data/nhl_data
# Copied 2018020702.json to ../data/nhl_data
# Copied 2021020691.json to ../data/nhl_data
# Copied 2022021220.json to ../data/nhl_data
# Copied 2016020384.json to ../data/nhl_data
# Copied 2023020863.json to ../data/nhl_data
# Copied 2019020253.json to ../data/nhl_data
# Copied 2018020352.json to ../data/nhl_data
# Copied 2022020962.json to ../data/nhl_data
# Copied 2017020285.json to ../data/nhl_data
# Copied 2019020603.json to ../data/nhl_data
# Copied 2020020790.json to ../data/nhl_data
# Copied 2021020015.json to ../data/nhl_data
# Copied 2018020186.json to ../data/nhl_data
# Copied 2017020051.json to ../data/nhl_data
# Copied 2016020500.json to ../data/nhl_data
# Copied 2020020544.json to ../data/nhl_data
# Copied 2021020445.json to ../data/nhl_data
# Copied 2017020401.json to ../data/nhl_data
# Copied 2016020150.json to ../data/nhl_data
# Copied 2020020114.json to ../data/nhl_data
# Copied 2019020087.json to ../data/nhl_data
# Copied 2021020916.json to ../data/nhl_data
# Copied 2018020885.json to ../data/nhl_data
# Copied 2017020952.json to ../data/nhl_data
# Copied 2021021254.json to ../data/nhl_data
# Copied 2017021210.json to ../data/nhl_data
# Copied 2016020853.json to ../data/nhl_data
# Copied 2020020817.json to ../data/nhl_data
# Copied 2019020984.json to ../data/nhl_data
# Copied 2021020853.json to ../data/nhl_data
# Copied 2017020817.json to ../data/nhl_data
# Copied 2016020916.json to ../data/nhl_data
# Copied 2021021311.json to ../data/nhl_data
# Copied 2016020445.json to ../data/nhl_data
# Copied 2018020539.json to ../data/nhl_data
# Copied 2020020401.json to ../data/nhl_data
# Copied 2019020592.json to ../data/nhl_data
# Copied 2019020068.json to ../data/nhl_data
# Copied 2021020150.json to ../data/nhl_data
# Copied 2017020114.json to ../data/nhl_data
# Copied 2016020015.json to ../data/nhl_data
# Copied 2020020051.json to ../data/nhl_data
# Copied 2018020169.json to ../data/nhl_data
# Copied 2021020500.json to ../data/nhl_data
# Copied 2018020493.json to ../data/nhl_data
# Copied 2019020438.json to ../data/nhl_data
# Copied 2017020544.json to ../data/nhl_data
# Copied 2022020173.json to ../data/nhl_data
# Copied 2022020489.json to ../data/nhl_data
# Copied 2023020422.json to ../data/nhl_data
# Copied 2021021038.json to ../data/nhl_data
# Copied 2021021192.json to ../data/nhl_data
# Copied 2018021001.json to ../data/nhl_data
# Copied 2022020523.json to ../data/nhl_data
# Copied 2023020588.json to ../data/nhl_data
# Copied 2023020072.json to ../data/nhl_data
# Copied 2020020378.json to ../data/nhl_data
# Copied 2018020240.json to ../data/nhl_data
# Copied 2022020870.json to ../data/nhl_data
# Copied 2017020397.json to ../data/nhl_data
# Copied 2022021298.json to ../data/nhl_data
# Copied 2023021233.json to ../data/nhl_data
# Copied 2021020629.json to ../data/nhl_data
# Copied 2019020711.json to ../data/nhl_data
# Copied 2020020682.json to ../data/nhl_data
# Copied 2018020610.json to ../data/nhl_data
# Copied 2021020783.json to ../data/nhl_data
# Copied 2020020728.json to ../data/nhl_data
# Copied 2016020296.json to ../data/nhl_data
# Copied 2023020971.json to ../data/nhl_data
# Copied 2019020341.json to ../data/nhl_data
# Copied 2021020279.json to ../data/nhl_data
# Copied 2016020783.json to ../data/nhl_data
# Copied 2017020728.json to ../data/nhl_data
# Copied 2019020654.json to ../data/nhl_data
# Copied 2018020305.json to ../data/nhl_data
# Copied 2021020296.json to ../data/nhl_data
# Copied 2022020935.json to ../data/nhl_data
# Copied 2016020279.json to ../data/nhl_data
# Copied 2017020378.json to ../data/nhl_data
# Copied 2023020834.json to ../data/nhl_data
# Copied 2019020204.json to ../data/nhl_data
# Copied 2020020397.json to ../data/nhl_data
# Copied 2018020755.json to ../data/nhl_data
# Copied 2016020629.json to ../data/nhl_data
# Copied 2022021277.json to ../data/nhl_data
# Copied 2017020682.json to ../data/nhl_data
# Copied 2016021192.json to ../data/nhl_data
# Copied 2023020567.json to ../data/nhl_data
# Copied 2017021139.json to ../data/nhl_data
# Copied 2019021045.json to ../data/nhl_data
# Copied 2022020036.json to ../data/nhl_data
# Copied 2023020137.json to ../data/nhl_data
# Copied 2018021144.json to ../data/nhl_data
# Copied 2022020466.json to ../data/nhl_data
# Copied 2016021038.json to ../data/nhl_data
# Copied 2017021093.json to ../data/nhl_data
# Copied 2018021133.json to ../data/nhl_data
# Copied 2022020411.json to ../data/nhl_data
# Copied 2023020140.json to ../data/nhl_data
# Copied 2022020041.json to ../data/nhl_data
# Copied 2023020510.json to ../data/nhl_data
# Copied 2018021099.json to ../data/nhl_data
# Copied 2019021032.json to ../data/nhl_data
# Copied 2018020722.json to ../data/nhl_data
# Copied 2019020789.json to ../data/nhl_data
# Copied 2022021200.json to ../data/nhl_data
# Copied 2023020843.json to ../data/nhl_data
# Copied 2019020273.json to ../data/nhl_data
# Copied 2018020372.json to ../data/nhl_data
# Copied 2022020942.json to ../data/nhl_data
# Copied 2023021301.json to ../data/nhl_data
# Copied 2018020688.json to ../data/nhl_data
# Copied 2019020623.json to ../data/nhl_data
# Copied 2023020906.json to ../data/nhl_data
# Copied 2019020336.json to ../data/nhl_data
# Copied 2018020667.json to ../data/nhl_data
# Copied 2023021244.json to ../data/nhl_data
# Copied 2019020766.json to ../data/nhl_data
# Copied 2018020237.json to ../data/nhl_data
# Copied 2022020807.json to ../data/nhl_data
# Copied 2023020005.json to ../data/nhl_data
# Copied 2018021076.json to ../data/nhl_data
# Copied 2022020554.json to ../data/nhl_data
# Copied 2023020455.json to ../data/nhl_data
# Copied 2022020104.json to ../data/nhl_data
# Copied 2021020577.json to ../data/nhl_data
# Copied 2016020598.json to ../data/nhl_data
# Copied 2017020533.json to ../data/nhl_data
# Copied 2016020062.json to ../data/nhl_data
# Copied 2020020026.json to ../data/nhl_data
# Copied 2021020127.json to ../data/nhl_data
# Copied 2017020163.json to ../data/nhl_data
# Copied 2016020432.json to ../data/nhl_data
# Copied 2017020499.json to ../data/nhl_data
# Copied 2020020476.json to ../data/nhl_data
# Copied 2023020286.json to ../data/nhl_data
# Copied 2016020961.json to ../data/nhl_data
# Copied 2021020824.json to ../data/nhl_data
# Copied 2017020860.json to ../data/nhl_data
# Copied 2022020387.json to ../data/nhl_data
# Copied 2016021223.json to ../data/nhl_data
# Copied 2016020824.json to ../data/nhl_data
# Copied 2022020368.json to ../data/nhl_data
# Copied 2018020958.json to ../data/nhl_data
# Copied 2020020860.json to ../data/nhl_data
# Copied 2021021223.json to ../data/nhl_data
# Copied 2022020692.json to ../data/nhl_data
# Copied 2023020639.json to ../data/nhl_data
# Copied 2017021267.json to ../data/nhl_data
# Copied 2022020738.json to ../data/nhl_data
# Copied 2023020793.json to ../data/nhl_data
# Copied 2021020961.json to ../data/nhl_data
# Copied 2019020859.json to ../data/nhl_data
# Copied 2023020269.json to ../data/nhl_data
# Copied 2017020925.json to ../data/nhl_data
# Copied 2016020127.json to ../data/nhl_data
# Copied 2020020163.json to ../data/nhl_data
# Copied 2021020432.json to ../data/nhl_data
# Copied 2020020499.json to ../data/nhl_data
# Copied 2022021083.json to ../data/nhl_data
# Copied 2017020476.json to ../data/nhl_data
# Copied 2023021028.json to ../data/nhl_data
# Copied 2016020577.json to ../data/nhl_data
# Copied 2022021129.json to ../data/nhl_data
# Copied 2023021182.json to ../data/nhl_data
# Copied 2021020598.json to ../data/nhl_data
# Copied 2020020533.json to ../data/nhl_data
# Copied 2021020062.json to ../data/nhl_data
# Copied 2017020026.json to ../data/nhl_data
# Copied 2017020708.json to ../data/nhl_data
# Copied 2019020674.json to ../data/nhl_data
# Copied 2018020325.json to ../data/nhl_data
# Copied 2022020915.json to ../data/nhl_data
# Copied 2016020259.json to ../data/nhl_data
# Copied 2017020358.json to ../data/nhl_data
# Copied 2023020814.json to ../data/nhl_data
# Copied 2019020224.json to ../data/nhl_data
# Copied 2018020775.json to ../data/nhl_data
# Copied 2022021257.json to ../data/nhl_data
# Copied 2016020609.json to ../data/nhl_data
# Copied 2017021119.json to ../data/nhl_data
# Copied 2023020547.json to ../data/nhl_data
# Copied 2019021065.json to ../data/nhl_data
# Copied 2022020016.json to ../data/nhl_data
# Copied 2023020117.json to ../data/nhl_data
# Copied 2018021164.json to ../data/nhl_data
# Copied 2016021018.json to ../data/nhl_data
# Copied 2022020446.json to ../data/nhl_data
# Copied 2022020153.json to ../data/nhl_data
# Copied 2023020402.json to ../data/nhl_data
# Copied 2021021018.json to ../data/nhl_data
# Copied 2018021021.json to ../data/nhl_data
# Copied 2022020503.json to ../data/nhl_data
# Copied 2023020052.json to ../data/nhl_data
# Copied 2020020358.json to ../data/nhl_data
# Copied 2018020260.json to ../data/nhl_data
# Copied 2022020850.json to ../data/nhl_data
# Copied 2023021213.json to ../data/nhl_data
# Copied 2021020609.json to ../data/nhl_data
# Copied 2019020731.json to ../data/nhl_data
# Copied 2018020630.json to ../data/nhl_data
# Copied 2020020708.json to ../data/nhl_data
# Copied 2022021312.json to ../data/nhl_data
# Copied 2023020951.json to ../data/nhl_data
# Copied 2019020361.json to ../data/nhl_data
# Copied 2021020259.json to ../data/nhl_data
# Copied 2023020681.json to ../data/nhl_data
# Copied 2021020873.json to ../data/nhl_data
# Copied 2017020837.json to ../data/nhl_data
# Copied 2016020936.json to ../data/nhl_data
# Copied 2022020780.json to ../data/nhl_data
# Copied 2016020465.json to ../data/nhl_data
# Copied 2023021090.json to ../data/nhl_data
# Copied 2018020519.json to ../data/nhl_data
# Copied 2020020421.json to ../data/nhl_data
# Copied 2019020048.json to ../data/nhl_data
# Copied 2021020170.json to ../data/nhl_data
# Copied 2017020134.json to ../data/nhl_data
# Copied 2016020035.json to ../data/nhl_data
# Copied 2020020071.json to ../data/nhl_data
# Copied 2018020149.json to ../data/nhl_data
# Copied 2021020520.json to ../data/nhl_data
# Copied 2019020418.json to ../data/nhl_data
# Copied 2022021191.json to ../data/nhl_data
# Copied 2017020564.json to ../data/nhl_data
# Copied 2021020035.json to ../data/nhl_data
# Copied 2017020071.json to ../data/nhl_data
# Copied 2016020520.json to ../data/nhl_data
# Copied 2020020564.json to ../data/nhl_data
# Copied 2021020465.json to ../data/nhl_data
# Copied 2017020421.json to ../data/nhl_data
# Copied 2016020170.json to ../data/nhl_data
# Copied 2020020134.json to ../data/nhl_data
# Copied 2021020936.json to ../data/nhl_data
# Copied 2017020972.json to ../data/nhl_data
# Copied 2022020295.json to ../data/nhl_data
# Copied 2021021274.json to ../data/nhl_data
# Copied 2017021230.json to ../data/nhl_data
# Copied 2023020394.json to ../data/nhl_data
# Copied 2016020873.json to ../data/nhl_data
# Copied 2020020837.json to ../data/nhl_data
# Copied 2022020450.json to ../data/nhl_data
# Copied 2018021172.json to ../data/nhl_data
# Copied 2023020101.json to ../data/nhl_data
# Copied 2019021073.json to ../data/nhl_data
# Copied 2023020551.json to ../data/nhl_data
# Copied 2022021241.json to ../data/nhl_data
# Copied 2018020763.json to ../data/nhl_data
# Copied 2018020299.json to ../data/nhl_data
# Copied 2019020232.json to ../data/nhl_data
# Copied 2023020802.json to ../data/nhl_data
# Copied 2022020903.json to ../data/nhl_data
# Copied 2018020333.json to ../data/nhl_data
# Copied 2019020398.json to ../data/nhl_data
# Copied 2019020662.json to ../data/nhl_data
# Copied 2019020377.json to ../data/nhl_data
# Copied 2023020947.json to ../data/nhl_data
# Copied 2022021304.json to ../data/nhl_data
# Copied 2018020626.json to ../data/nhl_data
# Copied 2019020727.json to ../data/nhl_data
# Copied 2023021205.json to ../data/nhl_data
# Copied 2022020846.json to ../data/nhl_data
# Copied 2018020276.json to ../data/nhl_data
# Copied 2023020044.json to ../data/nhl_data
# Copied 2022020515.json to ../data/nhl_data
# Copied 2018021037.json to ../data/nhl_data
# Copied 2023020414.json to ../data/nhl_data
# Copied 2022020145.json to ../data/nhl_data
# Copied 2017020572.json to ../data/nhl_data
# Copied 2022021187.json to ../data/nhl_data
# Copied 2021020536.json to ../data/nhl_data
# Copied 2020020067.json to ../data/nhl_data
# Copied 2016020023.json to ../data/nhl_data
# Copied 2017020088.json to ../data/nhl_data
# Copied 2016020189.json to ../data/nhl_data
# Copied 2017020122.json to ../data/nhl_data
# Copied 2021020166.json to ../data/nhl_data
# Copied 2020020437.json to ../data/nhl_data
# Copied 2023021086.json to ../data/nhl_data
# Copied 2016020473.json to ../data/nhl_data
# Copied 2022020796.json to ../data/nhl_data
# Copied 2016020920.json to ../data/nhl_data
# Copied 2017020821.json to ../data/nhl_data
# Copied 2021020865.json to ../data/nhl_data
# Copied 2023020697.json to ../data/nhl_data
# Copied 2020020821.json to ../data/nhl_data
# Copied 2018020919.json to ../data/nhl_data
# Copied 2022020329.json to ../data/nhl_data
# Copied 2023020382.json to ../data/nhl_data
# Copied 2016020865.json to ../data/nhl_data
# Copied 2017021226.json to ../data/nhl_data
# Copied 2023020678.json to ../data/nhl_data
# Copied 2021021262.json to ../data/nhl_data
# Copied 2022020779.json to ../data/nhl_data
# Copied 2017020964.json to ../data/nhl_data
# Copied 2022020283.json to ../data/nhl_data
# Copied 2023020228.json to ../data/nhl_data
# Copied 2019020818.json to ../data/nhl_data
# Copied 2021020920.json to ../data/nhl_data
# Copied 2021020189.json to ../data/nhl_data
# Copied 2020020122.json to ../data/nhl_data
# Copied 2016020166.json to ../data/nhl_data
# Copied 2023021069.json to ../data/nhl_data
# Copied 2017020437.json to ../data/nhl_data
# Copied 2021020473.json to ../data/nhl_data
# Copied 2020020572.json to ../data/nhl_data
# Copied 2022021168.json to ../data/nhl_data
# Copied 2016020536.json to ../data/nhl_data
# Copied 2017020067.json to ../data/nhl_data
# Copied 2021020023.json to ../data/nhl_data
# Copied 2020020088.json to ../data/nhl_data
# Copied 2019020635.json to ../data/nhl_data
# Copied 2017020749.json to ../data/nhl_data
# Copied 2016020218.json to ../data/nhl_data
# Copied 2022020954.json to ../data/nhl_data
# Copied 2018020364.json to ../data/nhl_data
# Copied 2019020265.json to ../data/nhl_data
# Copied 2023020855.json to ../data/nhl_data
# Copied 2017020319.json to ../data/nhl_data
# Copied 2016020648.json to ../data/nhl_data
# Copied 2022021216.json to ../data/nhl_data
# Copied 2018020734.json to ../data/nhl_data
# Copied 2019021024.json to ../data/nhl_data
# Copied 2023020506.json to ../data/nhl_data
# Copied 2017021158.json to ../data/nhl_data
# Copied 2022020057.json to ../data/nhl_data
# Copied 2023020156.json to ../data/nhl_data
# Copied 2022020407.json to ../data/nhl_data
# Copied 2016021059.json to ../data/nhl_data
# Copied 2018021125.json to ../data/nhl_data
# Copied 2022020112.json to ../data/nhl_data
# Copied 2021021059.json to ../data/nhl_data
# Copied 2023020443.json to ../data/nhl_data
# Copied 2022020542.json to ../data/nhl_data
# Copied 2018021060.json to ../data/nhl_data
# Copied 2023020013.json to ../data/nhl_data
# Copied 2022020811.json to ../data/nhl_data
# Copied 2018020221.json to ../data/nhl_data
# Copied 2020020319.json to ../data/nhl_data
# Copied 2019020770.json to ../data/nhl_data
# Copied 2021020648.json to ../data/nhl_data
# Copied 2023021252.json to ../data/nhl_data
# Copied 2020020749.json to ../data/nhl_data
# Copied 2018020671.json to ../data/nhl_data
# Copied 2021020218.json to ../data/nhl_data
# Copied 2019020320.json to ../data/nhl_data
# Copied 2023020910.json to ../data/nhl_data
# Copied 2017020876.json to ../data/nhl_data
# Copied 2022020391.json to ../data/nhl_data
# Copied 2021020832.json to ../data/nhl_data
# Copied 2021020998.json to ../data/nhl_data
# Copied 2023020290.json to ../data/nhl_data
# Copied 2016020977.json to ../data/nhl_data
# Copied 2020020460.json to ../data/nhl_data
# Copied 2018020558.json to ../data/nhl_data
# Copied 2016020424.json to ../data/nhl_data
# Copied 2017020175.json to ../data/nhl_data
# Copied 2021020131.json to ../data/nhl_data
# Copied 2019020009.json to ../data/nhl_data
# Copied 2018020108.json to ../data/nhl_data
# Copied 2020020030.json to ../data/nhl_data
# Copied 2016020074.json to ../data/nhl_data
# Copied 2017020525.json to ../data/nhl_data
# Copied 2019020459.json to ../data/nhl_data
# Copied 2021020561.json to ../data/nhl_data
# Copied 2017020030.json to ../data/nhl_data
# Copied 2021020074.json to ../data/nhl_data
# Copied 2020020525.json to ../data/nhl_data
# Copied 2023021194.json to ../data/nhl_data
# Copied 2016020561.json to ../data/nhl_data
# Copied 2017020460.json to ../data/nhl_data
# Copied 2022021095.json to ../data/nhl_data
# Copied 2021020424.json to ../data/nhl_data
# Copied 2020020175.json to ../data/nhl_data
# Copied 2016020131.json to ../data/nhl_data
# Copied 2017020933.json to ../data/nhl_data
# Copied 2016020998.json to ../data/nhl_data
# Copied 2021020977.json to ../data/nhl_data
# Copied 2023020785.json to ../data/nhl_data
# Copied 2017021271.json to ../data/nhl_data
# Copied 2022020684.json to ../data/nhl_data
# Copied 2021021235.json to ../data/nhl_data
# Copied 2017020899.json to ../data/nhl_data
# Copied 2016020832.json to ../data/nhl_data
# Copied 2022020169.json to ../data/nhl_data
# Copied 2023020438.json to ../data/nhl_data
# Copied 2017021066.json to ../data/nhl_data
# Copied 2022020493.json to ../data/nhl_data
# Copied 2021021022.json to ../data/nhl_data
# Copied 2021021188.json to ../data/nhl_data
# Copied 2023020592.json to ../data/nhl_data
# Copied 2022020539.json to ../data/nhl_data
# Copied 2016021167.json to ../data/nhl_data
# Copied 2023020068.json to ../data/nhl_data
# Copied 2020020362.json to ../data/nhl_data
# Copied 2016020326.json to ../data/nhl_data
# Copied 2017020677.json to ../data/nhl_data
# Copied 2023021229.json to ../data/nhl_data
# Copied 2022021282.json to ../data/nhl_data
# Copied 2020020698.json to ../data/nhl_data
# Copied 2021020633.json to ../data/nhl_data
# Copied 2020020732.json to ../data/nhl_data
# Copied 2021020799.json to ../data/nhl_data
# Copied 2016020776.json to ../data/nhl_data
# Copied 2017020227.json to ../data/nhl_data
# Copied 2021020263.json to ../data/nhl_data
# Copied 2017020732.json to ../data/nhl_data
# Copied 2016020799.json to ../data/nhl_data
# Copied 2021020776.json to ../data/nhl_data
# Copied 2020020227.json to ../data/nhl_data
# Copied 2023020984.json to ../data/nhl_data
# Copied 2016020263.json to ../data/nhl_data
# Copied 2017020362.json to ../data/nhl_data
# Copied 2022020885.json to ../data/nhl_data
# Copied 2021020326.json to ../data/nhl_data
# Copied 2020020677.json to ../data/nhl_data
# Copied 2017020698.json to ../data/nhl_data
# Copied 2016020633.json to ../data/nhl_data
# Copied 2017021123.json to ../data/nhl_data
# Copied 2016021188.json to ../data/nhl_data
# Copied 2021021167.json to ../data/nhl_data
# Copied 2023020087.json to ../data/nhl_data
# Copied 2022020186.json to ../data/nhl_data
# Copied 2017021089.json to ../data/nhl_data
# Copied 2016021022.json to ../data/nhl_data
# Copied 2019020137.json to ../data/nhl_data
# Copied 2022021144.json to ../data/nhl_data
# Copied 2018020466.json to ../data/nhl_data
# Copied 2019020567.json to ../data/nhl_data
# Copied 2023021045.json to ../data/nhl_data
# Copied 2018020036.json to ../data/nhl_data
# Copied 2019020834.json to ../data/nhl_data
# Copied 2017020948.json to ../data/nhl_data
# Copied 2023020204.json to ../data/nhl_data
# Copied 2022020755.json to ../data/nhl_data
# Copied 2023020654.json to ../data/nhl_data
# Copied 2022020305.json to ../data/nhl_data
# Copied 2016020849.json to ../data/nhl_data
# Copied 2018020935.json to ../data/nhl_data
# Copied 2022020610.json to ../data/nhl_data
# Copied 2019020971.json to ../data/nhl_data
# Copied 2021020849.json to ../data/nhl_data
# Copied 2023020341.json to ../data/nhl_data
# Copied 2022020240.json to ../data/nhl_data
# Copied 2018020870.json to ../data/nhl_data
# Copied 2023020711.json to ../data/nhl_data
# Copied 2022021001.json to ../data/nhl_data
# Copied 2019020588.json to ../data/nhl_data
# Copied 2018020523.json to ../data/nhl_data
# Copied 2019020072.json to ../data/nhl_data
# Copied 2018020173.json to ../data/nhl_data
# Copied 2019020422.json to ../data/nhl_data
# Copied 2018020489.json to ../data/nhl_data
# Copied 2023021100.json to ../data/nhl_data
# Copied 2017020270.json to ../data/nhl_data
# Copied 2022020997.json to ../data/nhl_data
# Copied 2021020234.json to ../data/nhl_data
# Copied 2020020765.json to ../data/nhl_data
# Copied 2016020721.json to ../data/nhl_data
# Copied 2017020620.json to ../data/nhl_data
# Copied 2021020664.json to ../data/nhl_data
# Copied 2020020335.json to ../data/nhl_data
# Copied 2023020896.json to ../data/nhl_data
# Copied 2016020371.json to ../data/nhl_data
# Copied 2022020094.json to ../data/nhl_data
# Copied 2016021130.json to ../data/nhl_data
# Copied 2017021031.json to ../data/nhl_data
# Copied 2021021075.json to ../data/nhl_data
# Copied 2023020195.json to ../data/nhl_data
# Copied 2018021109.json to ../data/nhl_data
# Copied 2023020480.json to ../data/nhl_data
# Copied 2016021075.json to ../data/nhl_data
# Copied 2017021174.json to ../data/nhl_data
# Copied 2022020581.json to ../data/nhl_data
# Copied 2019021008.json to ../data/nhl_data
# Copied 2021021130.json to ../data/nhl_data
# Copied 2020020620.json to ../data/nhl_data
# Copied 2018020718.json to ../data/nhl_data
# Copied 2023021291.json to ../data/nhl_data
# Copied 2016020664.json to ../data/nhl_data
# Copied 2023020879.json to ../data/nhl_data
# Copied 2017020335.json to ../data/nhl_data
# Copied 2021020371.json to ../data/nhl_data
# Copied 2019020249.json to ../data/nhl_data
# Copied 2018020348.json to ../data/nhl_data
# Copied 2020020270.json to ../data/nhl_data
# Copied 2016020234.json to ../data/nhl_data
# Copied 2022020978.json to ../data/nhl_data
# Copied 2017020765.json to ../data/nhl_data
# Copied 2019020619.json to ../data/nhl_data
# Copied 2021020721.json to ../data/nhl_data
# Copied 2022020352.json to ../data/nhl_data
# Copied 2018020962.json to ../data/nhl_data
# Copied 2021021219.json to ../data/nhl_data
# Copied 2023020603.json to ../data/nhl_data
# Copied 2022020702.json to ../data/nhl_data
# Copied 2018021220.json to ../data/nhl_data
# Copied 2019020863.json to ../data/nhl_data
# Copied 2023020253.json to ../data/nhl_data
# Copied 2018020061.json to ../data/nhl_data
# Copied 2020020159.json to ../data/nhl_data
# Copied 2019020530.json to ../data/nhl_data
# Copied 2021020408.json to ../data/nhl_data
# Copied 2023021012.json to ../data/nhl_data
# Copied 2022021113.json to ../data/nhl_data
# Copied 2020020509.json to ../data/nhl_data
# Copied 2018020431.json to ../data/nhl_data
# Copied 2021020058.json to ../data/nhl_data
# Copied 2019020160.json to ../data/nhl_data
# Copied 2019020475.json to ../data/nhl_data
# Copied 2023021157.json to ../data/nhl_data
# Copied 2017020509.json to ../data/nhl_data
# Copied 2016020058.json to ../data/nhl_data
# Copied 2018020124.json to ../data/nhl_data
# Copied 2019020025.json to ../data/nhl_data
# Copied 2017020159.json to ../data/nhl_data
# Copied 2022021056.json to ../data/nhl_data
# Copied 2016020408.json to ../data/nhl_data
# Copied 2018020574.json to ../data/nhl_data
# Copied 2023020746.json to ../data/nhl_data
# Copied 2022020217.json to ../data/nhl_data
# Copied 2018020827.json to ../data/nhl_data
# Copied 2019020926.json to ../data/nhl_data
# Copied 2023020316.json to ../data/nhl_data
# Copied 2016021219.json to ../data/nhl_data
# Copied 2022020647.json to ../data/nhl_data
# Copied 2023020183.json to ../data/nhl_data
# Copied 2022020128.json to ../data/nhl_data
# Copied 2021021063.json to ../data/nhl_data
# Copied 2017021027.json to ../data/nhl_data
# Copied 2023020479.json to ../data/nhl_data
# Copied 2016021126.json to ../data/nhl_data
# Copied 2022020578.json to ../data/nhl_data
# Copied 2023020029.json to ../data/nhl_data
# Copied 2022020082.json to ../data/nhl_data
# Copied 2023020880.json to ../data/nhl_data
# Copied 2016020367.json to ../data/nhl_data
# Copied 2020020323.json to ../data/nhl_data
# Copied 2021020388.json to ../data/nhl_data
# Copied 2021020672.json to ../data/nhl_data
# Copied 2023021268.json to ../data/nhl_data
# Copied 2017020636.json to ../data/nhl_data
# Copied 2016020737.json to ../data/nhl_data
# Copied 2020020773.json to ../data/nhl_data
# Copied 2020020289.json to ../data/nhl_data
# Copied 2021020222.json to ../data/nhl_data
# Copied 2017020266.json to ../data/nhl_data
# Copied 2022020981.json to ../data/nhl_data
# Copied 2021020737.json to ../data/nhl_data
# Copied 2017020773.json to ../data/nhl_data
# Copied 2017020289.json to ../data/nhl_data
# Copied 2016020222.json to ../data/nhl_data
# Copied 2020020266.json to ../data/nhl_data
# Copied 2021020367.json to ../data/nhl_data
# Copied 2017020323.json to ../data/nhl_data
# Copied 2016020388.json to ../data/nhl_data
# Copied 2016020672.json to ../data/nhl_data
# Copied 2023021287.json to ../data/nhl_data
# Copied 2020020636.json to ../data/nhl_data
# Copied 2021021126.json to ../data/nhl_data
# Copied 2022020597.json to ../data/nhl_data
# Copied 2017021162.json to ../data/nhl_data
# Copied 2016021063.json to ../data/nhl_data
# Copied 2023020496.json to ../data/nhl_data
# Copied 2019020176.json to ../data/nhl_data
# Copied 2018020427.json to ../data/nhl_data
# Copied 2022021105.json to ../data/nhl_data
# Copied 2023021004.json to ../data/nhl_data
# Copied 2019020526.json to ../data/nhl_data
# Copied 2018020077.json to ../data/nhl_data
# Copied 2023020245.json to ../data/nhl_data
# Copied 2017020909.json to ../data/nhl_data
# Copied 2019020875.json to ../data/nhl_data
# Copied 2018021236.json to ../data/nhl_data
# Copied 2022020714.json to ../data/nhl_data
# Copied 2023020615.json to ../data/nhl_data
# Copied 2018020974.json to ../data/nhl_data
# ...
# Copied 2023030151.json to ../data/nhl_data
# Copied 2022030115.json to ../data/nhl_data
# Copied 2021030161.json to ../data/nhl_data
# Copied 2017030125.json to ../data/nhl_data
# Copied 2016030161.json to ../data/nhl_data
# Copied 2020030125.json to ../data/nhl_data
# Copied 2019030235.json to ../data/nhl_data
# Copied 2023030413.json to ../data/nhl_data
# Copied 2022030142.json to ../data/nhl_data
# Copied 2017030133.json to ../data/nhl_data
# Copied 2021030177.json to ../data/nhl_data
# Copied 2020030133.json to ../data/nhl_data
# Copied 2018030322.json to ../data/nhl_data
# Copied 2019030223.json to ../data/nhl_data
# Copied 2022030154.json to ../data/nhl_data
# Copied 2017030164.json to ../data/nhl_data
# Copied 2020030164.json to ../data/nhl_data
# Copied 2018030161.json to ../data/nhl_data
# Copied 2019030125.json to ../data/nhl_data
# Copied 2023030216.json to ../data/nhl_data
# Copied 2020030235.json to ../data/nhl_data
# Copied 2017030235.json to ../data/nhl_data
# Copied 2018030136.json to ../data/nhl_data
# Copied 2023030241.json to ../data/nhl_data
# Copied 2019030172.json to ../data/nhl_data
# Copied 2016030226.json to ../data/nhl_data
# Copied 2020030327.json to ../data/nhl_data
# Copied 2021030226.json to ../data/nhl_data
# Copied 2022030213.json to ../data/nhl_data
# Copied 2023030312.json to ../data/nhl_data
# Copied 2019030164.json to ../data/nhl_data
# Copied 2022030244.json to ../data/nhl_data
# Copied 2019030133.json to ../data/nhl_data
# Copied 2022030182.json to ../data/nhl_data
# Copied 2020030223.json to ../data/nhl_data
# Copied 2021030322.json to ../data/nhl_data
# Copied 2016030322.json to ../data/nhl_data
# Copied 2017030223.json to ../data/nhl_data
# Copied 2016030135.json to ../data/nhl_data
# Copied 2020030171.json to ../data/nhl_data
# Copied 2021030135.json to ../data/nhl_data
# Copied 2017030171.json to ../data/nhl_data
# Copied 2019030324.json to ../data/nhl_data
# Copied 2022030116.json to ../data/nhl_data
# Copied 2023030152.json to ../data/nhl_data
# Copied 2016030162.json to ../data/nhl_data
# Copied 2021030162.json to ../data/nhl_data
# Copied 2017030126.json to ../data/nhl_data
# Copied 2022030141.json to ../data/nhl_data
# Copied 2019030236.json to ../data/nhl_data
# Copied 2016030174.json to ../data/nhl_data
# Copied 2021030174.json to ../data/nhl_data
# Copied 2022030157.json to ../data/nhl_data
# Copied 2023030113.json to ../data/nhl_data
# Copied 2018030321.json to ../data/nhl_data
# Copied 2020030167.json to ../data/nhl_data
# Copied 2016030123.json to ../data/nhl_data
# Copied 2021030123.json to ../data/nhl_data
# Copied 2018030233.json to ../data/nhl_data
# Copied 2022030415.json to ../data/nhl_data
# Copied 2023030144.json to ../data/nhl_data
# Copied 2023030133.json to ../data/nhl_data
# Copied 2018030244.json to ../data/nhl_data
# Copied 2021030154.json to ../data/nhl_data
# Copied 2018030182.json to ../data/nhl_data
# Copied 2016030154.json to ../data/nhl_data
# Copied 2023030164.json to ../data/nhl_data
# Copied 2019030312.json to ../data/nhl_data
# Copied 2018030213.json to ../data/nhl_data
# Copied 2016030416.json to ../data/nhl_data
# Copied 2021030416.json to ../data/nhl_data
# Copied 2023030172.json to ../data/nhl_data
# Copied 2019030241.json to ../data/nhl_data
# Copied 2022030136.json to ../data/nhl_data
# Copied 2021030115.json to ../data/nhl_data
# Copied 2017030151.json to ../data/nhl_data
# Copied 2016030115.json to ../data/nhl_data
# Copied 2020030151.json to ../data/nhl_data
# Copied 2019030216.json to ../data/nhl_data
# Copied 2023030125.json to ../data/nhl_data
# Copied 2022030161.json to ../data/nhl_data
# Copied 2021030142.json to ../data/nhl_data
# Copied 2020030413.json to ../data/nhl_data
# Copied 2016030142.json to ../data/nhl_data
# Copied 2017030413.json to ../data/nhl_data
# Copied 2020030311.json to ../data/nhl_data
# Copied 2017030311.json to ../data/nhl_data
# Copied 2018030415.json to ../data/nhl_data
# Copied 2019030144.json to ../data/nhl_data
# Copied 2022030233.json to ../data/nhl_data
# Copied 2016030247.json to ../data/nhl_data
# Copied 2022030321.json to ../data/nhl_data
# Copied 2019030113.json to ../data/nhl_data
# Copied 2021030181.json to ../data/nhl_data
# Copied 2016030181.json to ../data/nhl_data
# Copied 2017030215.json to ../data/nhl_data
# Copied 2016030314.json to ../data/nhl_data
# Copied 2021030314.json to ../data/nhl_data
# Copied 2020030215.json to ../data/nhl_data
# Copied 2023030236.json to ../data/nhl_data
# Copied 2018030141.json to ../data/nhl_data
# Copied 2017030242.json to ../data/nhl_data
# Copied 2020030242.json to ../data/nhl_data
# Copied 2019030152.json to ../data/nhl_data
# Copied 2017030184.json to ../data/nhl_data
# Copied 2020030184.json to ../data/nhl_data
# Copied 2023030324.json to ../data/nhl_data
# Copied 2022030225.json to ../data/nhl_data
# Copied 2019030153.json to ../data/nhl_data
# Copied 2023030325.json to ../data/nhl_data
# Copied 2022030224.json to ../data/nhl_data
# Copied 2017030243.json to ../data/nhl_data
# Copied 2020030243.json to ../data/nhl_data
# Copied 2019030411.json to ../data/nhl_data
# Copied 2017030214.json to ../data/nhl_data
# Copied 2016030315.json to ../data/nhl_data
# Copied 2021030315.json to ../data/nhl_data
# Copied 2020030214.json to ../data/nhl_data
# Copied 2023030221.json to ../data/nhl_data
# Copied 2019030112.json to ../data/nhl_data
# Copied 2018030156.json to ../data/nhl_data
# Copied 2016030246.json to ../data/nhl_data
# Copied 2018030414.json to ../data/nhl_data
# Copied 2019030145.json to ../data/nhl_data
# Copied 2022030232.json to ../data/nhl_data
# Copied 2021030211.json to ../data/nhl_data
# Copied 2016030211.json to ../data/nhl_data
# Copied 2021030143.json to ../data/nhl_data
# Copied 2020030412.json to ../data/nhl_data
# Copied 2016030143.json to ../data/nhl_data
# Copied 2017030412.json to ../data/nhl_data
# Copied 2019030217.json to ../data/nhl_data
# Copied 2023030124.json to ../data/nhl_data
# Copied 2021030114.json to ../data/nhl_data
# Copied 2019030186.json to ../data/nhl_data
# Copied 2016030114.json to ../data/nhl_data
# Copied 2023030173.json to ../data/nhl_data
# Copied 2017030146.json to ../data/nhl_data
# Copied 2020030146.json to ../data/nhl_data
# Copied 2023030165.json to ../data/nhl_data
# Copied 2022030121.json to ../data/nhl_data
# Copied 2019030313.json to ../data/nhl_data
# Copied 2018030212.json to ../data/nhl_data
# Copied 2017030111.json to ../data/nhl_data
# Copied 2018030183.json to ../data/nhl_data
# Copied 2020030111.json to ../data/nhl_data
# Copied 2023030132.json to ../data/nhl_data
# Copied 2018030245.json to ../data/nhl_data
# Copied 2018030232.json to ../data/nhl_data
# Copied 2022030414.json to ../data/nhl_data
# Copied 2023030145.json to ../data/nhl_data
# Copied 2016030122.json to ../data/nhl_data
# Copied 2020030166.json to ../data/nhl_data
# Copied 2021030122.json to ../data/nhl_data
# Copied 2022030156.json to ../data/nhl_data
# Copied 2023030112.json to ../data/nhl_data
# Copied 2019030221.json to ../data/nhl_data
# Copied 2020030131.json to ../data/nhl_data
# Copied 2021030175.json to ../data/nhl_data
# Copied 2017030131.json to ../data/nhl_data
# Copied 2023030411.json to ../data/nhl_data
# Copied 2019030237.json to ../data/nhl_data
# Copied 2016030163.json to ../data/nhl_data
# Copied 2017030127.json to ../data/nhl_data
# Copied 2021030163.json to ../data/nhl_data
# Copied 2018030224.json to ../data/nhl_data
# Copied 2019030325.json to ../data/nhl_data
# Copied 2022030117.json to ../data/nhl_data
# Copied 2023030153.json to ../data/nhl_data
# Copied 2016030134.json to ../data/nhl_data
# Copied 2021030134.json to ../data/nhl_data
# Copied 2022030183.json to ../data/nhl_data
# Copied 2020030222.json to ../data/nhl_data
# Copied 2021030323.json to ../data/nhl_data
# Copied 2016030323.json to ../data/nhl_data
# Copied 2017030222.json to ../data/nhl_data
# Copied 2022030245.json to ../data/nhl_data
# Copied 2019030132.json to ../data/nhl_data
# Copied 2016030231.json to ../data/nhl_data
# Copied 2021030231.json to ../data/nhl_data
# Copied 2022030212.json to ../data/nhl_data
# Copied 2023030313.json to ../data/nhl_data
# Copied 2018030121.json to ../data/nhl_data
# Copied 2019030165.json to ../data/nhl_data
# Copied 2016030227.json to ../data/nhl_data
# Copied 2020030326.json to ../data/nhl_data
# Copied 2021030227.json to ../data/nhl_data
# Copied 2018030137.json to ../data/nhl_data
# Copied 2019030173.json to ../data/nhl_data
# Copied 2020030234.json to ../data/nhl_data
# Copied 2017030234.json to ../data/nhl_data
# Copied 2019030124.json to ../data/nhl_data
# Copied 2022030171.json to ../data/nhl_data
# Copied 2018030242.json to ../data/nhl_data
# Copied 2021030152.json to ../data/nhl_data
# Copied 2018030184.json to ../data/nhl_data
# Copied 2020030116.json to ../data/nhl_data
# Copied 2016030152.json to ../data/nhl_data
# Copied 2023030162.json to ../data/nhl_data
# Copied 2019030314.json to ../data/nhl_data
# Copied 2018030215.json to ../data/nhl_data
# Copied 2022030126.json to ../data/nhl_data
# Copied 2017030141.json to ../data/nhl_data
# Copied 2020030141.json to ../data/nhl_data
# Copied 2019030247.json to ../data/nhl_data
# Copied 2023030174.json to ../data/nhl_data
# Copied 2021030113.json to ../data/nhl_data
# Copied 2019030181.json to ../data/nhl_data
# Copied 2016030113.json to ../data/nhl_data
# Copied 2023030123.json to ../data/nhl_data
# Copied 2018030311.json to ../data/nhl_data
# Copied 2020030415.json to ../data/nhl_data
# Copied 2021030144.json to ../data/nhl_data
# Copied 2017030415.json to ../data/nhl_data
# Copied 2016030144.json to ../data/nhl_data
# Copied 2017030317.json to ../data/nhl_data
# Copied 2016030216.json to ../data/nhl_data
# Copied 2019030142.json to ../data/nhl_data
# Copied 2018030413.json to ../data/nhl_data
# Copied 2022030235.json to ../data/nhl_data
# Copied 2021030241.json to ../data/nhl_data
# Copied 2016030241.json to ../data/nhl_data
# Copied 2019030115.json to ../data/nhl_data
# Copied 2021030187.json to ../data/nhl_data
# Copied 2023030226.json to ../data/nhl_data
# Copied 2018030151.json to ../data/nhl_data
# Copied 2017030213.json to ../data/nhl_data
# Copied 2016030312.json to ../data/nhl_data
# Copied 2021030312.json to ../data/nhl_data
# Copied 2020030213.json to ../data/nhl_data
# Copied 2019030416.json to ../data/nhl_data
# Copied 2017030244.json to ../data/nhl_data
# Copied 2020030244.json to ../data/nhl_data
# Copied 2019030154.json to ../data/nhl_data
# Copied 2017030182.json to ../data/nhl_data
# Copied 2023030322.json to ../data/nhl_data
# Copied 2022030223.json to ../data/nhl_data
# Copied 2020030182.json to ../data/nhl_data
# Copied 2022030311.json to ../data/nhl_data
# Copied 2019030123.json to ../data/nhl_data
# Copied 2020030233.json to ../data/nhl_data
# Copied 2017030233.json to ../data/nhl_data
# Copied 2019030174.json to ../data/nhl_data
# Copied 2023030247.json to ../data/nhl_data
# Copied 2017030321.json to ../data/nhl_data
# Copied 2023030181.json to ../data/nhl_data
# Copied 2020030321.json to ../data/nhl_data
# Copied 2018030126.json to ../data/nhl_data
# Copied 2022030215.json to ../data/nhl_data
# Copied 2023030314.json to ../data/nhl_data
# Copied 2019030162.json to ../data/nhl_data
# Copied 2016030236.json to ../data/nhl_data
# Copied 2021030236.json to ../data/nhl_data
# Copied 2022030242.json to ../data/nhl_data
# Copied 2018030171.json to ../data/nhl_data
# Copied 2019030135.json to ../data/nhl_data
# Copied 2020030225.json to ../data/nhl_data
# Copied 2021030324.json to ../data/nhl_data
# Copied 2022030184.json to ../data/nhl_data
# Copied 2016030324.json to ../data/nhl_data
# Copied 2017030225.json to ../data/nhl_data
# Copied 2016030133.json to ../data/nhl_data
# Copied 2020030177.json to ../data/nhl_data
# Copied 2021030133.json to ../data/nhl_data
# Copied 2018030223.json to ../data/nhl_data
# Copied 2019030322.json to ../data/nhl_data
# Copied 2023030154.json to ../data/nhl_data
# Copied 2016030164.json to ../data/nhl_data
# Copied 2021030164.json to ../data/nhl_data
# Copied 2022030147.json to ../data/nhl_data
# Copied 2023030416.json to ../data/nhl_data
# Copied 2020030136.json to ../data/nhl_data
# Copied 2016030172.json to ../data/nhl_data
# Copied 2017030136.json to ../data/nhl_data
# Copied 2021030172.json to ../data/nhl_data
# Copied 2022030151.json to ../data/nhl_data
# Copied 2023030115.json to ../data/nhl_data
# Copied 2020030161.json to ../data/nhl_data
# Copied 2016030125.json to ../data/nhl_data
# Copied 2017030161.json to ../data/nhl_data
# Copied 2021030125.json to ../data/nhl_data
# Copied 2018030235.json to ../data/nhl_data
# Copied 2023030142.json to ../data/nhl_data
# Copied 2022030413.json to ../data/nhl_data
# Copied 2018030234.json to ../data/nhl_data
# Copied 2023030143.json to ../data/nhl_data
# Copied 2022030412.json to ../data/nhl_data
# Copied 2016030124.json to ../data/nhl_data
# Copied 2021030124.json to ../data/nhl_data
# Copied 2018030326.json to ../data/nhl_data
# Copied 2023030114.json to ../data/nhl_data
# Copied 2016030173.json to ../data/nhl_data
# Copied 2021030173.json to ../data/nhl_data
# Copied 2022030146.json to ../data/nhl_data
# Copied 2023030417.json to ../data/nhl_data
# Copied 2019030231.json to ../data/nhl_data
# Copied 2020030121.json to ../data/nhl_data
# Copied 2016030165.json to ../data/nhl_data
# Copied 2017030121.json to ../data/nhl_data
# Copied 2021030165.json to ../data/nhl_data
# Copied 2022030111.json to ../data/nhl_data
# Copied 2018030222.json to ../data/nhl_data
# Copied 2019030323.json to ../data/nhl_data
# Copied 2023030155.json to ../data/nhl_data
# Copied 2020030176.json to ../data/nhl_data
# Copied 2016030132.json to ../data/nhl_data
# Copied 2021030132.json to ../data/nhl_data
# Copied 2020030224.json to ../data/nhl_data
# Copied 2022030185.json to ../data/nhl_data
# Copied 2016030325.json to ../data/nhl_data
# Copied 2017030224.json to ../data/nhl_data
# Copied 2022030243.json to ../data/nhl_data
# Copied 2019030134.json to ../data/nhl_data
# Copied 2018030127.json to ../data/nhl_data
# Copied 2022030214.json to ../data/nhl_data
# Copied 2023030315.json to ../data/nhl_data
# Copied 2019030163.json to ../data/nhl_data
# Copied 2016030221.json to ../data/nhl_data
# Copied 2021030221.json to ../data/nhl_data
# Copied 2018030131.json to ../data/nhl_data
# Copied 2019030175.json to ../data/nhl_data
# Copied 2023030246.json to ../data/nhl_data
# Copied 2020030232.json to ../data/nhl_data
# Copied 2017030232.json to ../data/nhl_data
# Copied 2018030166.json to ../data/nhl_data
# Copied 2023030211.json to ../data/nhl_data
# Copied 2019030122.json to ../data/nhl_data
# Copied 2019030155.json to ../data/nhl_data
# Copied 2017030183.json to ../data/nhl_data
# Copied 2023030323.json to ../data/nhl_data
# Copied 2022030222.json to ../data/nhl_data
# Copied 2020030183.json to ../data/nhl_data
# Copied 2018030111.json to ../data/nhl_data
# Copied 2017030245.json to ../data/nhl_data
# Copied 2023030231.json to ../data/nhl_data
# Copied 2017030212.json to ../data/nhl_data
# Copied 2016030313.json to ../data/nhl_data
# Copied 2021030313.json to ../data/nhl_data
# Copied 2020030212.json to ../data/nhl_data
# Copied 2019030114.json to ../data/nhl_data
# Copied 2021030186.json to ../data/nhl_data
# Copied 2022030326.json to ../data/nhl_data
# Copied 2016030186.json to ../data/nhl_data
# Copied 2019030143.json to ../data/nhl_data
# Copied 2018030412.json to ../data/nhl_data
# Copied 2022030234.json to ../data/nhl_data
# Copied 2020030316.json to ../data/nhl_data
# Copied 2017030316.json to ../data/nhl_data
# Copied 2020030414.json to ../data/nhl_data
# Copied 2021030145.json to ../data/nhl_data
# Copied 2017030414.json to ../data/nhl_data
# Copied 2016030145.json to ../data/nhl_data
# Copied 2023030122.json to ../data/nhl_data
# Copied 2019030211.json to ../data/nhl_data
# Copied 2022030166.json to ../data/nhl_data
# Copied 2017030156.json to ../data/nhl_data
# Copied 2021030112.json to ../data/nhl_data
# Copied 2016030112.json to ../data/nhl_data
# Copied 2019030246.json to ../data/nhl_data
# Copied 2023030175.json to ../data/nhl_data
# Copied 2022030131.json to ../data/nhl_data
# Copied 2016030411.json to ../data/nhl_data
# Copied 2021030411.json to ../data/nhl_data
# Copied 2023030163.json to ../data/nhl_data
# Copied 2019030315.json to ../data/nhl_data
# Copied 2018030214.json to ../data/nhl_data
# Copied 2021030153.json to ../data/nhl_data
# Copied 2018030185.json to ../data/nhl_data
# Copied 2016030153.json to ../data/nhl_data
# Copied 2023030134.json to ../data/nhl_data
# Copied 2018030243.json to ../data/nhl_data
# All files have been copied successfully.
