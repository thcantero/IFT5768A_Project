# %% [markdown]
# # Part 1: Acquisition de données
#
# #### Logique générale
# 1. Classe pour téléchargement de données
# 2. Téléchargement des matches de 2016 à 2023:
#     * **Saisons régulières**. Sauvegarde dans: _data/nhl_reguliere_
#     * **Matches des playoffs**. Sauvegarde dans: _data/nhl_playoffs_
# 3. Fusion des deux repertoires _data/nhl_reguliere_ et _data/nhl_playoffs_ dans _data/nhl_data_

# %% [markdown]
# ### 1. Classe pour téléchargement de données

# %%
import os
import requests
import json
import time

class NHLDataDownloader:
    def __init__(self, base_dir):
        """
        Initialise le répertoire où les données seront sauvegardées.
        :param base_dir: Chemin du répertoire local pour la sauvegarde des données
        """
        self.base_dir = base_dir
        if not os.path.exists(base_dir):
            os.makedirs(base_dir)

    def download_game_data(self, game_id: str) -> dict:
     """
    Télécharge les données d'un match spécifique depuis l'API de la LNH.
    Si le fichier existe déjà localement, il est chargé depuis le disque.
    :param game_id: L'identifiant unique du match (ex. '2020020001' pour le premier match de la saison 2020-21)
    :return: Un dictionnaire contenant les données du match, ou None en cas d'erreur
    """
     file_path = os.path.join(self.base_dir, f"{game_id}.json")
     if os.path.exists(file_path):
        print(f"Fichier {game_id}.json déjà existant dans le répertoire {self.base_dir}.")
        with open(file_path, 'r', encoding='utf-8') as f:
                game = json.load(f)
                return game
     else:
        game_type = str(game_id)[4:6]
        game = None  # Initialisation de la variable 'game'
        if game_type == '02' or game_type == '03':
            url = f"https://api-web.nhle.com/v1/gamecenter/{str(game_id)}/play-by-play"
            try:
                response = requests.get(url)
                response.raise_for_status()  # Vérifie si la requête a réussi
                game = response.json()
                with open(os.path.join(self.base_dir, f"{game_id}.json"), 'w', encoding='utf-8') as f:
                    json.dump(game, f, ensure_ascii=False, indent=4)
                    f.close()
                    print(f"Téléchargé et enregistré : {game_id}.json")
            except Exception as e:
                print(f"Erreur de téléchargement du match {game_id}: {e}")
            time.sleep(1)  # Délai d'une seconde entre les requêtes
        return game

# %% [markdown]
# ##### Exemple de téléchargement d'un fichier existent et d'un fichier non-existent

# %%
# Utilisation de la classe
downloader = NHLDataDownloader(base_dir='../data/test')

# Télécharge les données pour la saison 2016 (saison régulière et playoffs)
downloader.download_game_data(2016020001)
downloader.download_game_data(2016020002)
# Out:
# Fichier 2016020001.json déjà existant dans le répertoire ../data/test.
# Fichier 2016020002.json déjà existant dans le répertoire ../data/test.
# {'id': 2016020002,
#  'season': 20162017,
#  'gameType': 2,
#  'limitedScoring': False,
#  'gameDate': '2016-10-12',
#  'venue': {'default': 'United Center'},
#  'venueLocation': {'default': 'Chicago'},
#  'startTimeUTC': '2016-10-13T00:00:00Z',
#  'easternUTCOffset': '-04:00',
#  'venueUTCOffset': '-05:00',
#  'tvBroadcasts': [{'id': 241,
#    'market': 'N',
#    'countryCode': 'US',
#    'network': 'NBCSN',
#    'sequenceNumber': 13}],
#  'gameState': 'OFF',
#  'gameScheduleState': 'OK',
#  'periodDescriptor': {'number': 3,
#   'periodType': 'REG',
#   'maxRegulationPeriods': 3},
#  'awayTeam': {'id': 19,
#   'name': {'default': 'Blues'},
#   'abbrev': 'STL',
#   'score': 5,
#   'sog': 33,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/STL_light.svg',
#   'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/STL_dark.svg',
#   'placeName': {'default': 'St. Louis'},
#   'placeNameWithPreposition': {'default': 'St. Louis', 'fr': 'de St. Louis'}},
#  'homeTeam': {'id': 16,
#   'name': {'default': 'Blackhawks'},
#   'abbrev': 'CHI',
#   'score': 2,
#   'sog': 19,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/CHI_light.svg',
#   'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CHI_dark.svg',
#   'placeName': {'default': 'Chicago'},
#   'placeNameWithPreposition': {'default': 'Chicago', 'fr': 'de Chicago'}},
#  'shootoutInUse': True,
#  'otInUse': True,
#  'clock': {'timeRemaining': '00:00',
#   'secondsRemaining': 0,
#   'running': False,
#   'inIntermission': False},
#  'displayPeriod': 1,
#  'maxPeriods': 5,
#  'gameOutcome': {'lastPeriodType': 'REG'},
#  'plays': [{'eventId': 5,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'typeCode': 520,
#    'typeDescKey': 'period-start',
#    'sortOrder': 5},
#   {'eventId': 6,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 6,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473604,
#     'winningPlayerId': 8471669,
#     'xCoord': 1,
#     'yCoord': 1,
#     'zoneCode': 'N'}},
#   {'eventId': 7,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:12',
#    'timeRemaining': '19:48',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 7,
#    'details': {'xCoord': 64,
#     'yCoord': -16,
#     'zoneCode': 'O',
#     'shotType': 'snap',
#     'shootingPlayerId': 8470257,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 1,
#     'homeSOG': 0}},
#   {'eventId': 51,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:11',
#    'timeRemaining': '19:49',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 8,
#    'details': {'xCoord': 88,
#     'yCoord': -37,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8471669,
#     'hitteePlayerId': 8470281}},
#   {'eventId': 8,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:45',
#    'timeRemaining': '19:15',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 9,
#    'details': {'xCoord': 54,
#     'yCoord': 28,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'slap',
#     'shootingPlayerId': 8470151,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 9,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:10',
#    'timeRemaining': '18:50',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 13,
#    'details': {'xCoord': 52,
#     'yCoord': -8,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474627,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 2,
#     'homeSOG': 0}},
#   {'eventId': 53,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:10',
#    'timeRemaining': '18:50',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 15,
#    'details': {'reason': 'goalie-stopped-after-sog'}},
#   {'eventId': 10,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:10',
#    'timeRemaining': '18:50',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 17,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8474627,
#     'winningPlayerId': 8475323,
#     'xCoord': 69,
#     'yCoord': -22,
#     'zoneCode': 'D'}},
#   {'eventId': 54,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:24',
#    'timeRemaining': '18:36',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 18,
#    'details': {'xCoord': -95,
#     'yCoord': 21,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477353,
#     'hitteePlayerId': 8476441}},
#   {'eventId': 11,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:33',
#    'timeRemaining': '18:27',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 19,
#    'details': {'xCoord': 86,
#     'yCoord': 11,
#     'zoneCode': 'O',
#     'reason': 'goalpost',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8476892,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 55,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:06',
#    'timeRemaining': '17:54',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 22,
#    'details': {'xCoord': 42,
#     'yCoord': 32,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8466285}},
#   {'eventId': 12,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:27',
#    'timeRemaining': '17:33',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 24,
#    'details': {'xCoord': -77,
#     'yCoord': 8,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8474565,
#     'shootingPlayerId': 8473573,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 56,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:38',
#    'timeRemaining': '17:22',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 27,
#    'details': {'xCoord': -33,
#     'yCoord': -37,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8479482,
#     'hitteePlayerId': 8476436}},
#   {'eventId': 13,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:36',
#    'timeRemaining': '17:24',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 29,
#    'details': {'xCoord': -66,
#     'yCoord': 7,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8470151,
#     'shootingPlayerId': 8474141,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 57,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:50',
#    'timeRemaining': '17:10',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 30,
#    'details': {'xCoord': -90,
#     'yCoord': 28,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474145,
#     'hitteePlayerId': 8476994}},
#   {'eventId': 58,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:54',
#    'timeRemaining': '17:06',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 31,
#    'details': {'xCoord': -92,
#     'yCoord': 33,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8469547,
#     'hitteePlayerId': 8474145}},
#   {'eventId': 59,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:00',
#    'timeRemaining': '17:00',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 33,
#    'details': {'reason': 'offside'}},
#   {'eventId': 14,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:00',
#    'timeRemaining': '17:00',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 35,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8471669,
#     'winningPlayerId': 8473604,
#     'xCoord': 20,
#     'yCoord': -21,
#     'zoneCode': 'N'}},
#   {'eventId': 60,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:22',
#    'timeRemaining': '16:38',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 36,
#    'details': {'xCoord': -65,
#     'yCoord': -39,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474145,
#     'hitteePlayerId': 8466148}},
#   {'eventId': 15,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:28',
#    'timeRemaining': '16:32',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 37,
#    'details': {'xCoord': -82,
#     'yCoord': -8,
#     'zoneCode': 'O',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8473604,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 2,
#     'homeSOG': 1}},
#   {'eventId': 16,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:31',
#    'timeRemaining': '16:29',
#    'situationCode': '1551',
#    'typeCode': 509,
#    'typeDescKey': 'penalty',
#    'sortOrder': 39,
#    'details': {'xCoord': -30,
#     'yCoord': 38,
#     'zoneCode': 'D',
#     'typeCode': 'MIN',
#     'descKey': 'slashing',
#     'duration': 2,
#     'committedByPlayerId': 8477952,
#     'drawnByPlayerId': 8477845,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 61,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:31',
#    'timeRemaining': '16:29',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 43,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8474141,
#     'winningPlayerId': 8474627,
#     'xCoord': -68,
#     'yCoord': -23,
#     'zoneCode': 'D'}},
#   {'eventId': 18,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:45',
#    'timeRemaining': '16:15',
#    'situationCode': '1451',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 44,
#    'details': {'xCoord': -76,
#     'yCoord': 29,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474141,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 2,
#     'homeSOG': 2}},
#   {'eventId': 62,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:53',
#    'timeRemaining': '16:07',
#    'situationCode': '1451',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 45,
#    'details': {'xCoord': -17,
#     'yCoord': 27,
#     'zoneCode': 'N',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474102,
#     'hitteePlayerId': 8470607}},
#   {'eventId': 63,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:17',
#    'timeRemaining': '15:43',
#    'situationCode': '1451',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 50,
#    'details': {'xCoord': -17,
#     'yCoord': 35,
#     'zoneCode': 'N',
#     'playerId': 8470803,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 64,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:26',
#    'timeRemaining': '15:34',
#    'situationCode': '1451',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 53,
#    'details': {'reason': 'offside'}},
#   {'eventId': 19,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:26',
#    'timeRemaining': '15:34',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 55,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8471669,
#     'winningPlayerId': 8473604,
#     'xCoord': -69,
#     'yCoord': 21,
#     'zoneCode': 'O'}},
#   {'eventId': 20,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:37',
#    'timeRemaining': '15:23',
#    'situationCode': '1451',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 56,
#    'details': {'xCoord': -76,
#     'yCoord': 2,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8473604,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 2,
#     'homeSOG': 3}},
#   {'eventId': 21,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:38',
#    'timeRemaining': '15:22',
#    'situationCode': '1451',
#    'typeCode': 505,
#    'typeDescKey': 'goal',
#    'sortOrder': 57,
#    'details': {'xCoord': -81,
#     'yCoord': -8,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'scoringPlayerId': 8475209,
#     'scoringPlayerTotal': 1,
#     'assist1PlayerId': 8473604,
#     'assist1PlayerTotal': 1,
#     'assist2PlayerId': 8466148,
#     'assist2PlayerTotal': 1,
#     'eventOwnerTeamId': 16,
#     'goalieInNetId': 8474596,
#     'awayScore': 0,
#     'homeScore': 1}},
#   {'eventId': 65,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:38',
#    'timeRemaining': '15:22',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 61,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8474627,
#     'winningPlayerId': 8473573,
#     'xCoord': 1,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 22,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:57',
#    'timeRemaining': '15:03',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 63,
#    'details': {'xCoord': -79,
#     'yCoord': -3,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8473573,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 2,
#     'homeSOG': 4}},
#   {'eventId': 23,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:01',
#    'timeRemaining': '14:59',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 64,
#    'details': {'xCoord': -77,
#     'yCoord': -1,
#     'zoneCode': 'O',
#     'reason': 'over-net',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8473573,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 24,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:06',
#    'timeRemaining': '14:54',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 65,
#    'details': {'xCoord': -68,
#     'yCoord': 3,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8475765,
#     'shootingPlayerId': 8479482,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 25,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:16',
#    'timeRemaining': '14:44',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 66,
#    'details': {'xCoord': -76,
#     'yCoord': -3,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8470151,
#     'shootingPlayerId': 8473573,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 66,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:12',
#    'timeRemaining': '14:48',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 67,
#    'details': {'xCoord': -91,
#     'yCoord': -37,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474565,
#     'hitteePlayerId': 8473573}},
#   {'eventId': 26,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:25',
#    'timeRemaining': '14:35',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 69,
#    'details': {'xCoord': 74,
#     'yCoord': -34,
#     'zoneCode': 'O',
#     'shotType': 'slap',
#     'shootingPlayerId': 8474565,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 3,
#     'homeSOG': 4}},
#   {'eventId': 67,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:38',
#    'timeRemaining': '14:22',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 72,
#    'details': {'xCoord': -95,
#     'yCoord': 32,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477451,
#     'hitteePlayerId': 8476436}},
#   {'eventId': 68,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:01',
#    'timeRemaining': '13:59',
#    'situationCode': '1551',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 73,
#    'details': {'xCoord': -64,
#     'yCoord': -37,
#     'zoneCode': 'O',
#     'playerId': 8477353,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 27,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:04',
#    'timeRemaining': '13:56',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 74,
#    'details': {'xCoord': -46,
#     'yCoord': -26,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8473534,
#     'shootingPlayerId': 8470281,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 69,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:15',
#    'timeRemaining': '13:45',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 78,
#    'details': {'xCoord': -34,
#     'yCoord': -7,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8471817,
#     'hitteePlayerId': 8475323}},
#   {'eventId': 28,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:23',
#    'timeRemaining': '13:37',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 81,
#    'details': {'xCoord': 65,
#     'yCoord': -35,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'slap',
#     'shootingPlayerId': 8470803,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 70,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:43',
#    'timeRemaining': '13:17',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 83,
#    'details': {'xCoord': 84,
#     'yCoord': -38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8478055}},
#   {'eventId': 29,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:48',
#    'timeRemaining': '13:12',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 84,
#    'details': {'xCoord': 44,
#     'yCoord': 19,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8469547,
#     'shootingPlayerId': 8476441,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 71,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:56',
#    'timeRemaining': '13:04',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 85,
#    'details': {'xCoord': 61,
#     'yCoord': 38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8469547}},
#   {'eventId': 30,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '07:58',
#    'timeRemaining': '12:02',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 95,
#    'details': {'xCoord': 63,
#     'yCoord': -3,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474627,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 4,
#     'homeSOG': 4}},
#   {'eventId': 31,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:03',
#    'timeRemaining': '11:57',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 96,
#    'details': {'xCoord': 78,
#     'yCoord': 13,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8475765,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 32,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:30',
#    'timeRemaining': '11:30',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 99,
#    'details': {'xCoord': 72,
#     'yCoord': 3,
#     'zoneCode': 'O',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8474145,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 5,
#     'homeSOG': 4}},
#   {'eventId': 73,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:47',
#    'timeRemaining': '11:13',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 102,
#    'details': {'reason': 'offside', 'secondaryReason': 'tv-timeout'}},
#   {'eventId': 33,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:47',
#    'timeRemaining': '11:13',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 104,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8475323,
#     'winningPlayerId': 8473534,
#     'xCoord': 20,
#     'yCoord': 23,
#     'zoneCode': 'N'}},
#   {'eventId': 74,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '09:13',
#    'timeRemaining': '10:47',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 105,
#    'details': {'xCoord': 92,
#     'yCoord': -36,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8476855,
#     'hitteePlayerId': 8466285}},
#   {'eventId': 75,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '09:36',
#    'timeRemaining': '10:24',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 108,
#    'details': {'xCoord': 95,
#     'yCoord': 12,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477845,
#     'hitteePlayerId': 8476892}},
#   {'eventId': 34,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '09:46',
#    'timeRemaining': '10:14',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 112,
#    'details': {'xCoord': -49,
#     'yCoord': 17,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8474102,
#     'shootingPlayerId': 8466148,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 35,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '09:54',
#    'timeRemaining': '10:06',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 113,
#    'details': {'xCoord': -58,
#     'yCoord': 21,
#     'zoneCode': 'O',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8466148,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 5,
#     'homeSOG': 5}},
#   {'eventId': 76,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '10:20',
#    'timeRemaining': '09:40',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 118,
#    'details': {'xCoord': 93,
#     'yCoord': 31,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8477952,
#     'hitteePlayerId': 8474141}},
#   {'eventId': 77,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '10:40',
#    'timeRemaining': '09:20',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 119,
#    'details': {'xCoord': -96,
#     'yCoord': -31,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8474565}},
#   {'eventId': 78,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:02',
#    'timeRemaining': '08:58',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 124,
#    'details': {'xCoord': -51,
#     'yCoord': -39,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474031,
#     'hitteePlayerId': 8474141}},
#   {'eventId': 79,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:08',
#    'timeRemaining': '08:52',
#    'situationCode': '1551',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 126,
#    'details': {'xCoord': -54,
#     'yCoord': 37,
#     'zoneCode': 'O',
#     'playerId': 8476994,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 80,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:16',
#    'timeRemaining': '08:44',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 128,
#    'details': {'xCoord': 81,
#     'yCoord': 0,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8470645}},
#   {'eventId': 36,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:18',
#    'timeRemaining': '08:42',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 129,
#    'details': {'xCoord': 52,
#     'yCoord': 3,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8470105,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 6,
#     'homeSOG': 5}},
#   {'eventId': 81,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:18',
#    'timeRemaining': '08:42',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 130,
#    'details': {'reason': 'goalie-stopped-after-sog',
#     'secondaryReason': 'tv-timeout'}},
#   {'eventId': 37,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:18',
#    'timeRemaining': '08:42',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 133,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8474102,
#     'winningPlayerId': 8475323,
#     'xCoord': 73,
#     'yCoord': 24,
#     'zoneCode': 'D'}},
#   {'eventId': 82,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:24',
#    'timeRemaining': '08:36',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 134,
#    'details': {'reason': 'puck-in-benches'}},
#   {'eventId': 38,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:24',
#    'timeRemaining': '08:36',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 135,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8475323,
#     'winningPlayerId': 8474627,
#     'xCoord': 68,
#     'yCoord': 22,
#     'zoneCode': 'O'}},
#   {'eventId': 39,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:31',
#    'timeRemaining': '08:29',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 136,
#    'details': {'xCoord': 50,
#     'yCoord': -22,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8477353,
#     'shootingPlayerId': 8474031,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 83,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:41',
#    'timeRemaining': '08:19',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 137,
#    'details': {'xCoord': -60,
#     'yCoord': -35,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8474031}},
#   {'eventId': 84,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:56',
#    'timeRemaining': '08:04',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 140,
#    'details': {'xCoord': -96,
#     'yCoord': -6,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474031,
#     'hitteePlayerId': 8475323}},
#   {'eventId': 85,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:05',
#    'timeRemaining': '07:55',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 143,
#    'details': {'xCoord': 76,
#     'yCoord': 38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477353,
#     'hitteePlayerId': 8475765}},
#   {'eventId': 86,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:17',
#    'timeRemaining': '07:43',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 144,
#    'details': {'reason': 'icing'}},
#   {'eventId': 40,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:17',
#    'timeRemaining': '07:43',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 145,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8471669,
#     'winningPlayerId': 8473604,
#     'xCoord': 69,
#     'yCoord': -21,
#     'zoneCode': 'D'}},
#   {'eventId': 87,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:28',
#    'timeRemaining': '07:32',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 146,
#    'details': {'xCoord': 80,
#     'yCoord': -38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8479482,
#     'hitteePlayerId': 8470257}},
#   {'eventId': 41,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:04',
#    'timeRemaining': '06:56',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 151,
#    'details': {'xCoord': 78,
#     'yCoord': 30,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8473534,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 7,
#     'homeSOG': 5}},
#   {'eventId': 88,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:05',
#    'timeRemaining': '06:55',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 152,
#    'details': {'reason': 'goalie-stopped-after-sog'}},
#   {'eventId': 42,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:05',
#    'timeRemaining': '06:55',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 154,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473573,
#     'winningPlayerId': 8473534,
#     'xCoord': 68,
#     'yCoord': 21,
#     'zoneCode': 'O'}},
#   {'eventId': 89,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:17',
#    'timeRemaining': '06:43',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 155,
#    'details': {'xCoord': -94,
#     'yCoord': 32,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8478550,
#     'hitteePlayerId': 8476441}},
#   {'eventId': 90,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:30',
#    'timeRemaining': '06:30',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 157,
#    'details': {'xCoord': -75,
#     'yCoord': -30,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8476892}},
#   {'eventId': 91,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:40',
#    'timeRemaining': '06:20',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 159,
#    'details': {'xCoord': -62,
#     'yCoord': 37,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8476441,
#     'hitteePlayerId': 8474141}},
#   {'eventId': 92,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:47',
#    'timeRemaining': '06:13',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 160,
#    'details': {'xCoord': -84,
#     'yCoord': -18,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8476892}},
#   {'eventId': 43,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:14',
#    'timeRemaining': '05:46',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 166,
#    'details': {'xCoord': 69,
#     'yCoord': -33,
#     'zoneCode': 'O',
#     'shotType': 'snap',
#     'shootingPlayerId': 8470803,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 8,
#     'homeSOG': 5}},
#   {'eventId': 93,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:14',
#    'timeRemaining': '05:46',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 167,
#    'details': {'reason': 'goalie-stopped-after-sog',
#     'secondaryReason': 'tv-timeout'}},
#   {'eventId': 44,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:14',
#    'timeRemaining': '05:46',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 170,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8471669,
#     'winningPlayerId': 8473604,
#     'xCoord': 70,
#     'yCoord': -22,
#     'zoneCode': 'D'}},
#   {'eventId': 94,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:51',
#    'timeRemaining': '05:09',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 175,
#    'details': {'xCoord': -55,
#     'yCoord': -37,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474627,
#     'hitteePlayerId': 8466148}},
#   {'eventId': 95,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:15',
#    'timeRemaining': '04:45',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 179,
#    'details': {'xCoord': -3,
#     'yCoord': -40,
#     'zoneCode': 'N',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8474141,
#     'hitteePlayerId': 8476892}},
#   {'eventId': 96,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:15',
#    'timeRemaining': '04:45',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 180,
#    'details': {'reason': 'offside'}},
#   {'eventId': 45,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:15',
#    'timeRemaining': '04:45',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 182,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473573,
#     'winningPlayerId': 8473534,
#     'xCoord': 19,
#     'yCoord': -21,
#     'zoneCode': 'N'}},
#   {'eventId': 97,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:26',
#    'timeRemaining': '04:34',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 184,
#    'details': {'xCoord': 95,
#     'yCoord': 3,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8466285,
#     'hitteePlayerId': 8470151}},
#   {'eventId': 98,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:44',
#    'timeRemaining': '04:16',
#    'situationCode': '1551',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 185,
#    'details': {'xCoord': -48,
#     'yCoord': 29,
#     'zoneCode': 'D',
#     'playerId': 8476436,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 46,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:52',
#    'timeRemaining': '04:08',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 186,
#    'details': {'xCoord': -47,
#     'yCoord': 8,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'slap',
#     'shootingPlayerId': 8473573,
#     'goalieInNetId': 8474596,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 99,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:22',
#    'timeRemaining': '03:38',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 192,
#    'details': {'xCoord': -71,
#     'yCoord': -38,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8476994,
#     'hitteePlayerId': 8474145}},
#   {'eventId': 100,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:26',
#    'timeRemaining': '03:34',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 193,
#    'details': {'reason': 'puck-in-benches'}},
#   {'eventId': 47,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:26',
#    'timeRemaining': '03:34',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 195,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8477951,
#     'winningPlayerId': 8470803,
#     'xCoord': 0,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 48,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:42',
#    'timeRemaining': '03:18',
#    'situationCode': '1551',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 196,
#    'details': {'xCoord': 51,
#     'yCoord': -7,
#     'zoneCode': 'O',
#     'reason': 'wide-of-net',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8471817,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 251,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:52',
#    'timeRemaining': '03:08',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 197,
#    'details': {'xCoord': 86,
#     'yCoord': 38,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8470105,
#     'hitteePlayerId': 8470607}},
#   {'eventId': 49,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:06',
#    'timeRemaining': '02:54',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 198,
#    'details': {'xCoord': 36,
#     'yCoord': -33,
#     'zoneCode': 'O',
#     'shotType': 'slap',
#     'shootingPlayerId': 8476892,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 9,
#     'homeSOG': 5}},
#   {'eventId': 252,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:03',
#    'timeRemaining': '02:57',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 200,
#    'details': {'xCoord': 54,
#     'yCoord': 35,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8470803,
#     'hitteePlayerId': 8469547}},
#   {'eventId': 253,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:45',
#    'timeRemaining': '02:15',
#    'situationCode': '1551',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 205,
#    'details': {'xCoord': -13,
#     'yCoord': 27,
#     'zoneCode': 'N',
#     'playerId': 8470257,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 254,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:16',
#    'timeRemaining': '01:44',
#    'situationCode': '1551',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 212,
#    'details': {'reason': 'high-stick'}},
#   {'eventId': 50,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:16',
#    'timeRemaining': '01:44',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 215,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8470803,
#     'winningPlayerId': 8473573,
#     'xCoord': -68,
#     'yCoord': -24,
#     'zoneCode': 'O'}},
#   {'eventId': 255,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:33',
#    'timeRemaining': '01:27',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 216,
#    'details': {'xCoord': -57,
#     'yCoord': 41,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8476441,
#     'hitteePlayerId': 8473573}},
#   {'eventId': 201,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:39',
#    'timeRemaining': '01:21',
#    'situationCode': '1551',
#    'typeCode': 509,
#    'typeDescKey': 'penalty',
#    'sortOrder': 217,
#    'details': {'xCoord': -50,
#     'yCoord': -38,
#     'zoneCode': 'D',
#     'typeCode': 'MIN',
#     'descKey': 'holding',
#     'duration': 2,
#     'committedByPlayerId': 8476892,
#     'drawnByPlayerId': 8474141,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 256,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:39',
#    'timeRemaining': '01:21',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 221,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473604,
#     'winningPlayerId': 8471669,
#     'xCoord': -68,
#     'yCoord': -23,
#     'zoneCode': 'D'}},
#   {'eventId': 257,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:22',
#    'timeRemaining': '00:38',
#    'situationCode': '1451',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 225,
#    'details': {'xCoord': -94,
#     'yCoord': 5,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8474596}},
#   {'eventId': 258,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:33',
#    'timeRemaining': '00:27',
#    'situationCode': '1451',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 227,
#    'details': {'xCoord': -45,
#     'yCoord': -34,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'hittingPlayerId': 8474145,
#     'hitteePlayerId': 8478550}},
#   {'eventId': 203,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '20:00',
#    'timeRemaining': '00:00',
#    'typeCode': 521,
#    'typeDescKey': 'period-end',
#    'sortOrder': 230},
#   {'eventId': 208,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'typeCode': 520,
#    'typeDescKey': 'period-start',
#    'sortOrder': 237},
#   {'eventId': 209,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 238,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8473604,
#     'winningPlayerId': 8471669,
#     'xCoord': 2,
#     'yCoord': 1,
#     'zoneCode': 'N'}},
#   {'eventId': 259,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:32',
#    'timeRemaining': '19:28',
#    'situationCode': '1451',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 240,
#    'details': {'reason': 'offside'}},
#   {'eventId': 210,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:32',
#    'timeRemaining': '19:28',
#    'situationCode': '1451',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 242,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8474627,
#     'winningPlayerId': 8473573,
#     'xCoord': 1,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 260,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:53',
#    'timeRemaining': '19:07',
#    'situationCode': '1551',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 245,
#    'details': {'xCoord': -30,
#     'yCoord': -18,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8475209}},
#   {'eventId': 211,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:55',
#    'timeRemaining': '19:05',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 246,
#    'details': {'xCoord': -77,
#     'yCoord': 4,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474102,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
#     'awaySOG': 10,
#     'homeSOG': 5}},
#   {'eventId': 212,
#    'periodDescriptor': {'number': 2,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:56',
#    'timeRemaining': '19:04',
#    'situationCode': '1551',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 247,
#    'details': {'xCoord': -91,
#     'yCoord': 13,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8474102,
#     'goalieInNetId': 8470645,
#     'eventOwnerTeamId': 19,
# ...
#    'sortOrder': 649,
#    'details': {'xCoord': -52,
#     'yCoord': -12,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8471669,
#     'shootingPlayerId': 8478550,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 619,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:44',
#    'timeRemaining': '01:16',
#    'situationCode': '1560',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 650,
#    'details': {'xCoord': -45,
#     'yCoord': 10,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8470257,
#     'shootingPlayerId': 8478055,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 620,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:54',
#    'timeRemaining': '01:06',
#    'situationCode': '1560',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 651,
#    'details': {'xCoord': 81,
#     'yCoord': -15,
#     'zoneCode': 'O',
#     'reason': 'goalpost',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8471669,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 621,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:54',
#    'timeRemaining': '01:06',
#    'situationCode': '1560',
#    'typeCode': 505,
#    'typeDescKey': 'goal',
#    'sortOrder': 652,
#    'details': {'xCoord': 77,
#     'yCoord': 5,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'scoringPlayerId': 8475765,
#     'scoringPlayerTotal': 2,
#     'assist1PlayerId': 8471669,
#     'assist1PlayerTotal': 2,
#     'assist2PlayerId': 8470257,
#     'assist2PlayerTotal': 2,
#     'eventOwnerTeamId': 19,
#     'awayScore': 4,
#     'homeScore': 2}},
#   {'eventId': 598,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:54',
#    'timeRemaining': '01:06',
#    'situationCode': '1560',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 655,
#    'details': {'reason': 'home-timeout', 'secondaryReason': 'home-timeout'}},
#   {'eventId': 599,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:54',
#    'timeRemaining': '01:06',
#    'situationCode': '1560',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 657,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8473534,
#     'winningPlayerId': 8473604,
#     'xCoord': 1,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 623,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:06',
#    'timeRemaining': '00:54',
#    'situationCode': '1560',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 658,
#    'details': {'xCoord': 34,
#     'yCoord': 16,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8470281,
#     'shootingPlayerId': 8473534,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 600,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:10',
#    'timeRemaining': '00:50',
#    'situationCode': '1560',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 659,
#    'details': {'xCoord': 45,
#     'yCoord': -38,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8473604,
#     'hitteePlayerId': 8470803}},
#   {'eventId': 701,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:24',
#    'timeRemaining': '00:36',
#    'situationCode': '1560',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 660,
#    'details': {'xCoord': -70,
#     'yCoord': -8,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 19,
#     'playerId': 8476892}},
#   {'eventId': 1101,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:41',
#    'timeRemaining': '00:19',
#    'situationCode': '1560',
#    'typeCode': 505,
#    'typeDescKey': 'goal',
#    'sortOrder': 663,
#    'details': {'xCoord': 26,
#     'yCoord': 27,
#     'zoneCode': 'N',
#     'shotType': 'wrist',
#     'scoringPlayerId': 8470105,
#     'scoringPlayerTotal': 1,
#     'eventOwnerTeamId': 19,
#     'awayScore': 5,
#     'homeScore': 2}},
#   {'eventId': 702,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:41',
#    'timeRemaining': '00:19',
#    'situationCode': '1551',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 665,
#    'details': {'eventOwnerTeamId': 19,
#     'losingPlayerId': 8477951,
#     'winningPlayerId': 8474627,
#     'xCoord': 0,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 703,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:51',
#    'timeRemaining': '00:09',
#    'situationCode': '1551',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 667,
#    'details': {'xCoord': 95,
#     'yCoord': 14,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8477951,
#     'hitteePlayerId': 8474627}},
#   {'eventId': 625,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:59',
#    'timeRemaining': '00:01',
#    'situationCode': '1551',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 668,
#    'details': {'xCoord': 57,
#     'yCoord': -14,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8477951,
#     'shootingPlayerId': 8476436,
#     'eventOwnerTeamId': 19}},
#   {'eventId': 626,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '20:00',
#    'timeRemaining': '00:00',
#    'typeCode': 521,
#    'typeDescKey': 'period-end',
#    'sortOrder': 669},
#   {'eventId': 630,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '20:00',
#    'timeRemaining': '00:00',
#    'typeCode': 524,
#    'typeDescKey': 'game-end',
#    'sortOrder': 673}],
#  'rosterSpots': [{'teamId': 16,
#    'playerId': 8466148,
#    'firstName': {'default': 'Marian'},
#    'lastName': {'default': 'Hossa'},
#    'sweaterNumber': 81,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8466148.png'},
#   {'teamId': 16,
#    'playerId': 8466285,
#    'firstName': {'default': 'Brian'},
#    'lastName': {'default': 'Campbell'},
#    'sweaterNumber': 51,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8466285.png'},
#   {'teamId': 16,
#    'playerId': 8469547,
#    'firstName': {'default': 'Jordin'},
#    'lastName': {'default': 'Tootoo'},
#    'sweaterNumber': 22,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8469547.png'},
#   {'teamId': 19,
#    'playerId': 8470105,
#    'firstName': {'default': 'Scottie'},
#    'lastName': {'default': 'Upshall'},
#    'sweaterNumber': 10,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8470105.png'},
#   {'teamId': 19,
#    'playerId': 8470151,
#    'firstName': {'default': 'Jay'},
#    'lastName': {'default': 'Bouwmeester'},
#    'sweaterNumber': 19,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8470151.png'},
#   {'teamId': 19,
#    'playerId': 8470257,
#    'firstName': {'default': 'Alexander'},
#    'lastName': {'default': 'Steen'},
#    'sweaterNumber': 20,
#    'positionCode': 'L',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8470257.png'},
#   {'teamId': 16,
#    'playerId': 8470281,
#    'firstName': {'default': 'Duncan'},
#    'lastName': {'default': 'Keith'},
#    'sweaterNumber': 2,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8470281.png'},
#   {'teamId': 16,
#    'playerId': 8470607,
#    'firstName': {'default': 'Brent'},
#    'lastName': {'default': 'Seabrook'},
#    'sweaterNumber': 7,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8470607.png'},
#   {'teamId': 16,
#    'playerId': 8470645,
#    'firstName': {'default': 'Corey'},
#    'lastName': {'default': 'Crawford'},
#    'sweaterNumber': 50,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8470645.png'},
#   {'teamId': 19,
#    'playerId': 8470803,
#    'firstName': {'default': 'Kyle'},
#    'lastName': {'default': 'Brodziak'},
#    'sweaterNumber': 28,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8470803.png'},
#   {'teamId': 19,
#    'playerId': 8471669,
#    'firstName': {'default': 'Paul'},
#    'lastName': {'default': 'Stastny'},
#    'sweaterNumber': 26,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8471669.png'},
#   {'teamId': 19,
#    'playerId': 8471817,
#    'firstName': {'default': 'Ryan'},
#    'lastName': {'default': 'Reaves'},
#    'sweaterNumber': 75,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8471817.png'},
#   {'teamId': 19,
#    'playerId': 8473534,
#    'firstName': {'default': 'Patrik'},
#    'lastName': {'default': 'Berglund'},
#    'sweaterNumber': 21,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8473534.png'},
#   {'teamId': 16,
#    'playerId': 8473573,
#    'firstName': {'default': 'Artem',
#     'cs': 'Arťom',
#     'fi': 'Artjom',
#     'sk': 'Arťom'},
#    'lastName': {'default': 'Anisimov'},
#    'sweaterNumber': 15,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8473573.png'},
#   {'teamId': 16,
#    'playerId': 8473604,
#    'firstName': {'default': 'Jonathan'},
#    'lastName': {'default': 'Toews'},
#    'sweaterNumber': 19,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8473604.png'},
#   {'teamId': 19,
#    'playerId': 8474031,
#    'firstName': {'default': 'Kevin'},
#    'lastName': {'default': 'Shattenkirk'},
#    'sweaterNumber': 22,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474031.png'},
#   {'teamId': 19,
#    'playerId': 8474102,
#    'firstName': {'default': 'David'},
#    'lastName': {'default': 'Perron'},
#    'sweaterNumber': 57,
#    'positionCode': 'L',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474102.png'},
#   {'teamId': 16,
#    'playerId': 8474141,
#    'firstName': {'default': 'Patrick'},
#    'lastName': {'default': 'Kane'},
#    'sweaterNumber': 88,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8474141.png'},
#   {'teamId': 19,
#    'playerId': 8474145,
#    'firstName': {'default': 'Robert'},
#    'lastName': {'default': 'Bortuzzo'},
#    'sweaterNumber': 41,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474145.png'},
#   {'teamId': 16,
#    'playerId': 8474152,
#    'firstName': {'default': 'Scott'},
#    'lastName': {'default': 'Darling'},
#    'sweaterNumber': 33,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8474152.png'},
#   {'teamId': 19,
#    'playerId': 8474565,
#    'firstName': {'default': 'Alex'},
#    'lastName': {'default': 'Pietrangelo'},
#    'sweaterNumber': 27,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474565.png'},
#   {'teamId': 19,
#    'playerId': 8474596,
#    'firstName': {'default': 'Jake'},
#    'lastName': {'default': 'Allen'},
#    'sweaterNumber': 34,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474596.png'},
#   {'teamId': 19,
#    'playerId': 8474627,
#    'firstName': {'default': 'Jori'},
#    'lastName': {'default': 'Lehtera'},
#    'sweaterNumber': 12,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8474627.png'},
#   {'teamId': 16,
#    'playerId': 8475209,
#    'firstName': {'default': 'Richard'},
#    'lastName': {'default': 'Panik', 'cs': 'Pánik', 'sk': 'Pánik'},
#    'sweaterNumber': 14,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8475209.png'},
#   {'teamId': 16,
#    'playerId': 8475323,
#    'firstName': {'default': 'Marcus'},
#    'lastName': {'default': 'Kruger'},
#    'sweaterNumber': 16,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8475323.png'},
#   {'teamId': 19,
#    'playerId': 8475622,
#    'firstName': {'default': 'Carter'},
#    'lastName': {'default': 'Hutton'},
#    'sweaterNumber': 40,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8475622.png'},
#   {'teamId': 19,
#    'playerId': 8475765,
#    'firstName': {'default': 'Vladimir'},
#    'lastName': {'default': 'Tarasenko'},
#    'sweaterNumber': 91,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8475765.png'},
#   {'teamId': 19,
#    'playerId': 8476436,
#    'firstName': {'default': 'Dmitrij'},
#    'lastName': {'default': 'Jaskin', 'cs': 'Jaškin', 'sk': 'Jaškin'},
#    'sweaterNumber': 23,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8476436.png'},
#   {'teamId': 19,
#    'playerId': 8476441,
#    'firstName': {'default': 'Joel'},
#    'lastName': {'default': 'Edmundson'},
#    'sweaterNumber': 6,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8476441.png'},
#   {'teamId': 19,
#    'playerId': 8476855,
#    'firstName': {'default': 'Nail'},
#    'lastName': {'default': 'Yakupov'},
#    'sweaterNumber': 64,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8476855.png'},
#   {'teamId': 19,
#    'playerId': 8476892,
#    'firstName': {'default': 'Colton'},
#    'lastName': {'default': 'Parayko'},
#    'sweaterNumber': 55,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8476892.png'},
#   {'teamId': 16,
#    'playerId': 8476994,
#    'firstName': {'default': 'Vinnie'},
#    'lastName': {'default': 'Hinostroza'},
#    'sweaterNumber': 48,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8476994.png'},
#   {'teamId': 16,
#    'playerId': 8477353,
#    'firstName': {'default': 'Tyler'},
#    'lastName': {'default': 'Motte'},
#    'sweaterNumber': 64,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8477353.png'},
#   {'teamId': 16,
#    'playerId': 8477451,
#    'firstName': {'default': 'Ryan'},
#    'lastName': {'default': 'Hartman'},
#    'sweaterNumber': 38,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8477451.png'},
#   {'teamId': 16,
#    'playerId': 8477845,
#    'firstName': {'default': 'Trevor'},
#    'lastName': {'default': 'van Riemsdyk'},
#    'sweaterNumber': 57,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8477845.png'},
#   {'teamId': 16,
#    'playerId': 8477951,
#    'firstName': {'default': 'Nick'},
#    'lastName': {'default': 'Schmaltz'},
#    'sweaterNumber': 8,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8477951.png'},
#   {'teamId': 19,
#    'playerId': 8477952,
#    'firstName': {'default': 'Robby'},
#    'lastName': {'default': 'Fabbri'},
#    'sweaterNumber': 15,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/STL/8477952.png'},
#   {'teamId': 16,
#    'playerId': 8478055,
#    'firstName': {'default': 'Gustav'},
#    'lastName': {'default': 'Forsling'},
#    'sweaterNumber': 42,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8478055.png'},
#   {'teamId': 16,
#    'playerId': 8478550,
#    'firstName': {'default': 'Artemi', 'cs': 'Artěmij', 'sk': 'Artemij'},
#    'lastName': {'default': 'Panarin'},
#    'sweaterNumber': 72,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8478550.png'},
#   {'teamId': 16,
#    'playerId': 8479482,
#    'firstName': {'default': 'Michal'},
#    'lastName': {'default': 'Kempny', 'cs': 'Kempný', 'sk': 'Kempný'},
#    'sweaterNumber': 6,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20162017/CHI/8479482.png'}],
#  'regPeriods': 3,
#  'summary': {}}

# %% [markdown]
# ### 2. Téléchargement des matches de 2016 à 2023

# %% [markdown]
# #### **Saisons régulières**. Sauvegarde dans: _data/nhl_reguliere_

# %%
# Utilisation de la classe
downloader = NHLDataDownloader(base_dir='../data/nhl_reguliere')

def download_all_seasons(downloader, start_year, end_year):    
    # Cette partie a seulement relation avec la saison régulière (type 2) 
    """
    Télécharge les données pour des saisons de la LNH.
    :param downloader: Une instance de la classe NHLDataDownloader
    :param year: Année de début de la saison (ex. '2020')
    :param no_of_games: Nombre de matchs à télécharger pour la saison régulière (ex. 1271)
    :param game_type: '02' pour la saison régulière
    """

    for year in range(start_year, end_year + 1):
        year_str = str(year)
        
        # Définir le nombre de matchs en fonction de l'année
        if year_str == '2016':
            no_of_games = 1231  # 1230 matches in 2016
        elif year_str == '2020':
            no_of_games = 869  # 868 matches in 2020 because of covid
        elif year_str in ['2017', '2018', '2019']:
            no_of_games = 1272  # Matches normaux pour ces années
        else:
            no_of_games = 1354  # Pour les années 2021 et après (32 équipes)

        print(f"Téléchargement des données de la saison {year_str} pour {no_of_games} matchs.")

        # Boucler sur les IDs de match pour télécharger les données de la saison régulière (type 02)
        for game_number in range(1, no_of_games + 1):
            game_id = f"{year_str}02{str(game_number).zfill(4)}"  # Format de l'ID de jeu
            game_data = downloader.download_game_data(game_id=game_id)

            # Vérifier le contenu des données téléchargées
            if game_data:
                print(f"Données pour le game_id {game_id} téléchargées avec succès.")
            else:
                print(f"Aucune donnée disponible pour le game_id {game_id}.")

# %%
# Télécharger toutes les saisons de 2016 à 2023
download_all_seasons(downloader, start_year=2016, end_year=2023)
# Out:
# Téléchargement des données de la saison 2016 pour 1231 matchs.
# Fichier 2016020001.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020001 téléchargées avec succès.
# Fichier 2016020002.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020002 téléchargées avec succès.
# Fichier 2016020003.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020003 téléchargées avec succès.
# Fichier 2016020004.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020004 téléchargées avec succès.
# Fichier 2016020005.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020005 téléchargées avec succès.
# Fichier 2016020006.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020006 téléchargées avec succès.
# Fichier 2016020007.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020007 téléchargées avec succès.
# Fichier 2016020008.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020008 téléchargées avec succès.
# Fichier 2016020009.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020009 téléchargées avec succès.
# Fichier 2016020010.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020010 téléchargées avec succès.
# Fichier 2016020011.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020011 téléchargées avec succès.
# Fichier 2016020012.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020012 téléchargées avec succès.
# Fichier 2016020013.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020013 téléchargées avec succès.
# Fichier 2016020014.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020014 téléchargées avec succès.
# Fichier 2016020015.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020015 téléchargées avec succès.
# Fichier 2016020016.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020016 téléchargées avec succès.
# Fichier 2016020017.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020017 téléchargées avec succès.
# Fichier 2016020018.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020018 téléchargées avec succès.
# Fichier 2016020019.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020019 téléchargées avec succès.
# Fichier 2016020020.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020020 téléchargées avec succès.
# Fichier 2016020021.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020021 téléchargées avec succès.
# Fichier 2016020022.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020022 téléchargées avec succès.
# Fichier 2016020023.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020023 téléchargées avec succès.
# Fichier 2016020024.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020024 téléchargées avec succès.
# Fichier 2016020025.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020025 téléchargées avec succès.
# Fichier 2016020026.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020026 téléchargées avec succès.
# Fichier 2016020027.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020027 téléchargées avec succès.
# Fichier 2016020028.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020028 téléchargées avec succès.
# Fichier 2016020029.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020029 téléchargées avec succès.
# Fichier 2016020030.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020030 téléchargées avec succès.
# Fichier 2016020031.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020031 téléchargées avec succès.
# Fichier 2016020032.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020032 téléchargées avec succès.
# Fichier 2016020033.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020033 téléchargées avec succès.
# Fichier 2016020034.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020034 téléchargées avec succès.
# Fichier 2016020035.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020035 téléchargées avec succès.
# Fichier 2016020036.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020036 téléchargées avec succès.
# Fichier 2016020037.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020037 téléchargées avec succès.
# Fichier 2016020038.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020038 téléchargées avec succès.
# Fichier 2016020039.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020039 téléchargées avec succès.
# Fichier 2016020040.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020040 téléchargées avec succès.
# Fichier 2016020041.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020041 téléchargées avec succès.
# Fichier 2016020042.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020042 téléchargées avec succès.
# Fichier 2016020043.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020043 téléchargées avec succès.
# Fichier 2016020044.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020044 téléchargées avec succès.
# Fichier 2016020045.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020045 téléchargées avec succès.
# Fichier 2016020046.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020046 téléchargées avec succès.
# Fichier 2016020047.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020047 téléchargées avec succès.
# Fichier 2016020048.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020048 téléchargées avec succès.
# Fichier 2016020049.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020049 téléchargées avec succès.
# Fichier 2016020050.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020050 téléchargées avec succès.
# Fichier 2016020051.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020051 téléchargées avec succès.
# Fichier 2016020052.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020052 téléchargées avec succès.
# Fichier 2016020053.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020053 téléchargées avec succès.
# Fichier 2016020054.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020054 téléchargées avec succès.
# Fichier 2016020055.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020055 téléchargées avec succès.
# Fichier 2016020056.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020056 téléchargées avec succès.
# Fichier 2016020057.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020057 téléchargées avec succès.
# Fichier 2016020058.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020058 téléchargées avec succès.
# Fichier 2016020059.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020059 téléchargées avec succès.
# Fichier 2016020060.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020060 téléchargées avec succès.
# Fichier 2016020061.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020061 téléchargées avec succès.
# Fichier 2016020062.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020062 téléchargées avec succès.
# Fichier 2016020063.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020063 téléchargées avec succès.
# Fichier 2016020064.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020064 téléchargées avec succès.
# Fichier 2016020065.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020065 téléchargées avec succès.
# Fichier 2016020066.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020066 téléchargées avec succès.
# Fichier 2016020067.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020067 téléchargées avec succès.
# Fichier 2016020068.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020068 téléchargées avec succès.
# Fichier 2016020069.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020069 téléchargées avec succès.
# Fichier 2016020070.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020070 téléchargées avec succès.
# Fichier 2016020071.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020071 téléchargées avec succès.
# Fichier 2016020072.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020072 téléchargées avec succès.
# Fichier 2016020073.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020073 téléchargées avec succès.
# Fichier 2016020074.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020074 téléchargées avec succès.
# Fichier 2016020075.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020075 téléchargées avec succès.
# Fichier 2016020076.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020076 téléchargées avec succès.
# Fichier 2016020077.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020077 téléchargées avec succès.
# Fichier 2016020078.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020078 téléchargées avec succès.
# Fichier 2016020079.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020079 téléchargées avec succès.
# Fichier 2016020080.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020080 téléchargées avec succès.
# Fichier 2016020081.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020081 téléchargées avec succès.
# Fichier 2016020082.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020082 téléchargées avec succès.
# Fichier 2016020083.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020083 téléchargées avec succès.
# Fichier 2016020084.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020084 téléchargées avec succès.
# Fichier 2016020085.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020085 téléchargées avec succès.
# Fichier 2016020086.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020086 téléchargées avec succès.
# Fichier 2016020087.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020087 téléchargées avec succès.
# Fichier 2016020088.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020088 téléchargées avec succès.
# Fichier 2016020089.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020089 téléchargées avec succès.
# Fichier 2016020090.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020090 téléchargées avec succès.
# Fichier 2016020091.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020091 téléchargées avec succès.
# Fichier 2016020092.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020092 téléchargées avec succès.
# Fichier 2016020093.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020093 téléchargées avec succès.
# Fichier 2016020094.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020094 téléchargées avec succès.
# Fichier 2016020095.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020095 téléchargées avec succès.
# Fichier 2016020096.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020096 téléchargées avec succès.
# Fichier 2016020097.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020097 téléchargées avec succès.
# Fichier 2016020098.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020098 téléchargées avec succès.
# Fichier 2016020099.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020099 téléchargées avec succès.
# Fichier 2016020100.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020100 téléchargées avec succès.
# Fichier 2016020101.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020101 téléchargées avec succès.
# Fichier 2016020102.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020102 téléchargées avec succès.
# Fichier 2016020103.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020103 téléchargées avec succès.
# Fichier 2016020104.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020104 téléchargées avec succès.
# Fichier 2016020105.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020105 téléchargées avec succès.
# Fichier 2016020106.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020106 téléchargées avec succès.
# Fichier 2016020107.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020107 téléchargées avec succès.
# Fichier 2016020108.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020108 téléchargées avec succès.
# Fichier 2016020109.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020109 téléchargées avec succès.
# Fichier 2016020110.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020110 téléchargées avec succès.
# Fichier 2016020111.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020111 téléchargées avec succès.
# Fichier 2016020112.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020112 téléchargées avec succès.
# Fichier 2016020113.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020113 téléchargées avec succès.
# Fichier 2016020114.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020114 téléchargées avec succès.
# Fichier 2016020115.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020115 téléchargées avec succès.
# Fichier 2016020116.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020116 téléchargées avec succès.
# Fichier 2016020117.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020117 téléchargées avec succès.
# Fichier 2016020118.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020118 téléchargées avec succès.
# Fichier 2016020119.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020119 téléchargées avec succès.
# Fichier 2016020120.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020120 téléchargées avec succès.
# Fichier 2016020121.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020121 téléchargées avec succès.
# Fichier 2016020122.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020122 téléchargées avec succès.
# Fichier 2016020123.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020123 téléchargées avec succès.
# Fichier 2016020124.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020124 téléchargées avec succès.
# Fichier 2016020125.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020125 téléchargées avec succès.
# Fichier 2016020126.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020126 téléchargées avec succès.
# Fichier 2016020127.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020127 téléchargées avec succès.
# Fichier 2016020128.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020128 téléchargées avec succès.
# Fichier 2016020129.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020129 téléchargées avec succès.
# Fichier 2016020130.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020130 téléchargées avec succès.
# Fichier 2016020131.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020131 téléchargées avec succès.
# Fichier 2016020132.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020132 téléchargées avec succès.
# Fichier 2016020133.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020133 téléchargées avec succès.
# Fichier 2016020134.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020134 téléchargées avec succès.
# Fichier 2016020135.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020135 téléchargées avec succès.
# Fichier 2016020136.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020136 téléchargées avec succès.
# Fichier 2016020137.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020137 téléchargées avec succès.
# Fichier 2016020138.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020138 téléchargées avec succès.
# Fichier 2016020139.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020139 téléchargées avec succès.
# Fichier 2016020140.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020140 téléchargées avec succès.
# Fichier 2016020141.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020141 téléchargées avec succès.
# Fichier 2016020142.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020142 téléchargées avec succès.
# Fichier 2016020143.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020143 téléchargées avec succès.
# Fichier 2016020144.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020144 téléchargées avec succès.
# Fichier 2016020145.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020145 téléchargées avec succès.
# Fichier 2016020146.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020146 téléchargées avec succès.
# Fichier 2016020147.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020147 téléchargées avec succès.
# Fichier 2016020148.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020148 téléchargées avec succès.
# Fichier 2016020149.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020149 téléchargées avec succès.
# Fichier 2016020150.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020150 téléchargées avec succès.
# Fichier 2016020151.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020151 téléchargées avec succès.
# Fichier 2016020152.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020152 téléchargées avec succès.
# Fichier 2016020153.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020153 téléchargées avec succès.
# Fichier 2016020154.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020154 téléchargées avec succès.
# Fichier 2016020155.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020155 téléchargées avec succès.
# Fichier 2016020156.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020156 téléchargées avec succès.
# Fichier 2016020157.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020157 téléchargées avec succès.
# Fichier 2016020158.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020158 téléchargées avec succès.
# Fichier 2016020159.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020159 téléchargées avec succès.
# Fichier 2016020160.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020160 téléchargées avec succès.
# Fichier 2016020161.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020161 téléchargées avec succès.
# Fichier 2016020162.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020162 téléchargées avec succès.
# Fichier 2016020163.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020163 téléchargées avec succès.
# Fichier 2016020164.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020164 téléchargées avec succès.
# Fichier 2016020165.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020165 téléchargées avec succès.
# Fichier 2016020166.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020166 téléchargées avec succès.
# Fichier 2016020167.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020167 téléchargées avec succès.
# Fichier 2016020168.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020168 téléchargées avec succès.
# Fichier 2016020169.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020169 téléchargées avec succès.
# Fichier 2016020170.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020170 téléchargées avec succès.
# Fichier 2016020171.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020171 téléchargées avec succès.
# Fichier 2016020172.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020172 téléchargées avec succès.
# Fichier 2016020173.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020173 téléchargées avec succès.
# Fichier 2016020174.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020174 téléchargées avec succès.
# Fichier 2016020175.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020175 téléchargées avec succès.
# Fichier 2016020176.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020176 téléchargées avec succès.
# Fichier 2016020177.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020177 téléchargées avec succès.
# Fichier 2016020178.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020178 téléchargées avec succès.
# Fichier 2016020179.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020179 téléchargées avec succès.
# Fichier 2016020180.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020180 téléchargées avec succès.
# Fichier 2016020181.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020181 téléchargées avec succès.
# Fichier 2016020182.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020182 téléchargées avec succès.
# Fichier 2016020183.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020183 téléchargées avec succès.
# Fichier 2016020184.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020184 téléchargées avec succès.
# Fichier 2016020185.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020185 téléchargées avec succès.
# Fichier 2016020186.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020186 téléchargées avec succès.
# Fichier 2016020187.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020187 téléchargées avec succès.
# Fichier 2016020188.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020188 téléchargées avec succès.
# Fichier 2016020189.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020189 téléchargées avec succès.
# Fichier 2016020190.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020190 téléchargées avec succès.
# Fichier 2016020191.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020191 téléchargées avec succès.
# Fichier 2016020192.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020192 téléchargées avec succès.
# Fichier 2016020193.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020193 téléchargées avec succès.
# Fichier 2016020194.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020194 téléchargées avec succès.
# Fichier 2016020195.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020195 téléchargées avec succès.
# Fichier 2016020196.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020196 téléchargées avec succès.
# Fichier 2016020197.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020197 téléchargées avec succès.
# Fichier 2016020198.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020198 téléchargées avec succès.
# Fichier 2016020199.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020199 téléchargées avec succès.
# Fichier 2016020200.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020200 téléchargées avec succès.
# Fichier 2016020201.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020201 téléchargées avec succès.
# Fichier 2016020202.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020202 téléchargées avec succès.
# Fichier 2016020203.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020203 téléchargées avec succès.
# Fichier 2016020204.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020204 téléchargées avec succès.
# Fichier 2016020205.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020205 téléchargées avec succès.
# Fichier 2016020206.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020206 téléchargées avec succès.
# Fichier 2016020207.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020207 téléchargées avec succès.
# Fichier 2016020208.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020208 téléchargées avec succès.
# Fichier 2016020209.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020209 téléchargées avec succès.
# Fichier 2016020210.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020210 téléchargées avec succès.
# Fichier 2016020211.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020211 téléchargées avec succès.
# Fichier 2016020212.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020212 téléchargées avec succès.
# Fichier 2016020213.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020213 téléchargées avec succès.
# Fichier 2016020214.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020214 téléchargées avec succès.
# Fichier 2016020215.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020215 téléchargées avec succès.
# Fichier 2016020216.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020216 téléchargées avec succès.
# Fichier 2016020217.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020217 téléchargées avec succès.
# Fichier 2016020218.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020218 téléchargées avec succès.
# Fichier 2016020219.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020219 téléchargées avec succès.
# Fichier 2016020220.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020220 téléchargées avec succès.
# Fichier 2016020221.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020221 téléchargées avec succès.
# Fichier 2016020222.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020222 téléchargées avec succès.
# Fichier 2016020223.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020223 téléchargées avec succès.
# Fichier 2016020224.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020224 téléchargées avec succès.
# Fichier 2016020225.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020225 téléchargées avec succès.
# Fichier 2016020226.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020226 téléchargées avec succès.
# Fichier 2016020227.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020227 téléchargées avec succès.
# Fichier 2016020228.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020228 téléchargées avec succès.
# Fichier 2016020229.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020229 téléchargées avec succès.
# Fichier 2016020230.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020230 téléchargées avec succès.
# Fichier 2016020231.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020231 téléchargées avec succès.
# Fichier 2016020232.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020232 téléchargées avec succès.
# Fichier 2016020233.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020233 téléchargées avec succès.
# Fichier 2016020234.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020234 téléchargées avec succès.
# Fichier 2016020235.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020235 téléchargées avec succès.
# Fichier 2016020236.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020236 téléchargées avec succès.
# Fichier 2016020237.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020237 téléchargées avec succès.
# Fichier 2016020238.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020238 téléchargées avec succès.
# Fichier 2016020239.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020239 téléchargées avec succès.
# Fichier 2016020240.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020240 téléchargées avec succès.
# Fichier 2016020241.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020241 téléchargées avec succès.
# Fichier 2016020242.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020242 téléchargées avec succès.
# Fichier 2016020243.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020243 téléchargées avec succès.
# Fichier 2016020244.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020244 téléchargées avec succès.
# Fichier 2016020245.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020245 téléchargées avec succès.
# Fichier 2016020246.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020246 téléchargées avec succès.
# Fichier 2016020247.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020247 téléchargées avec succès.
# Fichier 2016020248.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020248 téléchargées avec succès.
# Fichier 2016020249.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020249 téléchargées avec succès.
# Fichier 2016020250.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020250 téléchargées avec succès.
# Fichier 2016020251.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020251 téléchargées avec succès.
# Fichier 2016020252.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020252 téléchargées avec succès.
# Fichier 2016020253.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020253 téléchargées avec succès.
# Fichier 2016020254.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020254 téléchargées avec succès.
# Fichier 2016020255.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020255 téléchargées avec succès.
# Fichier 2016020256.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020256 téléchargées avec succès.
# Fichier 2016020257.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020257 téléchargées avec succès.
# Fichier 2016020258.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020258 téléchargées avec succès.
# Fichier 2016020259.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020259 téléchargées avec succès.
# Fichier 2016020260.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020260 téléchargées avec succès.
# Fichier 2016020261.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020261 téléchargées avec succès.
# Fichier 2016020262.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020262 téléchargées avec succès.
# Fichier 2016020263.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020263 téléchargées avec succès.
# Fichier 2016020264.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020264 téléchargées avec succès.
# Fichier 2016020265.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020265 téléchargées avec succès.
# Fichier 2016020266.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020266 téléchargées avec succès.
# Fichier 2016020267.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020267 téléchargées avec succès.
# Fichier 2016020268.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020268 téléchargées avec succès.
# Fichier 2016020269.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020269 téléchargées avec succès.
# Fichier 2016020270.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020270 téléchargées avec succès.
# Fichier 2016020271.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020271 téléchargées avec succès.
# Fichier 2016020272.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020272 téléchargées avec succès.
# Fichier 2016020273.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020273 téléchargées avec succès.
# Fichier 2016020274.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020274 téléchargées avec succès.
# Fichier 2016020275.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020275 téléchargées avec succès.
# Fichier 2016020276.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020276 téléchargées avec succès.
# Fichier 2016020277.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020277 téléchargées avec succès.
# Fichier 2016020278.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020278 téléchargées avec succès.
# Fichier 2016020279.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020279 téléchargées avec succès.
# Fichier 2016020280.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020280 téléchargées avec succès.
# Fichier 2016020281.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020281 téléchargées avec succès.
# Fichier 2016020282.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020282 téléchargées avec succès.
# Fichier 2016020283.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020283 téléchargées avec succès.
# Fichier 2016020284.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020284 téléchargées avec succès.
# Fichier 2016020285.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020285 téléchargées avec succès.
# Fichier 2016020286.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020286 téléchargées avec succès.
# Fichier 2016020287.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020287 téléchargées avec succès.
# Fichier 2016020288.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020288 téléchargées avec succès.
# Fichier 2016020289.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020289 téléchargées avec succès.
# Fichier 2016020290.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020290 téléchargées avec succès.
# Fichier 2016020291.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020291 téléchargées avec succès.
# Fichier 2016020292.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020292 téléchargées avec succès.
# Fichier 2016020293.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020293 téléchargées avec succès.
# Fichier 2016020294.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020294 téléchargées avec succès.
# Fichier 2016020295.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020295 téléchargées avec succès.
# Fichier 2016020296.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020296 téléchargées avec succès.
# Fichier 2016020297.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020297 téléchargées avec succès.
# Fichier 2016020298.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020298 téléchargées avec succès.
# Fichier 2016020299.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020299 téléchargées avec succès.
# Fichier 2016020300.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020300 téléchargées avec succès.
# Fichier 2016020301.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020301 téléchargées avec succès.
# Fichier 2016020302.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020302 téléchargées avec succès.
# Fichier 2016020303.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020303 téléchargées avec succès.
# Fichier 2016020304.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020304 téléchargées avec succès.
# Fichier 2016020305.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020305 téléchargées avec succès.
# Fichier 2016020306.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020306 téléchargées avec succès.
# Fichier 2016020307.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020307 téléchargées avec succès.
# Fichier 2016020308.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020308 téléchargées avec succès.
# Fichier 2016020309.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020309 téléchargées avec succès.
# Fichier 2016020310.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020310 téléchargées avec succès.
# Fichier 2016020311.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020311 téléchargées avec succès.
# Fichier 2016020312.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020312 téléchargées avec succès.
# Fichier 2016020313.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020313 téléchargées avec succès.
# Fichier 2016020314.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020314 téléchargées avec succès.
# Fichier 2016020315.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020315 téléchargées avec succès.
# Fichier 2016020316.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020316 téléchargées avec succès.
# Fichier 2016020317.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020317 téléchargées avec succès.
# Fichier 2016020318.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020318 téléchargées avec succès.
# Fichier 2016020319.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020319 téléchargées avec succès.
# Fichier 2016020320.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020320 téléchargées avec succès.
# Fichier 2016020321.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020321 téléchargées avec succès.
# Fichier 2016020322.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020322 téléchargées avec succès.
# Fichier 2016020323.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020323 téléchargées avec succès.
# Fichier 2016020324.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020324 téléchargées avec succès.
# Fichier 2016020325.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020325 téléchargées avec succès.
# Fichier 2016020326.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020326 téléchargées avec succès.
# Fichier 2016020327.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020327 téléchargées avec succès.
# Fichier 2016020328.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020328 téléchargées avec succès.
# Fichier 2016020329.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020329 téléchargées avec succès.
# Fichier 2016020330.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020330 téléchargées avec succès.
# Fichier 2016020331.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020331 téléchargées avec succès.
# Fichier 2016020332.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020332 téléchargées avec succès.
# Fichier 2016020333.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020333 téléchargées avec succès.
# Fichier 2016020334.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020334 téléchargées avec succès.
# Fichier 2016020335.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020335 téléchargées avec succès.
# Fichier 2016020336.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020336 téléchargées avec succès.
# Fichier 2016020337.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020337 téléchargées avec succès.
# Fichier 2016020338.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020338 téléchargées avec succès.
# Fichier 2016020339.json déjà existant dans le répertoire ../data/nhl_reguliere.
# Données pour le game_id 2016020339 téléchargées avec succès.
# Fichier 2016020340.json déjà existant dans le répertoire ../data/nhl_reguliere.
# ...
# Téléchargé et enregistré : 2017020097.json
# Données pour le game_id 2017020097 téléchargées avec succès.
# Téléchargé et enregistré : 2017020098.json
# Données pour le game_id 2017020098 téléchargées avec succès.
# Téléchargé et enregistré : 2017020099.json
# Données pour le game_id 2017020099 téléchargées avec succès.
# Téléchargé et enregistré : 2017020100.json
# Données pour le game_id 2017020100 téléchargées avec succès.
# Téléchargé et enregistré : 2017020101.json
# Données pour le game_id 2017020101 téléchargées avec succès.
# Téléchargé et enregistré : 2017020102.json
# Données pour le game_id 2017020102 téléchargées avec succès.
# Téléchargé et enregistré : 2017020103.json
# Données pour le game_id 2017020103 téléchargées avec succès.
# Téléchargé et enregistré : 2017020104.json
# Données pour le game_id 2017020104 téléchargées avec succès.
# Téléchargé et enregistré : 2017020105.json
# Données pour le game_id 2017020105 téléchargées avec succès.
# Téléchargé et enregistré : 2017020106.json
# Données pour le game_id 2017020106 téléchargées avec succès.
# Téléchargé et enregistré : 2017020107.json
# Données pour le game_id 2017020107 téléchargées avec succès.
# Téléchargé et enregistré : 2017020108.json
# Données pour le game_id 2017020108 téléchargées avec succès.
# Téléchargé et enregistré : 2017020109.json
# Données pour le game_id 2017020109 téléchargées avec succès.
# Téléchargé et enregistré : 2017020110.json
# Données pour le game_id 2017020110 téléchargées avec succès.
# Téléchargé et enregistré : 2017020111.json
# Données pour le game_id 2017020111 téléchargées avec succès.
# Téléchargé et enregistré : 2017020112.json
# Données pour le game_id 2017020112 téléchargées avec succès.
# Téléchargé et enregistré : 2017020113.json
# Données pour le game_id 2017020113 téléchargées avec succès.
# Téléchargé et enregistré : 2017020114.json
# Données pour le game_id 2017020114 téléchargées avec succès.
# Téléchargé et enregistré : 2017020115.json
# Données pour le game_id 2017020115 téléchargées avec succès.
# Téléchargé et enregistré : 2017020116.json
# Données pour le game_id 2017020116 téléchargées avec succès.
# Téléchargé et enregistré : 2017020117.json
# Données pour le game_id 2017020117 téléchargées avec succès.
# Téléchargé et enregistré : 2017020118.json
# Données pour le game_id 2017020118 téléchargées avec succès.
# Téléchargé et enregistré : 2017020119.json
# Données pour le game_id 2017020119 téléchargées avec succès.
# Téléchargé et enregistré : 2017020120.json
# Données pour le game_id 2017020120 téléchargées avec succès.
# Téléchargé et enregistré : 2017020121.json
# Données pour le game_id 2017020121 téléchargées avec succès.
# Téléchargé et enregistré : 2017020122.json
# Données pour le game_id 2017020122 téléchargées avec succès.
# Téléchargé et enregistré : 2017020123.json
# Données pour le game_id 2017020123 téléchargées avec succès.
# Téléchargé et enregistré : 2017020124.json
# Données pour le game_id 2017020124 téléchargées avec succès.
# Téléchargé et enregistré : 2017020125.json
# Données pour le game_id 2017020125 téléchargées avec succès.
# Téléchargé et enregistré : 2017020126.json
# Données pour le game_id 2017020126 téléchargées avec succès.
# Téléchargé et enregistré : 2017020127.json
# Données pour le game_id 2017020127 téléchargées avec succès.
# Téléchargé et enregistré : 2017020128.json
# Données pour le game_id 2017020128 téléchargées avec succès.
# Téléchargé et enregistré : 2017020129.json
# Données pour le game_id 2017020129 téléchargées avec succès.
# Téléchargé et enregistré : 2017020130.json
# Données pour le game_id 2017020130 téléchargées avec succès.
# Téléchargé et enregistré : 2017020131.json
# Données pour le game_id 2017020131 téléchargées avec succès.
# Téléchargé et enregistré : 2017020132.json
# Données pour le game_id 2017020132 téléchargées avec succès.
# Téléchargé et enregistré : 2017020133.json
# Données pour le game_id 2017020133 téléchargées avec succès.
# Téléchargé et enregistré : 2017020134.json
# Données pour le game_id 2017020134 téléchargées avec succès.
# Téléchargé et enregistré : 2017020135.json
# Données pour le game_id 2017020135 téléchargées avec succès.
# Téléchargé et enregistré : 2017020136.json
# Données pour le game_id 2017020136 téléchargées avec succès.
# Téléchargé et enregistré : 2017020137.json
# Données pour le game_id 2017020137 téléchargées avec succès.
# Téléchargé et enregistré : 2017020138.json
# Données pour le game_id 2017020138 téléchargées avec succès.
# Téléchargé et enregistré : 2017020139.json
# Données pour le game_id 2017020139 téléchargées avec succès.
# Téléchargé et enregistré : 2017020140.json
# Données pour le game_id 2017020140 téléchargées avec succès.
# Téléchargé et enregistré : 2017020141.json
# Données pour le game_id 2017020141 téléchargées avec succès.
# Téléchargé et enregistré : 2017020142.json
# Données pour le game_id 2017020142 téléchargées avec succès.
# Téléchargé et enregistré : 2017020143.json
# Données pour le game_id 2017020143 téléchargées avec succès.
# Téléchargé et enregistré : 2017020144.json
# Données pour le game_id 2017020144 téléchargées avec succès.
# Téléchargé et enregistré : 2017020145.json
# Données pour le game_id 2017020145 téléchargées avec succès.
# Téléchargé et enregistré : 2017020146.json
# Données pour le game_id 2017020146 téléchargées avec succès.
# Téléchargé et enregistré : 2017020147.json
# Données pour le game_id 2017020147 téléchargées avec succès.
# Téléchargé et enregistré : 2017020148.json
# Données pour le game_id 2017020148 téléchargées avec succès.
# Téléchargé et enregistré : 2017020149.json
# Données pour le game_id 2017020149 téléchargées avec succès.
# Téléchargé et enregistré : 2017020150.json
# Données pour le game_id 2017020150 téléchargées avec succès.
# Téléchargé et enregistré : 2017020151.json
# Données pour le game_id 2017020151 téléchargées avec succès.
# Téléchargé et enregistré : 2017020152.json
# Données pour le game_id 2017020152 téléchargées avec succès.
# Téléchargé et enregistré : 2017020153.json
# Données pour le game_id 2017020153 téléchargées avec succès.
# Téléchargé et enregistré : 2017020154.json
# Données pour le game_id 2017020154 téléchargées avec succès.
# Téléchargé et enregistré : 2017020155.json
# Données pour le game_id 2017020155 téléchargées avec succès.
# Téléchargé et enregistré : 2017020156.json
# Données pour le game_id 2017020156 téléchargées avec succès.
# Téléchargé et enregistré : 2017020157.json
# Données pour le game_id 2017020157 téléchargées avec succès.
# Téléchargé et enregistré : 2017020158.json
# Données pour le game_id 2017020158 téléchargées avec succès.
# Téléchargé et enregistré : 2017020159.json
# Données pour le game_id 2017020159 téléchargées avec succès.
# Téléchargé et enregistré : 2017020160.json
# Données pour le game_id 2017020160 téléchargées avec succès.
# Téléchargé et enregistré : 2017020161.json
# Données pour le game_id 2017020161 téléchargées avec succès.
# Téléchargé et enregistré : 2017020162.json
# Données pour le game_id 2017020162 téléchargées avec succès.
# Téléchargé et enregistré : 2017020163.json
# Données pour le game_id 2017020163 téléchargées avec succès.
# Téléchargé et enregistré : 2017020164.json
# Données pour le game_id 2017020164 téléchargées avec succès.
# Téléchargé et enregistré : 2017020165.json
# Données pour le game_id 2017020165 téléchargées avec succès.
# Téléchargé et enregistré : 2017020166.json
# Données pour le game_id 2017020166 téléchargées avec succès.
# Téléchargé et enregistré : 2017020167.json
# Données pour le game_id 2017020167 téléchargées avec succès.
# Téléchargé et enregistré : 2017020168.json
# Données pour le game_id 2017020168 téléchargées avec succès.
# Téléchargé et enregistré : 2017020169.json
# Données pour le game_id 2017020169 téléchargées avec succès.
# Téléchargé et enregistré : 2017020170.json
# Données pour le game_id 2017020170 téléchargées avec succès.
# Téléchargé et enregistré : 2017020171.json
# Données pour le game_id 2017020171 téléchargées avec succès.
# Téléchargé et enregistré : 2017020172.json
# Données pour le game_id 2017020172 téléchargées avec succès.
# Téléchargé et enregistré : 2017020173.json
# Données pour le game_id 2017020173 téléchargées avec succès.
# Téléchargé et enregistré : 2017020174.json
# Données pour le game_id 2017020174 téléchargées avec succès.
# Téléchargé et enregistré : 2017020175.json
# Données pour le game_id 2017020175 téléchargées avec succès.
# Téléchargé et enregistré : 2017020176.json
# Données pour le game_id 2017020176 téléchargées avec succès.
# Téléchargé et enregistré : 2017020177.json
# Données pour le game_id 2017020177 téléchargées avec succès.
# Téléchargé et enregistré : 2017020178.json
# Données pour le game_id 2017020178 téléchargées avec succès.
# Téléchargé et enregistré : 2017020179.json
# Données pour le game_id 2017020179 téléchargées avec succès.
# Téléchargé et enregistré : 2017020180.json
# Données pour le game_id 2017020180 téléchargées avec succès.
# Téléchargé et enregistré : 2017020181.json
# Données pour le game_id 2017020181 téléchargées avec succès.
# Téléchargé et enregistré : 2017020182.json
# Données pour le game_id 2017020182 téléchargées avec succès.
# Téléchargé et enregistré : 2017020183.json
# Données pour le game_id 2017020183 téléchargées avec succès.
# Téléchargé et enregistré : 2017020184.json
# Données pour le game_id 2017020184 téléchargées avec succès.
# Téléchargé et enregistré : 2017020185.json
# Données pour le game_id 2017020185 téléchargées avec succès.
# Téléchargé et enregistré : 2017020186.json
# Données pour le game_id 2017020186 téléchargées avec succès.
# Téléchargé et enregistré : 2017020187.json
# Données pour le game_id 2017020187 téléchargées avec succès.
# Téléchargé et enregistré : 2017020188.json
# Données pour le game_id 2017020188 téléchargées avec succès.
# Téléchargé et enregistré : 2017020189.json
# Données pour le game_id 2017020189 téléchargées avec succès.
# Téléchargé et enregistré : 2017020190.json
# Données pour le game_id 2017020190 téléchargées avec succès.
# Téléchargé et enregistré : 2017020191.json
# Données pour le game_id 2017020191 téléchargées avec succès.
# Téléchargé et enregistré : 2017020192.json
# Données pour le game_id 2017020192 téléchargées avec succès.
# Téléchargé et enregistré : 2017020193.json
# Données pour le game_id 2017020193 téléchargées avec succès.
# Téléchargé et enregistré : 2017020194.json
# Données pour le game_id 2017020194 téléchargées avec succès.
# Téléchargé et enregistré : 2017020195.json
# Données pour le game_id 2017020195 téléchargées avec succès.
# Téléchargé et enregistré : 2017020196.json
# Données pour le game_id 2017020196 téléchargées avec succès.
# Téléchargé et enregistré : 2017020197.json
# Données pour le game_id 2017020197 téléchargées avec succès.
# Téléchargé et enregistré : 2017020198.json
# Données pour le game_id 2017020198 téléchargées avec succès.
# Téléchargé et enregistré : 2017020199.json
# Données pour le game_id 2017020199 téléchargées avec succès.
# Téléchargé et enregistré : 2017020200.json
# Données pour le game_id 2017020200 téléchargées avec succès.
# Téléchargé et enregistré : 2017020201.json
# Données pour le game_id 2017020201 téléchargées avec succès.
# Téléchargé et enregistré : 2017020202.json
# Données pour le game_id 2017020202 téléchargées avec succès.
# Téléchargé et enregistré : 2017020203.json
# Données pour le game_id 2017020203 téléchargées avec succès.
# Téléchargé et enregistré : 2017020204.json
# Données pour le game_id 2017020204 téléchargées avec succès.
# Téléchargé et enregistré : 2017020205.json
# Données pour le game_id 2017020205 téléchargées avec succès.
# Téléchargé et enregistré : 2017020206.json
# Données pour le game_id 2017020206 téléchargées avec succès.
# Téléchargé et enregistré : 2017020207.json
# Données pour le game_id 2017020207 téléchargées avec succès.
# Téléchargé et enregistré : 2017020208.json
# Données pour le game_id 2017020208 téléchargées avec succès.
# Téléchargé et enregistré : 2017020209.json
# Données pour le game_id 2017020209 téléchargées avec succès.
# Téléchargé et enregistré : 2017020210.json
# Données pour le game_id 2017020210 téléchargées avec succès.
# Téléchargé et enregistré : 2017020211.json
# Données pour le game_id 2017020211 téléchargées avec succès.
# Téléchargé et enregistré : 2017020212.json
# Données pour le game_id 2017020212 téléchargées avec succès.
# Téléchargé et enregistré : 2017020213.json
# Données pour le game_id 2017020213 téléchargées avec succès.
# Téléchargé et enregistré : 2017020214.json
# Données pour le game_id 2017020214 téléchargées avec succès.
# Téléchargé et enregistré : 2017020215.json
# Données pour le game_id 2017020215 téléchargées avec succès.
# Téléchargé et enregistré : 2017020216.json
# Données pour le game_id 2017020216 téléchargées avec succès.
# Téléchargé et enregistré : 2017020217.json
# Données pour le game_id 2017020217 téléchargées avec succès.
# Téléchargé et enregistré : 2017020218.json
# Données pour le game_id 2017020218 téléchargées avec succès.
# Téléchargé et enregistré : 2017020219.json
# Données pour le game_id 2017020219 téléchargées avec succès.
# Téléchargé et enregistré : 2017020220.json
# Données pour le game_id 2017020220 téléchargées avec succès.
# Téléchargé et enregistré : 2017020221.json
# Données pour le game_id 2017020221 téléchargées avec succès.
# Téléchargé et enregistré : 2017020222.json
# Données pour le game_id 2017020222 téléchargées avec succès.
# Téléchargé et enregistré : 2017020223.json
# Données pour le game_id 2017020223 téléchargées avec succès.
# Téléchargé et enregistré : 2017020224.json
# Données pour le game_id 2017020224 téléchargées avec succès.
# Téléchargé et enregistré : 2017020225.json
# Données pour le game_id 2017020225 téléchargées avec succès.
# Téléchargé et enregistré : 2017020226.json
# Données pour le game_id 2017020226 téléchargées avec succès.
# Téléchargé et enregistré : 2017020227.json
# Données pour le game_id 2017020227 téléchargées avec succès.
# Téléchargé et enregistré : 2017020228.json
# Données pour le game_id 2017020228 téléchargées avec succès.
# Téléchargé et enregistré : 2017020229.json
# Données pour le game_id 2017020229 téléchargées avec succès.
# Téléchargé et enregistré : 2017020230.json
# Données pour le game_id 2017020230 téléchargées avec succès.
# Téléchargé et enregistré : 2017020231.json
# Données pour le game_id 2017020231 téléchargées avec succès.
# Téléchargé et enregistré : 2017020232.json
# Données pour le game_id 2017020232 téléchargées avec succès.
# Téléchargé et enregistré : 2017020233.json
# Données pour le game_id 2017020233 téléchargées avec succès.
# Téléchargé et enregistré : 2017020234.json
# Données pour le game_id 2017020234 téléchargées avec succès.
# Téléchargé et enregistré : 2017020235.json
# Données pour le game_id 2017020235 téléchargées avec succès.
# Téléchargé et enregistré : 2017020236.json
# Données pour le game_id 2017020236 téléchargées avec succès.
# Téléchargé et enregistré : 2017020237.json
# Données pour le game_id 2017020237 téléchargées avec succès.
# Téléchargé et enregistré : 2017020238.json
# Données pour le game_id 2017020238 téléchargées avec succès.
# Téléchargé et enregistré : 2017020239.json
# Données pour le game_id 2017020239 téléchargées avec succès.
# Téléchargé et enregistré : 2017020240.json
# Données pour le game_id 2017020240 téléchargées avec succès.
# Téléchargé et enregistré : 2017020241.json
# Données pour le game_id 2017020241 téléchargées avec succès.
# Téléchargé et enregistré : 2017020242.json
# Données pour le game_id 2017020242 téléchargées avec succès.
# Téléchargé et enregistré : 2017020243.json
# Données pour le game_id 2017020243 téléchargées avec succès.
# Téléchargé et enregistré : 2017020244.json
# Données pour le game_id 2017020244 téléchargées avec succès.
# Téléchargé et enregistré : 2017020245.json
# Données pour le game_id 2017020245 téléchargées avec succès.
# Téléchargé et enregistré : 2017020246.json
# Données pour le game_id 2017020246 téléchargées avec succès.
# Téléchargé et enregistré : 2017020247.json
# Données pour le game_id 2017020247 téléchargées avec succès.
# Téléchargé et enregistré : 2017020248.json
# Données pour le game_id 2017020248 téléchargées avec succès.
# Téléchargé et enregistré : 2017020249.json
# Données pour le game_id 2017020249 téléchargées avec succès.
# Téléchargé et enregistré : 2017020250.json

# %% [markdown]
# #### **Playoffs**. Sauvegarde dans: _data/nhl_playoffs_

# %%
# Utilisation de la classe
downloader = NHLDataDownloader(base_dir='../data/nhl_playoffs')

def download_playoffs_data(downloader,start_year, end_year) -> None:
    """
        Fonction utilisant des appels REST calls pour télécharger les données des playoffs des saisons allant de start_year à end_year. Sauvegarde le résultat json dans le path 
        défini dans la classe NHLDataDownloader
        :param start_year: année de début de la liste écrite en 4-digits.
        :param end_year: année de fin de la liste écrite en 4-digits.
        :return: None

        """
    #Premier tour des playoffs (1/8 de finale) : 0301
    #Deuxième tour (quarts de finale) : 0302
    #Troisième tour (demi-finales) : 0303
    #Finale : 0304
       
    for year in range(start_year, end_year + 1):
        year_str = str(year)
        print(f"Téléchargement des données des playoffs pour la saison {year_str}")

        # Générer les IDs des matchs de playoffs
        playoffs = []
        # Huitièmes de finale
        playoffs.extend([f"{year_str}0301{str(matchup)}{game_number}" for matchup in range(1, 9) for game_number in range(1, 8)])
        # Quarts de finale
        playoffs.extend([f"{year_str}0302{str(matchup)}{game_number}" for matchup in range(1, 5) for game_number in range(1, 8)])   
        # Demi-finales
        playoffs.extend([f"{year_str}0303{str(matchup)}{game_number}" for matchup in range(1, 3) for game_number in range(1, 8)])   
        # Finales
        playoffs.extend([f"{year_str}0304{str(1)}{game_number}" for game_number in range(1, 8)])        
        
        # Télécharger chaque match de playoffs
        for game_id in playoffs:
            game_data = downloader.download_game_data(game_id=game_id)
            # Vérifier le contenu des données téléchargées
            if game_data:
                print(f"Données pour le game_id {game_id} téléchargées avec succès.")
            else:
                print(f"Aucune donnée disponible pour le game_id {game_id}.")

# Télécharger toutes les données des playoffs de 2016 à 2023
download_playoffs_data(downloader, start_year=2016, end_year=2023)

# %% [markdown]
# ### 3. Fusion des deux repertoires
# _data/nhl_reguliere_ et _data/nhl_playoffs_ dans _data/nhl_data_

# %%
import os
import shutil

# Define the paths to your folders
reguliere_folder = '../data/nhl_reguliere'
playoffs_folder = '../data/nhl_playoffs'
destination_folder ='../data/nhl_data'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Function to copy files from a source folder to the destination folder
def copy_files(source_folder, destination_folder):
    # Loop through all files in the source folder
    for filename in os.listdir(source_folder):
            source_file = os.path.join(source_folder, filename)
            destination_file = os.path.join(destination_folder, filename)

            # Copy the file to the destination folder
            shutil.copy(source_file, destination_file)
            print(f"Copied {filename} to {destination_folder}")

# Copy files from both nhl_reguliere and nhl_playoffs to nhl_data
copy_files(reguliere_folder, destination_folder)
copy_files(playoffs_folder, destination_folder)

print("All files have been copied successfully.")
